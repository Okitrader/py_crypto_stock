# %%
import numpy as np
import polars as pl
import matplotlib.pyplot as plt

# Create timestamps
time = np.arange(0, 50, 0.1) 

# Assign Amplitude and normalize above 0
amplitude = np.sin(time)      # 1. Generate the sine wave: Values will range from -1 to +1
amplitude = amplitude + 1     # 2. Shift values above zero: Add 1 to make the range 0 to 2
max_amp = max(amplitude)    # 3. Find the maximum amplitude: This will be 2 (after the shift)
amplitude = amplitude / max_amp # 4. Normalize to a range of 0 to 1: Divide by max_amp 
                                 #    so the sine wave values now fluctuate between 0 and 1.

# Construct DataFrame using Polars
df = pl.DataFrame({
    "Close": amplitude  # Using capital "C" for consistency 
})

# Calculate percentage change 
df = df.with_columns(
    pl.col("Close").pct_change().alias("Close_Rt")  # Capital "R" for consistency
)


df = df.fill_nan(None)

# Show DataFrame and Values
print(f"Length: {len(df)}")
print(f"Min Close: {df['Close'].min()}")
print(f"Max Close: {df['Close'].max()}")
print("\nDataFrame Head:")
print(df.head())
# Out:
# Length: 500
# Min Close: 4.896739968063352e-06
# Max Close: 1.0
#
# DataFrame Head:
# shape: (5, 2)
# ┌──────────┬──────────┐
# │ Close    ┆ Close_Rt │
# │ ---      ┆ ---      │
# │ f64      ┆ f64      │
# ╞══════════╪══════════╡
# │ 0.500002 ┆ null     │
# │ 0.549918 ┆ 0.099833 │
# │ 0.599337 ┆ 0.089864 │
# │ 0.647762 ┆ 0.080799 │
# │ 0.694711 ┆ 0.072479 │
# └──────────┴──────────┘

# %%
df = df.fill_null(0)
df.head()
# Out:
# shape: (5, 2)
# ┌──────────┬──────────┐
# │ Close    ┆ Close_Rt │
# │ ---      ┆ ---      │
# │ f64      ┆ f64      │
# ╞══════════╪══════════╡
# │ 0.500002 ┆ 0.0      │
# │ 0.549918 ┆ 0.099833 │
# │ 0.599337 ┆ 0.089864 │
# │ 0.647762 ┆ 0.080799 │
# │ 0.694711 ┆ 0.072479 │
# └──────────┴──────────┘

# %%
# Plot the sine wave (Matplotlib works well with Polars)
plt.rcParams['figure.figsize'] = (15, 3)  # Set plot size
plt.plot(df['Close']) 
plt.title("Sine Wave for Trading Environment")
plt.xlabel("Time Step")
plt.ylabel("Normalized Price")
plt.show()

# %%
# Enviornment setup and class
import gym
from gym import spaces # use gym .24.0 from pip install
import numpy as np
import random
import torch
# Out:
# Warning: Gym version v0.24.0 has a number of critical issues with `gym.make` such that the `reset` and `step` functions are called before returning the environment. It is recommend to downgrading to v0.23.1 or upgrading to v0.25.1

# %%
# Initialize environment variables
MAX_INT = 2147483647  # Maximum integer for scaling
MAX_OPEN_POSITIONS = 1 
INITIAL_ACCOUNT_BALANCE = 1000
PERCENT_CAPITAL = 0.1 
TRADING_COSTS_RATE = 0.001 
KILL_THRESHOLD = 0.4   # Terminate if balance drops below this threshold

# %%
import gym
from gym import spaces  # Use Gym 0.24.0 from pip install
import numpy as np
import polars as pl # use polars
import random
import torch

# Initialize variables
MAX_INT = 2147483647
MAX_OPEN_POSITIONS = 1  # Maximum number of simultaneous open positions allowed
INITIAL_ACCOUNT_BALANCE = 1000  # Starting capital for trading
PERCENT_CAPITAL = 0.1  # Percentage of capital to be used for each trade
TRADING_COSTS_RATE = 0.001  # Trading cost percentage per trade
KILL_THRESH = 0.4  # Threshold for balance preservation (if net_worth falls below this, trading stops)


# Structure environment
class StockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}

    def __init__(self, df: pl.DataFrame): # make sure we have a polars dataframe as input
        super(StockTradingEnv, self).__init__()

        # Generic variables
        self.df = df  # DataFrame containing historical price data

        # Account variables
        self.available_balance = INITIAL_ACCOUNT_BALANCE  # Tracks available capital
        self.net_worth = INITIAL_ACCOUNT_BALANCE  # Total account value
        self.realized_profit = 0  # Profit from closed positions
        self.unrealized_profit = 0  # Profit from open positions (unrealized)
        self.last_profit = 0  # Profit from the most recent closed position

        # Position variables
        self.open_quantities = []  # List to store quantities of assets in open positions
        self.open_prices = []  # List to store prices at which positions were opened
        self.trading_costs = 0  # Total trading costs incurred
        self.open_positions = 0  # Number of currently open positions
        self.closed_positions = 0  # Number of positions closed
        self.incorrect_position_calls = 0  # Number of times an invalid trading action was attempted
        self.num_trades = 0  # Total number of trades executed
        self.held_for_period = 0  # Number of steps a position has been held

        # Current Step
        self.current_step = 0  # Current time step in the trading environment
        self.max_steps = len(df)  # Total number of time steps in the dataset

        # Actions of the format Long, Hold, Close
        self.action_space = spaces.Discrete(3)  # 0: Long, 1: Hold, 2: Close

        # Prices contains the Close and Close Returns etc
        self.observation_space = spaces.Box(low=-1, high=1, shape=(8,),
                                            dtype=np.float32)  # Observation space shape (8 features)

    # Calculate Reward
    def _calculate_reward(self):
        """Calculates the reward for taking an action at the current step."""
        reward = 0  # Initialize reward

        # Reward for profit only if trades have been made
        if self.num_trades:
            reward += self.realized_profit / self.num_trades  # Reward for average realized profit
            reward += self.unrealized_profit / self.num_trades * 0.3  # Reward for unrealized profit (smaller weight)
            reward += 1 if self.last_profit > 0 else 0  # Bonus for a profitable last trade

        reward -= 1 if self.incorrect_position_calls > 0 else 0  # Penalty for incorrect position calls

        # Additional penalty if the reward is non-positive
        if reward <= 0:
            reward -= 2
        return reward

    # Structure sign observation data
    def _next_observation(self):
        """Returns the next observation (state) of the environment."""
        # Accessing polars dataframe by index is slightly different than pandas
        close_item = self.df["Close"][self.current_step]
        close_rt_item = self.df["Close_Rt"][self.current_step]
        close_T1_item = self.df["Close_Rt"][self.current_step - 1] if (
                    self.current_step - 1) >= 0 else 0  # Lookback: 1 step
        close_T2_item = self.df["Close_Rt"][self.current_step - 2] if (
                    self.current_step - 2) >= 0 else 0  # Lookback: 2 steps
        close_T3_item = self.df["Close_Rt"][self.current_step - 3] if (
                    self.current_step - 3) >= 0 else 0  # Lookback: 3 steps
        close_T4_item = self.df["Close_Rt"][self.current_step - 4] if (
                    self.current_step - 4) >= 0 else 0  # Lookback: 4 steps

        current_position = 1 if self.open_positions else 0  # 1 if a position is open, else 0
        num_trades = self.num_trades / len(self.df) if self.num_trades > 0 else 0  # Normalize number of trades

        # Create the observation array
        obs = np.array([close_item, close_rt_item, close_T1_item, close_T2_item, close_T3_item, close_T4_item,
                        current_position, num_trades])
        return obs

    # Calculate current open value
    def _calculate_open_value(self):
        """Calculates the total value of all open positions."""
        open_trades_value = 0
        counts = 0
        for qty in self.open_quantities:
            acquisition_price = self.open_prices[counts]
            open_trades_value += acquisition_price * qty
            counts += 1
        return open_trades_value

    # Calculate gross profit
    def _profit_calculation(self, current_price, calc_type):
        """Calculates profit based on the current price and action type."""
        open_trades_value = self._calculate_open_value()  # Get current value of open positions
        total_quantity_held = sum(self.open_quantities)  # Total quantity of assets held
        current_value = total_quantity_held * current_price  # Value if all positions were closed now

        # Calculate gross profit
        gross_profit = current_value - open_trades_value

        # Calculate trading costs based on action type
        if calc_type == "close_position":
            trading_costs = current_value * TRADING_COSTS_RATE  # Costs when closing positions
            self.trading_costs += trading_costs  # Update total trading costs
        elif calc_type == "hold_position" or calc_type == "open_position":
            trading_costs = open_trades_value * TRADING_COSTS_RATE  # Costs when holding or opening

        net_profit = gross_profit - trading_costs  # Calculate net profit
        return net_profit

    # Set the current price to a random price within the time step
    def _take_action(self, action):
        """Executes the chosen action in the trading environment."""
        current_price = self.df["Close"][self.current_step]  # Get current price

        # Reset temporary variables
        self.last_profit = 0
        self.incorrect_position_calls = 0

        # ------------------------------------------------------------------
        # Trading Logic based on Action
        # ------------------------------------------------------------------
        # Go Long (Buy)
        if action == 0:
            if self.open_positions < MAX_OPEN_POSITIONS:  # Check if allowed to open more positions
                net_profit = self._profit_calculation(current_price,
                                                      "open_position")  # Calculate potential profit
                net_worth = self.net_worth + net_profit
                trading_allowance = net_worth * PERCENT_CAPITAL  # Calculate the amount to invest

                # Update position information
                self.open_quantities.append(trading_allowance / current_price)  # Quantity purchased
                self.open_prices.append(current_price)  # Price at purchase
                self.trading_costs += trading_allowance * TRADING_COSTS_RATE  # Add trading costs
                self.num_trades += 1  # Increment trade counter
            else:
                self.incorrect_position_calls += 1  # Penalize for trying to exceed open position limit

        # Hold Positions
        if action == 1:
            net_profit = self._profit_calculation(current_price,
                                                      "hold_position")  # Calculate profit/loss for holding
            self.unrealized_profit += net_profit  # Update unrealized profit
            if self.open_positions > 0:
                self.held_for_period += 1  # Increment hold period counter

        # Close Positions (Sell)
        if action == 2:
            if self.open_positions != 0:  # Check if there are positions to close
                net_profit = self._profit_calculation(current_price, "close_position")  # Calculate closing profit
                self.last_profit = net_profit  # Update last profit
                self.realized_profit += net_profit  # Update realized profit

                # Reset position-related variables as all positions are closed
                self.unrealized_profit = 0
                self.open_quantities = []
                self.open_prices = []
                self.held_for_period = 0
                self.closed_positions += 1  # Increment closed positions counter
            else:
                self.incorrect_position_calls += 1  # Penalize for trying to close when no positions are open
        # ------------------------------------------------------------------

        # Update account variables
        open_trades_value = self._calculate_open_value()
        self.open_positions = len(self.open_quantities)
        self.net_worth = INITIAL_ACCOUNT_BALANCE + self.unrealized_profit + self.realized_profit
        self.available_balance = INITIAL_ACCOUNT_BALANCE - open_trades_value + self.realized_profit

    # Execute one time step within the environment
    def step(self, action):
        """Performs a single step in the environment."""
        self._take_action(action)  # Execute the chosen action

        reward = self._calculate_reward()  # Calculate the reward for the action

        self.current_step += 1  # Move to the next time step

        # Check termination conditions
        is_max_steps_taken = self.current_step >= self.max_steps - 1  # Reached maximum steps
        is_account_balance_reached = self.net_worth <= INITIAL_ACCOUNT_BALANCE * KILL_THRESH  # Account below threshold
        done = True if is_max_steps_taken or is_account_balance_reached else False  # Set 'done' flag if terminated

        obs = self._next_observation()  # Get the next observation

        return obs, reward, done, {}  # Return observation, reward, done flag, and additional info (empty dict)

    # Reset the state of the environment to an initial state
    def reset(self):
        """Resets the environment to its initial state."""
        self.account_balance = INITIAL_ACCOUNT_BALANCE
        self.net_worth = INITIAL_ACCOUNT_BALANCE
        self.realized_profit = 0
        self.unrealized_profit = 0
        self.open_quantities = []
        self.open_prices = []
        self.trading_costs = 0
        self.open_positions = 0
        self.incorrect_position_calls = 0
        self.current_step = 5  # Start from the 6th step to have enough lookback data

        return self._next_observation()  # Return the initial observation

    # Render the environment to the screen
    def render(self, mode='human', close=False):
        """Renders the environment (not implemented in this example)."""
        profit = self.net_worth - INITIAL_ACCOUNT_BALANCE
        return profit

# %%
# Test Environment
env = StockTradingEnv(df)
actions = [0, 1, 2] # 0 long, 1 hold, 2 close position sell
observation = env.reset()
print("Initial Observation: ", observation)

for action in actions:
    obs_, reward, done, info = env.step(action)
    print("")
    print("Action Taken: ", action)
    print("Reward Received : ", reward)
    print("Next State: ", obs_)
    print("Completed: ", done)
    print("-------------------")
    print("Available Balance: ", env.available_balance)
    print("Net Worth : ", env.net_worth)
    print("Realized Profit: ", env.realized_profit)
    print("Unrealized Profit: ", env.unrealized_profit)
    print("Open Quantities: ", env.open_quantities)
    print("Open Prices: ", env.open_prices)
    print("Trading Costs: ", env.trading_costs)
    print("Open Positions: ", env.open_positions)
    print("Incorrect Calls: ", env.incorrect_position_calls)
    print("-------------------")
# Out:
# Initial Observation:  [0.73971508 0.06478049 0.0724791  0.08079866 0.08986444 0.09983342
#  0.         0.        ]
#
# Action Taken:  0
# Reward Received :  -2.0
# Next State:  [0.78232368 0.05760137 0.06478049 0.0724791  0.08079866 0.08986444
#  1.         0.002     ]
# Completed:  False
# -------------------
# Available Balance:  900.0
# Net Worth :  1000
# Realized Profit:  0
# Unrealized Profit:  0
# Open Quantities:  [135.18718520595226]
# Open Prices:  [0.7397150835536224]
# Trading Costs:  0.1
# Open Positions:  1
# Incorrect Calls:  0
# -------------------
#
# Action Taken:  1
# Reward Received :  1.6980410382376971
# Next State:  [0.82211142 0.0508584  0.05760137 0.06478049 0.0724791  0.08079866
#  1.         0.002     ]
# Completed:  False
# -------------------
# Available Balance:  900.0
# Net Worth :  1005.6601367941256
# Realized Profit:  0
# Unrealized Profit:  5.660136794125657
# Open Quantities:  [135.18718520595226]
# Open Prices:  [0.7397150835536224]
# Trading Costs:  0.1
# Open Positions:  1
# Incorrect Calls:  0
# -------------------
#
# Action Taken:  2
# Reward Received :  12.027789279626449
# Next State:  [0.85868073 0.04448219 0.0508584  0.05760137 0.06478049 0.0724791
#  0.         0.002     ]
# Completed:  False
# -------------------
# Available Balance:  1011.0277892796264
# Net Worth :  1011.0277892796264
# Realized Profit:  11.027789279626449
# Unrealized Profit:  0
# Open Quantities:  []
# Open Prices:  []
# Trading Costs:  0.2111389282078343
# Open Positions:  0
# Incorrect Calls:  0
# -------------------

# %% [markdown]
# ### Utilities

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
    """
    Plots the learning curve of an agent during training, showing the running average of scores.

    Args:
        x (array-like): An array representing the x-axis values (e.g., episodes or steps).
        scores (array-like): An array of scores achieved by the agent at each x-axis value.
        figure_file (str): The filename to save the plot to.
    """
    
    running_avg = np.zeros(len(scores))  # Initialize an array to store the running average
    
    # Calculate running average over a window of 100 scores
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])  # Calculate mean of scores for the current window
    
    # Plot the running average
    plt.plot(x, running_avg)  # Plot x-values against the running average
    plt.title('Running average of previous 100 scores')  # Set plot title
    plt.savefig(figure_file)  # Save the plot to a file

# %% [markdown]
# ### PPO Classes

# %% [markdown]
# #### Imports

# %%
import os
import numpy as np
import torch as T
import torch.nn as nn
import torch.optim as optim
from torch.distributions.categorical import Categorical

# %% [markdown]
# #### PPO Memory Management

# %%
import numpy as np
from typing import List, Tuple, Any

class PPOMemory:
    """
    Experience replay buffer for Proximal Policy Optimization (PPO).

    This class stores and manages the agent's experiences (state, action, reward, etc.) 
    collected during training. It provides methods to sample batches of these 
    experiences for efficient learning. It uses NumPy arrays for efficient storage 
    and operations, and implements a circular buffer to manage memory.
    """

    def __init__(self, batch_size: int, state_dim: int, max_size: int = 10000):
        """
        Initializes the PPOMemory buffer.

        Args:
            batch_size (int): The size of each batch sampled from the buffer.
            state_dim (int): The dimensionality of the state space.
            max_size (int, optional): Maximum number of experiences to store. Defaults to 10000.
        """
        self.batch_size = batch_size
        self.max_size = max_size
        self.ptr = 0  # Pointer to keep track of the current position in the buffer

        # Initialize memory arrays using NumPy for efficient storage and operations
        self.states = np.zeros((max_size, state_dim), dtype=np.float32)   # Store states
        self.actions = np.zeros(max_size, dtype=np.int32)                # Store actions taken
        self.probs = np.zeros(max_size, dtype=np.float32)                 # Store action probabilities
        self.vals = np.zeros(max_size, dtype=np.float32)                  # Store state values (critic estimates)
        self.rewards = np.zeros(max_size, dtype=np.float32)                # Store rewards received
        self.dones = np.zeros(max_size, dtype=bool)                     # Store done flags (episode termination)

    def store_memory(self, state: np.ndarray, action: int, probs: float, vals: float, reward: float, done: bool) -> None:
        """
        Stores a single experience tuple in the buffer.

        Args:
            state (np.ndarray): The current state.
            action (int): The action taken.
            probs (float): The probability of taking the chosen action.
            vals (float): The estimated value of the current state.
            reward (float): The reward received after taking the action.
            done (bool): True if the episode ended after this step, False otherwise.
        """
        idx = self.ptr % self.max_size  # Calculate index using modulo for circular buffer
        
        # Store experience at the calculated index
        self.states[idx] = state
        self.actions[idx] = action
        self.probs[idx] = probs
        self.vals[idx] = vals
        self.rewards[idx] = reward
        self.dones[idx] = done
        
        self.ptr += 1  # Increment pointer for the next experience

    def generate_batches(self) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, np.ndarray, List[np.ndarray]]:
        """
        Generates random batches of experiences for training.

        This method shuffles the stored experiences and then creates batches of 
        indices pointing to those shuffled experiences. It uses memory views to avoid
        copying data, which is more efficient than creating new arrays.

        Returns:
            Tuple[np.ndarray, ...]: A tuple containing:
                - states (np.ndarray): Batch of states.
                - actions (np.ndarray): Batch of actions.
                - probs (np.ndarray): Batch of action probabilities.
                - vals (np.ndarray): Batch of state values.
                - rewards (np.ndarray): Batch of rewards.
                - dones (np.ndarray): Batch of done flags.
                - batches (List[np.ndarray]): A list of arrays, each containing indices for a batch of experiences.
        """
        max_mem = min(self.ptr, self.max_size)  # Use stored memory up to max_size
        indices = np.random.permutation(max_mem)  # Shuffle indices to create random batches

        # Get memory views (references, not copies) for efficiency
        states = self.states[:max_mem]
        actions = self.actions[:max_mem]
        probs = self.probs[:max_mem]
        vals = self.vals[:max_mem]
        rewards = self.rewards[:max_mem]
        dones = self.dones[:max_mem]

        # Create batch starting indices
        start_idx = np.arange(0, max_mem, self.batch_size) 

        # Generate batches of indices
        batches = [indices[i:i+self.batch_size] for i in start_idx]  

        return (states, actions, probs, vals, rewards, dones, batches)

    def clear_memory(self) -> None:
        """Clears the replay buffer."""
        self.ptr = 0  # Reset the pointer to the beginning

# %% [markdown]
# #### Create a tmp Directory

# %% [markdown]
# ## Actor Neural Net

# %%
# Actor Neural Network

class ActorNetwork(nn.Module):
    def __init__(self, n_actions, input_dims, alpha,
                 fc1_dims=256, fc2_dims=256, chkpt_dir='tmp/'):
        super(ActorNetwork, self).__init__()

        # Ensure the checkpoint directory exists
        os.makedirs(chkpt_dir, exist_ok=True)
        
        self.checkpoint_file = os.path.join(chkpt_dir, 'actor_torch_ppo_sine')
        
        self.actor = nn.Sequential(
            nn.Linear(input_dims, fc1_dims),
            nn.ReLU(),
            nn.Linear(fc1_dims, fc2_dims),
            nn.ReLU(),
            nn.Linear(fc2_dims, n_actions),
            nn.Softmax(dim=-1)
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        # Convert numpy array to torch tensor if necessary
        if isinstance(state, np.ndarray):
            state = T.tensor(state, dtype=T.float).to(self.device)
        
        dist = self.actor(state)
        dist = Categorical(dist)
        
        return dist

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# ### Critic Neural Net

# %%
# Critic Neural Net

class CriticNetwork(nn.Module):
    def __init__(self, input_dims, alpha, fc1_dims=256, fc2_dims=256,
                 chkpt_dir='tmp/'):
        super(CriticNetwork, self).__init__()

        # Ensure the checkpoint directory exists
        os.makedirs(chkpt_dir, exist_ok=True)

        self.checkpoint_file = os.path.join(chkpt_dir, 'critic_torch_ppo_sine')
        self.critic = nn.Sequential(
            nn.Linear(input_dims, fc1_dims),
            nn.ReLU(),
            nn.Linear(fc1_dims, fc2_dims),
            nn.ReLU(),
            nn.Linear(fc2_dims, 1)
        )

        self.optimizer = optim.AdamW(self.parameters(), lr=alpha)
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def forward(self, state):
        # Convert numpy array to torch tensor if necessary
        if isinstance(state, np.ndarray):
            state = T.tensor(state, dtype=T.float).to(self.device)
        
        value = self.critic(state)
        return value

    def save_checkpoint(self):
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# ### Agent
#
# It manages the interaction between the environment and the learning process.
#
# 1. Maintains an actor network to decide actions and a critic network to estimate state values.
# 2. Chooses actions based on the current policy when given an observation from the environment.
# 3. Stores experiences (state, action, reward, etc.) in a memory buffer.
# 4. Periodically learns from collected experiences by updating its policy and value estimates.
# 5. Uses GAE (Generalized Advantage Estimation) to compute advantages, which helps balance bias and variance in policy updates.
# 6. Implements the PPO objective, which allows for stable policy improvements while preventing too large policy changes.
# 7. Provides methods to save and load trained models for continued learning or deployment.

# %%
# Agent Neural Net

class Agent:
    def __init__(self, n_actions, input_dims, gamma=0.99, alpha=0.0003, gae_lambda=0.95,
                 policy_clip=0.2, batch_size=64, n_epochs=10):
        self.gamma = gamma  # Discount factor for future rewards
        self.policy_clip = policy_clip  # Clipping parameter for PPO
        self.n_epochs = n_epochs  # Number of epochs to train on each batch
        self.gae_lambda = gae_lambda  # Lambda parameter for Generalized Advantage Estimation
    
        # Initialize actor and critic networks
        self.actor = ActorNetwork(n_actions, input_dims, alpha)
        self.critic = CriticNetwork(input_dims, alpha)
        self.memory = PPOMemory(batch_size, input_dims)  # Pass input_dims to PPOMemory
       
    def remember(self, state, action, probs, vals, reward, done):
        # Store experience in memory buffer
        self.memory.store_memory(state, action, probs, vals, reward, done)

    def save_models(self):
        # Save actor and critic models
        print('... saving models ...')
        self.actor.save_checkpoint()
        self.critic.save_checkpoint()

    def load_models(self):
        # Load actor and critic models
        print('... loading models ...')
        self.actor.load_checkpoint()
        self.critic.load_checkpoint()

    def choose_action(self, observation):
        # Convert observation to tensor and choose action
        state = T.tensor(observation, dtype=T.float).to(self.actor.device)
        
        # Get action distribution and state value
        dist = self.actor(state)
        value = self.critic(state)
        action = dist.sample()

        # Extract probabilities, action, and value
        probs = T.squeeze(dist.log_prob(action)).item()
        action = T.squeeze(action).item()
        value = T.squeeze(value).item()

        return action, probs, value

    def learn(self):
        for _ in range(self.n_epochs):
            # Generate batches from memory
            state_arr, action_arr, old_prob_arr, vals_arr, \
            reward_arr, dones_arr, batches = \
                    self.memory.generate_batches()

            # Calculate advantages using GAE
            values = vals_arr
            advantage = np.zeros(len(reward_arr), dtype=np.float32)
            for t in range(len(reward_arr)-1):
                discount = 1
                a_t = 0
                for k in range(t, len(reward_arr)-1):
                    a_t += discount*(reward_arr[k] + self.gamma*values[k+1]*\
                            (1-int(dones_arr[k])) - values[k])
                    discount *= self.gamma*self.gae_lambda
                advantage[t] = a_t

            # Convert to tensors
            advantage = T.tensor(advantage).to(self.actor.device)
            values = T.tensor(values).to(self.actor.device)

            # Update policy and value function
            for batch in batches:
                states = T.tensor(state_arr[batch], dtype=T.float).to(self.actor.device)
                old_probs = T.tensor(old_prob_arr[batch]).to(self.actor.device)
                actions = T.tensor(action_arr[batch]).to(self.actor.device)

                # Get new action distributions and critic values
                dist = self.actor(states)
                critic_value = self.critic(states)
                critic_value = T.squeeze(critic_value)

                # Calculate ratios for PPO update
                new_probs = dist.log_prob(actions)
                prob_ratio = new_probs.exp() / old_probs.exp()

                # Compute PPO loss
                weighted_probs = advantage[batch] * prob_ratio
                weighted_clipped_probs = T.clamp(prob_ratio, 1-self.policy_clip,
                        1+self.policy_clip)*advantage[batch]
                actor_loss = -T.min(weighted_probs, weighted_clipped_probs).mean()

                # Compute critic loss
                returns = advantage[batch] + values[batch]
                critic_loss = (returns-critic_value)**2
                critic_loss = critic_loss.mean()

                # Compute total loss and perform backpropagation
                total_loss = actor_loss + 0.5*critic_loss
                self.actor.optimizer.zero_grad()
                self.critic.optimizer.zero_grad()
                total_loss.backward()
                self.actor.optimizer.step()
                self.critic.optimizer.step()

        # Clear memory after learning
        self.memory.clear_memory()

# %%
import logging
from typing import Dict, Any

# Configuration
CONFIG: Dict[str, Any] = {
    'batch_size': 5,
    'n_epochs': 4,
    'alpha': 0.0003,
    'test_episodes': 1
}

# Set up logging
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# Remove all handlers associated with the logger object.
for handler in logger.handlers[:]:
    logger.removeHandler(handler)

# Create file handler
file_handler = logging.FileHandler('trading_agent.log', mode='w')
file_handler.setLevel(logging.INFO)

# Create console handler
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)

# Create formatter and add it to the handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add the handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# Rest of your code remains the same...

# Testing
try:
    # Create the trading environment
    env = StockTradingEnv(df)

    # Initialize the agent
    agent = Agent(n_actions=env.action_space.n, batch_size=CONFIG['batch_size'], 
                  alpha=CONFIG['alpha'], n_epochs=CONFIG['n_epochs'], 
                  input_dims=env.observation_space.shape[0])

    episode_data = []  # List to store data for visualization

    for episode in range(CONFIG['test_episodes']):
        # Reset the environment and get initial observation
        observation = env.reset()

        # Choose an action using the agent
        action, prob, val = agent.choose_action(observation)

        # Get the number of possible actions
        n_actions = env.action_space.n

        # Log initial state and action information
        logger.info(f"Episode {episode + 1}")
        logger.info(f"Initial Observation: {observation}")
        logger.info(f"Number of Actions: {n_actions}")
        logger.info(f"Action Chosen: {action}")
        logger.info(f"Probability of Action: {prob}")
        logger.info(f"Value of Action: {val}")

        # Take a step in the environment
        try:
            observation_, reward, done, info = env.step(action)
        except Exception as e:
            logger.error(f"Error during environment step: {str(e)}")
            break

        # Log the results of the step
        logger.info(f"Next Observation: {observation_}")
        logger.info(f"Reward: {reward}")
        logger.info(f"Done: {done}")
        logger.info(f"Info: {info}")

        # Store the experience
        agent.remember(observation, action, prob, val, reward, done)

        # Store data for visualization
        episode_data.append({
            'episode': episode + 1,
            'initial_observation': observation,
            'action': action,
            'reward': reward
        })

except Exception as e:
    logger.error(f"An error occurred during testing: {str(e)}")

finally:
    logger.info("Testing completed")
# Out:
# 2024-08-05 17:26:48,917 - __main__ - INFO - Episode 1
# 2024-08-05 17:26:48,920 - __main__ - INFO - Initial Observation: [0.73971508 0.06478049 0.0724791  0.08079866 0.08986444 0.09983342
#  0.         0.        ]
# 2024-08-05 17:26:48,921 - __main__ - INFO - Number of Actions: 3
# 2024-08-05 17:26:48,922 - __main__ - INFO - Action Chosen: 2
# 2024-08-05 17:26:48,922 - __main__ - INFO - Probability of Action: -1.1165931224822998
# 2024-08-05 17:26:48,923 - __main__ - INFO - Value of Action: 0.0275435633957386
# 2024-08-05 17:26:48,927 - __main__ - INFO - Next Observation: [0.78232368 0.05760137 0.06478049 0.0724791  0.08079866 0.08986444
#  0.         0.        ]
# 2024-08-05 17:26:48,929 - __main__ - INFO - Reward: -3
# 2024-08-05 17:26:48,930 - __main__ - INFO - Done: False
# 2024-08-05 17:26:48,931 - __main__ - INFO - Info: {}
# 2024-08-05 17:26:48,932 - __main__ - INFO - Testing completed

# %%
import matplotlib.pyplot as plt

# Visualization
if episode_data:
    for data in episode_data:
        # Visualize initial state
        plt.figure(figsize=(10, 5))
        plt.plot(data['initial_observation'])
        plt.title(f"Initial Observation (Episode {data['episode']})")
        plt.xlabel("Feature")
        plt.ylabel("Value")
        plt.show()

        # Visualize action taken
        plt.figure(figsize=(5, 5))
        plt.bar(['Long', 'Hold', 'Close'], [1 if i == data['action'] else 0 for i in range(3)])
        plt.title(f"Action Taken (Episode {data['episode']})")
        plt.ylabel("Chosen")
        plt.show()

    # Plot rewards
    plt.figure(figsize=(10, 5))
    plt.plot([data['episode'] for data in episode_data], [data['reward'] for data in episode_data], marker='o')
    plt.title("Rewards per Episode")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.show()
else:
    print("No episode data available for visualization.")

# %% [markdown]
# ### Train Agents

# %%
if __name__ == '__main__':
    # Assuming df is already defined and contains your sine wave data
    env = StockTradingEnv(df)
    N = 20
    batch_size = 5
    n_epochs = 8
    alpha = 0.0003
    agent = Agent(n_actions=env.action_space.n, batch_size=batch_size, 
                    alpha=alpha, n_epochs=n_epochs, 
                    input_dims=env.observation_space.shape[0])  # Note the change here
    n_games = 200

    figure_file = 'sinewave.png'

    best_score = env.reward_range[0]
    score_history = []

    learn_iters = 0
    avg_score = 0
    n_steps = 0
    
    print("... starting ...")
    for i in range(n_games):
        observation = env.reset()
        done = False
        score = 0
        while not done:
            action, prob, val = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            n_steps += 1
            score += reward
            agent.remember(observation, action, prob, val, reward, done)
            if n_steps % N == 0:
                agent.learn()
                learn_iters += 1
            observation = observation_
            
        # Save history
        score_history.append(score)
        avg_score = np.mean(score_history[-50:])
        
        if avg_score > best_score and i > 50:
            best_score = avg_score
            agent.save_models()
            
        print(f"episode: {i}, score: {score}, avg score: {avg_score}, time_steps: {n_steps}, learning steps: {learn_iters}")
            
    x = [i+1 for i in range(len(score_history))]
    plot_learning_curve(x, score_history, figure_file)
# Out:
# ... starting ...
# episode: 0, score: 15769.383413294001, avg score: 15769.383413294001, time_steps: 494, learning steps: 24
# episode: 1, score: -1481.0, avg score: 7144.1917066470005, time_steps: 988, learning steps: 49
# episode: 2, score: -1481.0, avg score: 4269.127804431334, time_steps: 1482, learning steps: 74
# episode: 3, score: -114.23418936615204, avg score: 3173.287305981962, time_steps: 1525, learning steps: 76
# episode: 4, score: -109.83552203166208, avg score: 2516.662740379237, time_steps: 1569, learning steps: 78
# episode: 5, score: -72.31165960830255, avg score: 2085.167007047981, time_steps: 1610, learning steps: 80
# episode: 6, score: 1870.521894379649, avg score: 2054.5034195239336, time_steps: 1780, learning steps: 89
# episode: 7, score: -84.09463472968801, avg score: 1787.1786627422307, time_steps: 1820, learning steps: 91
# episode: 8, score: -78.68881557192091, avg score: 1579.8600540406583, time_steps: 1856, learning steps: 92
# episode: 9, score: -67.32120350990995, avg score: 1415.1419282856016, time_steps: 1906, learning steps: 95
# episode: 10, score: 66741.64050749509, avg score: 7353.914526395555, time_steps: 2400, learning steps: 120
# episode: 11, score: -1461.8281651652449, avg score: 6619.269302098822, time_steps: 2894, learning steps: 144
# episode: 12, score: -1481.0, avg score: 5996.171663475835, time_steps: 3388, learning steps: 169
# episode: 13, score: -1465.336557053775, avg score: 5463.2067905808635, time_steps: 3882, learning steps: 194
# episode: 14, score: -356.8230306577877, avg score: 5075.204802498286, time_steps: 4376, learning steps: 218
# episode: 15, score: -193.19787875271547, avg score: 4745.929634920099, time_steps: 4493, learning steps: 224
# episode: 16, score: 19343.862144046023, avg score: 5604.631547221624, time_steps: 4987, learning steps: 249
# episode: 17, score: -1481.0, avg score: 5210.9853501537555, time_steps: 5481, learning steps: 274
# episode: 18, score: -1542.2615815062468, avg score: 4855.551301119019, time_steps: 5975, learning steps: 298
# episode: 19, score: -1481.0, avg score: 4538.723736063068, time_steps: 6469, learning steps: 323
# episode: 20, score: -497.87241276786284, avg score: 4298.885824213976, time_steps: 6630, learning steps: 331
# episode: 21, score: 110266202973963.16, avg score: 5012100139283.626, time_steps: 7124, learning steps: 356
# episode: 22, score: 102233649838.07234, avg score: 4798627683220.775, time_steps: 7618, learning steps: 380
# episode: 23, score: 115344528662.20715, avg score: 4603490885114.169, time_steps: 8112, learning steps: 405
# episode: 24, score: 164501426653.0254, avg score: 4425931306775.723, time_steps: 8606, learning steps: 430
# episode: 25, score: 5851831079644.936, avg score: 4480773605732.231, time_steps: 9100, learning steps: 455
# episode: 26, score: 975668055781034.1, avg score: 40450672945558.23, time_steps: 9594, learning steps: 479
# episode: 27, score: 38963780285389.69, avg score: 40397569636266.49, time_steps: 10088, learning steps: 504
# episode: 28, score: 53412823021349.42, avg score: 40846371477131.42, time_steps: 10582, learning steps: 529
# episode: 29, score: 8958439048104530.0, avg score: 338099460698044.75, time_steps: 11076, learning steps: 553
# episode: 30, score: -1481.0, avg score: 327193026481930.94, time_steps: 11570, learning steps: 578
# episode: 31, score: -1481.0, avg score: 316968244404324.3, time_steps: 12064, learning steps: 603
# episode: 32, score: -1481.0, avg score: 307363146088996.9, time_steps: 12558, learning steps: 627
# episode: 33, score: -1481.0, avg score: 298323053556924.0, time_steps: 13052, learning steps: 652
# episode: 34, score: -1481.0, avg score: 289799537740969.6, time_steps: 13546, learning steps: 677
# episode: 35, score: -1481.0, avg score: 281749550581457.1, time_steps: 14040, learning steps: 702
# episode: 36, score: -1481.0, avg score: 274134697862999.34, time_steps: 14534, learning steps: 726
# episode: 37, score: -1481.0, avg score: 266920626866565.7, time_steps: 15028, learning steps: 751
# episode: 38, score: -1481.0, avg score: 260076508228923.5, time_steps: 15522, learning steps: 776
# episode: 39, score: -1481.0, avg score: 253574595523163.3, time_steps: 16016, learning steps: 800
# episode: 40, score: -1481.0, avg score: 247389849290854.94, time_steps: 16510, learning steps: 825
# episode: 41, score: -1481.0, avg score: 241499614783894.56, time_steps: 17004, learning steps: 850
# episode: 42, score: -1481.0, avg score: 235883344672606.78, time_steps: 17498, learning steps: 874
# episode: 43, score: -1481.0, avg score: 230522359566377.53, time_steps: 17992, learning steps: 899
# episode: 44, score: -1481.0, avg score: 225399640464869.6, time_steps: 18486, learning steps: 924
# episode: 45, score: -1481.0, avg score: 220499648280818.53, time_steps: 18980, learning steps: 949
# episode: 46, score: -1481.0, avg score: 215808166402471.75, time_steps: 19474, learning steps: 973
# episode: 47, score: -1481.0, avg score: 211312162935722.6, time_steps: 19968, learning steps: 998
# episode: 48, score: -1481.0, avg score: 206999669814555.2, time_steps: 20462, learning steps: 1023
# episode: 49, score: -1481.0, avg score: 202859676418234.47, time_steps: 20956, learning steps: 1047
# episode: 50, score: -1481.0, avg score: 202859676417889.53, time_steps: 21450, learning steps: 1072
# ... saving models ...
# episode: 51, score: -1481.0, avg score: 202859676417889.53, time_steps: 21944, learning steps: 1097
# episode: 52, score: -1481.0, avg score: 202859676417889.53, time_steps: 22438, learning steps: 1121
# episode: 53, score: -1481.0, avg score: 202859676417862.16, time_steps: 22932, learning steps: 1146
# episode: 54, score: -1481.0, avg score: 202859676417834.72, time_steps: 23426, learning steps: 1171
# episode: 55, score: -1481.0, avg score: 202859676417806.56, time_steps: 23920, learning steps: 1196
# episode: 56, score: -1481.0, avg score: 202859676417739.6, time_steps: 24414, learning steps: 1220
# episode: 57, score: -1481.0, avg score: 202859676417711.6, time_steps: 24908, learning steps: 1245
# episode: 58, score: -1481.0, avg score: 202859676417683.6, time_steps: 25402, learning steps: 1270
# episode: 59, score: -1481.0, avg score: 202859676417655.28, time_steps: 25896, learning steps: 1294
# episode: 60, score: -1481.0, avg score: 202859676416290.88, time_steps: 26390, learning steps: 1319
# episode: 61, score: -1481.0, avg score: 202859676416290.47, time_steps: 26884, learning steps: 1344
# episode: 62, score: -1481.0, avg score: 202859676416290.47, time_steps: 27378, learning steps: 1368
# episode: 63, score: -1481.0, avg score: 202859676416290.16, time_steps: 27872, learning steps: 1393
# episode: 64, score: -1481.0, avg score: 202859676416267.7, time_steps: 28366, learning steps: 1418
# episode: 65, score: -1481.0, avg score: 202859676416241.9, time_steps: 28860, learning steps: 1443
# episode: 66, score: -1481.0, avg score: 202859676415825.44, time_steps: 29354, learning steps: 1467
# episode: 67, score: -1481.0, avg score: 202859676415825.38, time_steps: 29848, learning steps: 1492
# episode: 68, score: -1481.0, avg score: 202859676415826.62, time_steps: 30342, learning steps: 1517
# episode: 69, score: -1481.0, avg score: 202859676415826.62, time_steps: 30836, learning steps: 1541
# episode: 70, score: -1481.0, avg score: 202859676415806.97, time_steps: 31330, learning steps: 1566
# episode: 71, score: -1481.0, avg score: 200654352356298.0, time_steps: 31824, learning steps: 1591
# episode: 72, score: -1481.0, avg score: 200652307683271.6, time_steps: 32318, learning steps: 1615
# episode: 73, score: -1481.0, avg score: 200650000792668.8, time_steps: 32812, learning steps: 1640
# episode: 74, score: -1481.0, avg score: 200646710764106.1, time_steps: 33306, learning steps: 1665
# episode: 75, score: -1481.0, avg score: 200529674142483.6, time_steps: 33800, learning steps: 1690
# episode: 76, score: -1481.0, avg score: 181016313026833.28, time_steps: 34294, learning steps: 1714
# episode: 77, score: -1481.0, avg score: 180237037421095.84, time_steps: 34788, learning steps: 1739
# episode: 78, score: -1481.0, avg score: 179168780960639.22, time_steps: 35282, learning steps: 1764
# episode: 79, score: -1481.0, avg score: -1481.0, time_steps: 35776, learning steps: 1788
# episode: 80, score: -1481.0, avg score: -1481.0, time_steps: 36270, learning steps: 1813
# episode: 81, score: -1481.0, avg score: -1481.0, time_steps: 36764, learning steps: 1838
# episode: 82, score: -1481.0, avg score: -1481.0, time_steps: 37258, learning steps: 1862
# episode: 83, score: -1481.0, avg score: -1481.0, time_steps: 37752, learning steps: 1887
# episode: 84, score: -1481.0, avg score: -1481.0, time_steps: 38246, learning steps: 1912
# episode: 85, score: -1481.0, avg score: -1481.0, time_steps: 38740, learning steps: 1937
# episode: 86, score: -1481.0, avg score: -1481.0, time_steps: 39234, learning steps: 1961
# episode: 87, score: -1481.0, avg score: -1481.0, time_steps: 39728, learning steps: 1986
# episode: 88, score: -1481.0, avg score: -1481.0, time_steps: 40222, learning steps: 2011
# episode: 89, score: -1481.0, avg score: -1481.0, time_steps: 40716, learning steps: 2035
# episode: 90, score: -1481.0, avg score: -1481.0, time_steps: 41210, learning steps: 2060
# episode: 91, score: -1481.0, avg score: -1481.0, time_steps: 41704, learning steps: 2085
# episode: 92, score: -1481.0, avg score: -1481.0, time_steps: 42198, learning steps: 2109
# episode: 93, score: -1481.0, avg score: -1481.0, time_steps: 42692, learning steps: 2134
# episode: 94, score: -1481.0, avg score: -1481.0, time_steps: 43186, learning steps: 2159
# episode: 95, score: -1481.0, avg score: -1481.0, time_steps: 43680, learning steps: 2184
# episode: 96, score: -1481.0, avg score: -1481.0, time_steps: 44174, learning steps: 2208
# episode: 97, score: -1481.0, avg score: -1481.0, time_steps: 44668, learning steps: 2233
# episode: 98, score: -1481.0, avg score: -1481.0, time_steps: 45162, learning steps: 2258
# episode: 99, score: -1481.0, avg score: -1481.0, time_steps: 45656, learning steps: 2282
# episode: 100, score: -1481.0, avg score: -1481.0, time_steps: 46150, learning steps: 2307
# episode: 101, score: -1481.0, avg score: -1481.0, time_steps: 46644, learning steps: 2332
# episode: 102, score: -1481.0, avg score: -1481.0, time_steps: 47138, learning steps: 2356
# episode: 103, score: -1481.0, avg score: -1481.0, time_steps: 47632, learning steps: 2381
# episode: 104, score: -1481.0, avg score: -1481.0, time_steps: 48126, learning steps: 2406
# episode: 105, score: -1481.0, avg score: -1481.0, time_steps: 48620, learning steps: 2431
# episode: 106, score: -1481.0, avg score: -1481.0, time_steps: 49114, learning steps: 2455
# episode: 107, score: -1481.0, avg score: -1481.0, time_steps: 49608, learning steps: 2480
# episode: 108, score: -1481.0, avg score: -1481.0, time_steps: 50102, learning steps: 2505
# episode: 109, score: -1481.0, avg score: -1481.0, time_steps: 50596, learning steps: 2529
# episode: 110, score: -1481.0, avg score: -1481.0, time_steps: 51090, learning steps: 2554
# episode: 111, score: -1481.0, avg score: -1481.0, time_steps: 51584, learning steps: 2579
# episode: 112, score: -1481.0, avg score: -1481.0, time_steps: 52078, learning steps: 2603
# episode: 113, score: -1481.0, avg score: -1481.0, time_steps: 52572, learning steps: 2628
# episode: 114, score: -1481.0, avg score: -1481.0, time_steps: 53066, learning steps: 2653
# episode: 115, score: -1481.0, avg score: -1481.0, time_steps: 53560, learning steps: 2678
# episode: 116, score: -1481.0, avg score: -1481.0, time_steps: 54054, learning steps: 2702
# episode: 117, score: -1481.0, avg score: -1481.0, time_steps: 54548, learning steps: 2727
# episode: 118, score: -1481.0, avg score: -1481.0, time_steps: 55042, learning steps: 2752
# episode: 119, score: -1439.206673309796, avg score: -1480.1641334661958, time_steps: 55536, learning steps: 2776
# episode: 120, score: 8435655.45901444, avg score: 167262.5650468226, time_steps: 56030, learning steps: 2801
# episode: 121, score: 3803935.56573059, avg score: 243370.8963614344, time_steps: 56524, learning steps: 2826
# episode: 122, score: 2085929.6911176988, avg score: 285119.1101837884, time_steps: 57018, learning steps: 2850
# episode: 123, score: 658615.2414193762, avg score: 298321.0350121759, time_steps: 57512, learning steps: 2875
# episode: 124, score: 20146.752726211213, avg score: 298753.5900667001, time_steps: 58006, learning steps: 2900
# episode: 125, score: 1026987.8983009238, avg score: 319322.9680327186, time_steps: 58500, learning steps: 2925
# episode: 126, score: 3702841.4835434323, avg score: 393409.41770358727, time_steps: 58994, learning steps: 2949
# episode: 127, score: 365027.2576031337, avg score: 400739.58285565, time_steps: 59488, learning steps: 2974
# episode: 128, score: 46066711343.36293, avg score: 921734996.0701143, time_steps: 59982, learning steps: 2999
# ... saving models ...
# episode: 129, score: 1.2913779830023356e+16, avg score: 258276518335492.8, time_steps: 60476, learning steps: 3023
# ... saving models ...
# episode: 130, score: 24664969379.58967, avg score: 258277011634910.03, time_steps: 60970, learning steps: 3048
# ... saving models ...
# episode: 131, score: 221856261920081.62, avg score: 262714136873341.28, time_steps: 61464, learning steps: 3073
# ... saving models ...
# episode: 132, score: 1.3707679942643316e+16, avg score: 536867735726237.25, time_steps: 61958, learning steps: 3097
# ... saving models ...
# episode: 133, score: 4.471359891902132e+17, avg score: 9479587519530530.0, time_steps: 62452, learning steps: 3122
# ... saving models ...
# episode: 134, score: 5.495457667047598e+17, avg score: 2.0470502853625756e+16, time_steps: 62946, learning steps: 3147
# ... saving models ...
# episode: 135, score: 2.657525138023694e+18, avg score: 7.362100561409966e+16, time_steps: 63440, learning steps: 3172
# ... saving models ...
# episode: 136, score: 2.5086397234443423e+18, avg score: 1.2379380008298654e+17, time_steps: 63934, learning steps: 3196
# ... saving models ...
# episode: 137, score: 2.375551620033259e+18, avg score: 1.7130483248365174e+17, time_steps: 64428, learning steps: 3221
# ... saving models ...
# episode: 138, score: 3.3442766248344435e+17, avg score: 1.7799338573332067e+17, time_steps: 64922, learning steps: 3246
# ... saving models ...
# episode: 139, score: 2.147207014545708e+18, avg score: 2.2093752602423485e+17, time_steps: 65416, learning steps: 3270
# ... saving models ...
# episode: 140, score: 21894535.608681876, avg score: 2.2093752602467274e+17, time_steps: 65910, learning steps: 3295
# ... saving models ...
# episode: 141, score: 86417998.53531738, avg score: 2.2093752602640118e+17, time_steps: 66404, learning steps: 3320
# ... saving models ...
# episode: 142, score: 82683355.63891408, avg score: 2.2093752602805485e+17, time_steps: 66898, learning steps: 3344
# ... saving models ...
# episode: 143, score: 79258136.62348376, avg score: 2.2093752602964006e+17, time_steps: 67392, learning steps: 3369
# ... saving models ...
# episode: 144, score: 592847270.4473344, avg score: 2.20937526041497e+17, time_steps: 67886, learning steps: 3394
# ... saving models ...
# episode: 145, score: 1347117389048.5, avg score: 2.2093755298384483e+17, time_steps: 68380, learning steps: 3419
# ... saving models ...
# episode: 146, score: 40232774902.27927, avg score: 2.209375537885004e+17, time_steps: 68874, learning steps: 3443
# ... saving models ...
# episode: 147, score: 529892756.59452224, avg score: 2.2093755379909827e+17, time_steps: 69368, learning steps: 3468
# ... saving models ...
# episode: 148, score: 511700134.4715787, avg score: 2.2093755380933232e+17, time_steps: 69862, learning steps: 3493
# ... saving models ...
# episode: 149, score: 494715256.4116844, avg score: 2.209375538192266e+17, time_steps: 70356, learning steps: 3517
# ... saving models ...
# episode: 150, score: 470283723.37088317, avg score: 2.209375538286323e+17, time_steps: 70850, learning steps: 3542
# ... saving models ...
# episode: 151, score: 455582451.8978233, avg score: 2.20937553837744e+17, time_steps: 71344, learning steps: 3567
# ... saving models ...
# episode: 152, score: 430763228461.934, avg score: 2.2093756245300858e+17, time_steps: 71838, learning steps: 3591
# ... saving models ...
# episode: 153, score: 8747164509.677126, avg score: 2.209375626279519e+17, time_steps: 72332, learning steps: 3616
# ... saving models ...
# episode: 154, score: 8497106886.878679, avg score: 2.2093756279789405e+17, time_steps: 72826, learning steps: 3641
# ... saving models ...
# episode: 155, score: 3202009444.6242514, avg score: 2.209375628619343e+17, time_steps: 73320, learning steps: 3666
# ... saving models ...
# episode: 156, score: 401249808.20453477, avg score: 2.209375628699593e+17, time_steps: 73814, learning steps: 3690
# ... saving models ...
# episode: 157, score: 390730604.4363306, avg score: 2.2093756287777395e+17, time_steps: 74308, learning steps: 3715
# ... saving models ...
# episode: 158, score: 373957191.4931141, avg score: 2.2093756288525312e+17, time_steps: 74802, learning steps: 3740
# ... saving models ...
# episode: 159, score: 371223666.425005, avg score: 2.2093756289267766e+17, time_steps: 75296, learning steps: 3764
# ... saving models ...
# episode: 160, score: 355740925.81041837, avg score: 2.209375628997925e+17, time_steps: 75790, learning steps: 3789
# ... saving models ...
# episode: 161, score: 347264339.3240188, avg score: 2.2093756290673782e+17, time_steps: 76284, learning steps: 3814
# ... saving models ...
# episode: 162, score: 2681390723.0152826, avg score: 2.2093756296036566e+17, time_steps: 76778, learning steps: 3838
# ... saving models ...
# episode: 163, score: 128487101.4097498, avg score: 2.2093756296293542e+17, time_steps: 77272, learning steps: 3863
# ... saving models ...
# episode: 164, score: 2562143211.030585, avg score: 2.2093756301417834e+17, time_steps: 77766, learning steps: 3888
# ... saving models ...
# episode: 165, score: 120710630.58073255, avg score: 2.2093756301659254e+17, time_steps: 78260, learning steps: 3913
# ... saving models ...
# episode: 166, score: 120269647.32653931, avg score: 2.20937563018998e+17, time_steps: 78754, learning steps: 3937
# ... saving models ...
# episode: 167, score: 115667387.35591091, avg score: 2.2093756302131136e+17, time_steps: 79248, learning steps: 3962
# ... saving models ...
# episode: 168, score: 113295488.19384462, avg score: 2.2093756302357728e+17, time_steps: 79742, learning steps: 3987
# ... saving models ...
# episode: 169, score: 113030196.30549234, avg score: 2.2093756302583795e+17, time_steps: 80236, learning steps: 4011
# ... saving models ...
# episode: 170, score: 110813266.20783202, avg score: 2.209375630278855e+17, time_steps: 80730, learning steps: 4036
# ... saving models ...
# episode: 171, score: 108681627.42796887, avg score: 2.2093756302998304e+17, time_steps: 81224, learning steps: 4061
# ... saving models ...
# episode: 172, score: 106630450.76946858, avg score: 2.2093756303207392e+17, time_steps: 81718, learning steps: 4085
# ... saving models ...
# episode: 173, score: 104655264.85563654, avg score: 2.2093756303415386e+17, time_steps: 82212, learning steps: 4110
# ... saving models ...
# episode: 174, score: 102751923.59132878, avg score: 2.209375630362085e+17, time_steps: 82706, learning steps: 4135
# ... saving models ...
# episode: 175, score: 100916577.11196418, avg score: 2.2093756303820627e+17, time_steps: 83200, learning steps: 4160
# ... saving models ...
# episode: 176, score: 99145645.79136774, avg score: 2.2093756304011514e+17, time_steps: 83694, learning steps: 4184
# ... saving models ...
# episode: 177, score: 12520605.72558921, avg score: 2.2093756304035827e+17, time_steps: 84188, learning steps: 4209
# episode: 178, score: 12308335.146379119, avg score: 2.2093756211927024e+17, time_steps: 84682, learning steps: 4234
# episode: 179, score: 116266566.62851034, avg score: 2.2067928652499504e+17, time_steps: 85176, learning steps: 4258
# episode: 180, score: 8054986.571234973, avg score: 2.2067928603185677e+17, time_steps: 85670, learning steps: 4283
# episode: 181, score: 173471522.98593664, avg score: 2.206748489100878e+17, time_steps: 86164, learning steps: 4308
# episode: 182, score: 461121544.9326991, avg score: 2.2040069532045738e+17, time_steps: 86658, learning steps: 4332
# episode: 183, score: 694797161.7555531, avg score: 2.1145797555054902e+17, time_steps: 87152, learning steps: 4357
# episode: 184, score: 11176430.774067301, avg score: 2.0046706021667734e+17, time_steps: 87646, learning steps: 4382
# episode: 185, score: 51972869194.90222, avg score: 1.473165584956609e+17, time_steps: 88140, learning steps: 4407
# episode: 186, score: 2455929773695.5005, avg score: 9.714381314536954e+16, time_steps: 88634, learning steps: 4431
# episode: 187, score: 3955.315761593816, avg score: 4.963278074470442e+16, time_steps: 89128, learning steps: 4456
# episode: 188, score: 3952.570961675703, avg score: 4.294422749503561e+16, time_steps: 89622, learning steps: 4481
# episode: 189, score: 3807.0536616268137, avg score: 87204121526.20049, time_steps: 90116, learning steps: 4505
# episode: 190, score: 4076.787854499215, avg score: 87203683717.02406, time_steps: 90610, learning steps: 4530
# episode: 191, score: 4226.194731068772, avg score: 87201955441.57726, time_steps: 91104, learning steps: 4555
# episode: 192, score: 3942.2309568303217, avg score: 87200301853.30908, time_steps: 91598, learning steps: 4579
# episode: 193, score: 3939.501610158985, avg score: 87198716769.36665, time_steps: 92092, learning steps: 4604
# episode: 194, score: 3936.7754813698016, avg score: 87186859902.6932, time_steps: 92586, learning steps: 4629
# episode: 195, score: 3934.052564775352, avg score: 60244512200.40427, time_steps: 93080, learning steps: 4654
# episode: 196, score: 4211.736135013753, avg score: 59439856786.5934, time_steps: 93574, learning steps: 4678
# episode: 197, score: 4057.47127601872, avg score: 59429259012.61094, time_steps: 94068, learning steps: 4703
# episode: 198, score: 4054.990216629316, avg score: 59419025091.02131, time_steps: 94562, learning steps: 4728
# episode: 199, score: 3781.802882804928, avg score: 59409130861.52913, time_steps: 95056, learning steps: 4752
