# %% [markdown]
# ### Imports

# %%
# Remove unwanted warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data extraction and management
import polars as pl
import numpy as np
import yfinance as yf

# Feature Engineering
from sklearn.preprocessing import StandardScaler

# Machine Learning
from sklearn.cluster import KMeans
from sklearn import metrics
from kneed import KneeLocator

# Cointegration and Statistics
from statsmodels.tsa.stattools import coint
import statsmodels.api as sm

# Reporting visualization
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %% [markdown]
# ## Data Extraction

# %%
# Set Data Extraction parameters for trading with Polars
start_date = "2019-01-01"  # Start date for historical data
end_date = "2024-06-01"    # End date for historical data (adjust as needed)

# File paths for storing and retrieving data
file_name = "data/raw_data_etf.csv"  # Path for ETF data
file_name_coint = "data/raw_data_coint_pairs.csv"  # Path for cointegrated pairs data

# Flags for data loading
load_existing = True     # Set to True to load existing ETF data from file
load_coint_pairs = False   # Set to True to load existing cointegrated pairs data

# Note: When using Polars for trading:
# - Ensure date parsing is handled correctly when reading/writing CSV files
# - Consider using Polars' memory-efficient data types for large datasets
# - Leverage Polars' fast I/O operations for reading/writing data
# - Utilize Polars' vectorized operations for quick data manipulations

# %% [markdown]
# ### Get Symbols

# %%
import yfinance as yf  # Import the yfinance library for financial data
import polars as pl    # Import the Polars library for DataFrame operations
import pandas as pd    # Import the pandas library for data manipulation

# Variable to determine whether to load existing data or fetch new data
load_existing = True

# Function to fetch NASDAQ symbols
def get_nasdaq_symbols():
    # URL of the NASDAQ listed symbols file
    url = 'ftp://ftp.nasdaqtrader.com/SymbolDirectory/nasdaqlisted.txt'
    # Read the symbols data from the URL using pandas
    symbols = pd.read_csv(url, sep='|')
    # Drop rows with any missing values
    symbols = symbols.dropna()
    # Set the 'Symbol' column as the index of the DataFrame
    symbols.set_index('Symbol', inplace=True)
    # Return the DataFrame containing the symbols
    return symbols

# Function to load existing symbols from a file
def load_existing_symbols(file_path):
    # Read the symbols from a CSV file
    existing_symbols = pd.read_csv(file_path)
    # Set the 'Symbol' column as the index of the DataFrame
    existing_symbols.set_index('Symbol', inplace=True)
    # Return the DataFrame containing the existing symbols
    return existing_symbols

# Path to the file where existing symbols are stored
existing_symbols_file = 'data/existing_symbols.csv'

# Check if we should load existing data or fetch new data
if load_existing:
    # Load existing symbols from the file
    existing_symbols = load_existing_symbols(existing_symbols_file)
    # Ensure symbols variable is defined when loading existing data
    symbols = existing_symbols.copy()
else:
    # Fetch the NASDAQ symbols using the defined function
    symbols = get_nasdaq_symbols()
    # Filter the symbols to include only those that are ETFs (ETF == 'Y') and belong to the NASDAQ Global Market (Market Category == 'G')
    symbols = symbols[(symbols['ETF'] == 'Y') & (symbols['Market Category'] == 'G')]
    # Convert the filtered symbols DataFrame index to a list of symbol strings
    new_symbols = list(symbols.index.values)

    # Compare new symbols with existing symbols (if they exist)
    try:
        existing_symbols = load_existing_symbols(existing_symbols_file)
        existing_symbols_list = list(existing_symbols.index.values)

        if new_symbols != existing_symbols_list:
            # If there are new or updated symbols, replace the existing symbols
            symbols.to_csv(existing_symbols_file)
            print("Symbols updated.")
        else:
            print("No new symbols.")
    except FileNotFoundError:
        # If the existing symbols file does not exist, save the new symbols
        symbols.to_csv(existing_symbols_file)
        print("Symbols saved.")

    # Print the list of new symbols
    print(new_symbols)

# Print the length of the symbols DataFrame
print(len(symbols))
# Out:
# 644

# %%
print(len(symbols))
# Out:
# 644

# %%
import yfinance as yf  
import pandas as pd   

# Ensure symbols is a list of strings, somehow errored because it was not in string format
if isinstance(symbols, pd.DataFrame):
    symbols = symbols.index.tolist()

# Fetch adjusted close prices for the symbols from Yahoo Finance
data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Save the data to a CSV file
data.to_csv(file_name)

print(f"Data saved to {file_name}")
# Out:
# [*********************100%%**********************]  644 of 644 completed
# 19 Failed downloads:
# ['BSCY', 'BGRO', 'METD', 'BMDL', 'METU', 'IBGA', 'EVSD', 'QQQT', 'BELT', 'AIPI', 'BSJW', 'QXQ', 'IBTP', 'IBGK', 'GLOW', 'FCTE', 'QBUF', 'BRHY', 'TMET']: Exception("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1717214400")
# Data saved to data/raw_data_etf.csv

# %%
import polars as pl

# Load (or re-load for consistency) Data and remove features with NaN's
data = pl.read_csv(file_name)

# Filter columns that have all null values
data = data.filter(~pl.all_horizontal(pl.all().is_null()))

# Replace null values with zero for each column explicitly
data = data.with_columns(
    [pl.col(column).fill_null(0) for column in data.columns]
)

# Print the shape of the dataset
print("Shape:", data.shape)

# Check for any null values and print a boolean
has_null_values = data.null_count().sum_horizontal().sum() > 0
print("Null Values:", has_null_values)

# Display the first 50 rows to verify
data
# Out:
# Shape: (1363, 645)
# Null Values: False
# shape: (1_363, 645)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Date      ┆ AADR      ┆ AAPB      ┆ AAPD      ┆ … ┆ XFIX      ┆ XT        ┆ YLDE      ┆ ZZZ      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ f64       ┆ str       ┆ str       ┆   ┆ str       ┆ f64       ┆ f64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2019-01-0 ┆ 37.611721 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 31.699696 ┆ 23.76158  ┆ 0        │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 37.192055 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 30.861734 ┆ 23.422531 ┆ 0        │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 38.637581 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 31.918711 ┆ 23.999846 ┆ 0        │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.094551 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 32.404346 ┆ 24.228943 ┆ 0        │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.365002 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 32.585262 ┆ 24.250931 ┆ 0        │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2024-05-2 ┆ 63.126698 ┆ 20.989999 ┆ 20.237186 ┆ … ┆ 50.850383 ┆ 59.230984 ┆ 46.30584  ┆ 24.38761 │
# │ 4         ┆           ┆ 771118164 ┆ 431884766 ┆   ┆ 75854492  ┆           ┆           ┆ 32965087 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 9        │
# │ 2024-05-2 ┆ 63.562946 ┆ 21.030000 ┆ 20.237186 ┆ … ┆ 50.657886 ┆ 59.320744 ┆ 46.065861 ┆ 24.31945 │
# │ 8         ┆           ┆ 686645508 ┆ 431884766 ┆   ┆ 50512695  ┆           ┆           ┆ 03784179 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 7        │
# │ 2024-05-2 ┆ 63.414223 ┆ 21.110000 ┆ 20.227298 ┆ … ┆ 50.490547 ┆ 58.433125 ┆ 45.606804 ┆ 24.15015 │
# │ 9         ┆           ┆ 610351562 ┆ 736572266 ┆   ┆ 18017578  ┆           ┆           ┆ 60211181 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 64       │
# │ 2024-05-3 ┆ 64.256973 ┆ 21.319999 ┆ 20.123493 ┆ … ┆ 50.710391 ┆ 58.094036 ┆ 45.859734 ┆ 24.16814 │
# │ 0         ┆           ┆ 69482422  ┆ 194580078 ┆   ┆ 998291016 ┆           ┆           ┆ 61334228 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 5        │
# │ 2024-05-3 ┆ 64.237144 ┆ 21.489999 ┆ 20.029575 ┆ … ┆ 50.955303 ┆ 57.934464 ┆ 46.511967 ┆ 24.19245 │
# │ 1         ┆           ┆ 771118164 ┆ 34790039  ┆   ┆ 19213867  ┆           ┆           ┆ 52917480 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 47       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Data Clean up

# %%
import polars as pl

def clean_data(df):
    # Function to try converting to float
    def try_float(s):
        try:
            return float(s)
        except ValueError:
            return s  # Return the original value if it can't be converted

    # Identify columns that are strings
    string_cols = [col for col, dtype in df.schema.items() if dtype == pl.String]
    
    for col in string_cols:
        # Try to convert the column to float
        df = df.with_columns(pl.col(col).apply(try_float))
        
        # Check if all values in the column are now float
        if df[col].dtype == pl.Float64:
            print(f"Column {col} successfully converted to Float64.")
        else:
            print(f"Column {col} contains non-numeric values and will remain as its original type.")

    return df

# Clean the data
cleaned_data = clean_data(data)

# Print schema to verify changes
print("\nUpdated Schema:")
print(cleaned_data.schema)

# Print the first few rows of the cleaned data
print("\nFirst few rows of cleaned data:")
print(cleaned_data.head())

# Count of float columns
float_cols = [col for col, dtype in cleaned_data.schema.items() if dtype == pl.Float64]
print(f"\nNumber of Float64 columns: {len(float_cols)}")
# Out:
# Column Date contains non-numeric values and will remain as its original type.
# Column AAPB successfully converted to Float64.
# Column AAPD successfully converted to Float64.
# Column AAPU successfully converted to Float64.
# Column ABCS successfully converted to Float64.
# Column AGMI successfully converted to Float64.
# Column AIPI successfully converted to Float64.
# Column AIRL successfully converted to Float64.
# Column AMDL successfully converted to Float64.
# Column AMDS successfully converted to Float64.
# Column AMID successfully converted to Float64.
# Column AMZD successfully converted to Float64.
# Column AMZU successfully converted to Float64.
# Column AMZZ successfully converted to Float64.
# Column AOTG successfully converted to Float64.
# Column AQWA successfully converted to Float64.
# Column ARVR successfully converted to Float64.
# Column AUMI successfully converted to Float64.
# Column AVXC successfully converted to Float64.
# Column BABX successfully converted to Float64.
# Column BDGS successfully converted to Float64.
# Column BEEZ successfully converted to Float64.
# Column BELT successfully converted to Float64.
# Column BGRO successfully converted to Float64.
# Column BITS successfully converted to Float64.
# Column BKCH successfully converted to Float64.
# Column BKIV successfully converted to Float64.
# Column BKWO successfully converted to Float64.
# Column BLCR successfully converted to Float64.
# Column BLLD successfully converted to Float64.
# Column BMDL successfully converted to Float64.
# Column BOTT successfully converted to Float64.
# Column BRHY successfully converted to Float64.
# Column BRNY successfully converted to Float64.
# Column BRRR successfully converted to Float64.
# Column BRTR successfully converted to Float64.
# Column BSCT successfully converted to Float64.
# Column BSCU successfully converted to Float64.
# Column BSCV successfully converted to Float64.
# Column BSCW successfully converted to Float64.
# Column BSCX successfully converted to Float64.
# Column BSCY successfully converted to Float64.
# Column BSJR successfully converted to Float64.
# Column BSJS successfully converted to Float64.
# Column BSJT successfully converted to Float64.
# Column BSJU successfully converted to Float64.
# Column BSJV successfully converted to Float64.
# Column BSJW successfully converted to Float64.
# Column BSMO successfully converted to Float64.
# Column BSMP successfully converted to Float64.
# Column BSMQ successfully converted to Float64.
# Column BSMR successfully converted to Float64.
# Column BSMS successfully converted to Float64.
# Column BSMT successfully converted to Float64.
# Column BSMU successfully converted to Float64.
# Column BSMV successfully converted to Float64.
# Column BSMW successfully converted to Float64.
# Column BSSX successfully converted to Float64.
# Column BSVO successfully converted to Float64.
# Column BTF successfully converted to Float64.
# Column BTFX successfully converted to Float64.
# Column BUFC successfully converted to Float64.
# Column BUG successfully converted to Float64.
# Column BULD successfully converted to Float64.
# Column CA successfully converted to Float64.
# Column CAFG successfully converted to Float64.
# Column CALY successfully converted to Float64.
# Column CANC successfully converted to Float64.
# Column CANQ successfully converted to Float64.
# Column CCSB successfully converted to Float64.
# Column CCSO successfully converted to Float64.
# Column CEFA successfully converted to Float64.
# Column CHPS successfully converted to Float64.
# Column CLOA successfully converted to Float64.
# Column CLOD successfully converted to Float64.
# Column CLSM successfully converted to Float64.
# Column CONL successfully converted to Float64.
# Column COPJ successfully converted to Float64.
# Column COPP successfully converted to Float64.
# Column COWG successfully converted to Float64.
# Column COWS successfully converted to Float64.
# Column CPLS successfully converted to Float64.
# Column CTEC successfully converted to Float64.
# Column CZAR successfully converted to Float64.
# Column DAPP successfully converted to Float64.
# Column DEMZ successfully converted to Float64.
# Column DFGP successfully converted to Float64.
# Column DFGX successfully converted to Float64.
# Column DGCB successfully converted to Float64.
# Column DIVD successfully converted to Float64.
# Column DMAT successfully converted to Float64.
# Column DMXF successfully converted to Float64.
# Column DTCR successfully converted to Float64.
# Column DVAL successfully converted to Float64.
# Column DWAW successfully converted to Float64.
# Column DWUS successfully converted to Float64.
# Column DYFI successfully converted to Float64.
# Column DYNI successfully converted to Float64.
# Column DYTA successfully converted to Float64.
# Column EDOC successfully converted to Float64.
# Column EFRA successfully converted to Float64.
# Column EHLS successfully converted to Float64.
# Column EKG successfully converted to Float64.
# Column EMXF successfully converted to Float64.
# Column ERET successfully converted to Float64.
# Column ERNZ successfully converted to Float64.
# Column ESMV successfully converted to Float64.
# Column ETEC successfully converted to Float64.
# Column EVMT successfully converted to Float64.
# Column EVSD successfully converted to Float64.
# Column EYEG successfully converted to Float64.
# Column FBL successfully converted to Float64.
# Column FBOT successfully converted to Float64.
# Column FCTE successfully converted to Float64.
# Column FDCF successfully converted to Float64.
# Column FDFF successfully converted to Float64.
# Column FDIF successfully converted to Float64.
# Column FDIG successfully converted to Float64.
# Column FDIV successfully converted to Float64.
# Column FDTX successfully converted to Float64.
# Column FEPI successfully converted to Float64.
# Column FICS successfully converted to Float64.
# Column FINE successfully converted to Float64.
# Column FIXT successfully converted to Float64.
# Column FLDB successfully converted to Float64.
# Column FMED successfully converted to Float64.
# Column FMET successfully converted to Float64.
# Column FTGS successfully converted to Float64.
# Column GFGF successfully converted to Float64.
# Column GGLL successfully converted to Float64.
# Column GGLS successfully converted to Float64.
# Column GINX successfully converted to Float64.
# Column GLOW successfully converted to Float64.
# Column GPIQ successfully converted to Float64.
# Column GPIX successfully converted to Float64.
# Column GSIB successfully converted to Float64.
# Column GTR successfully converted to Float64.
# Column GXTG successfully converted to Float64.
# Column HCOW successfully converted to Float64.
# Column HERO successfully converted to Float64.
# Column HIDE successfully converted to Float64.
# Column HLAL successfully converted to Float64.
# Column HQGO successfully converted to Float64.
# Column HRTS successfully converted to Float64.
# Column HYDR successfully converted to Float64.
# Column IBAT successfully converted to Float64.
# Column IBBQ successfully converted to Float64.
# Column IBGA successfully converted to Float64.
# Column IBGK successfully converted to Float64.
# Column IBIT successfully converted to Float64.
# Column IBOT successfully converted to Float64.
# Column IBTE successfully converted to Float64.
# Column IBTF successfully converted to Float64.
# Column IBTG successfully converted to Float64.
# Column IBTH successfully converted to Float64.
# Column IBTI successfully converted to Float64.
# Column IBTJ successfully converted to Float64.
# Column IBTK successfully converted to Float64.
# Column IBTL successfully converted to Float64.
# Column IBTM successfully converted to Float64.
# Column IBTO successfully converted to Float64.
# Column IBTP successfully converted to Float64.
# Column ICOP successfully converted to Float64.
# Column IHYF successfully converted to Float64.
# Column ILIT successfully converted to Float64.
# Column INDH successfully converted to Float64.
# Column INFR successfully converted to Float64.
# Column INRO successfully converted to Float64.
# Column IQQQ successfully converted to Float64.
# Column IVEG successfully converted to Float64.
# Column IWTR successfully converted to Float64.
# Column JDOC successfully converted to Float64.
# Column JEPQ successfully converted to Float64.
# Column JGLO successfully converted to Float64.
# Column JIVE successfully converted to Float64.
# Column JPEF successfully converted to Float64.
# Column JTEK successfully converted to Float64.
# Column KEAT successfully converted to Float64.
# Column KROP successfully converted to Float64.
# Column LDEM successfully converted to Float64.
# Column LGRO successfully converted to Float64.
# Column LITP successfully converted to Float64.
# Column LRND successfully converted to Float64.
# Column MAGQ successfully converted to Float64.
# Column MAGS successfully converted to Float64.
# Column MAGX successfully converted to Float64.
# Column MAXI successfully converted to Float64.
# Column MCHS successfully converted to Float64.
# Column MCSE successfully converted to Float64.
# Column MDCP successfully converted to Float64.
# Column MEDX successfully converted to Float64.
# Column MEMS successfully converted to Float64.
# Column METD successfully converted to Float64.
# Column METU successfully converted to Float64.
# Column MKAM successfully converted to Float64.
# Column MNTL successfully converted to Float64.
# Column MODL successfully converted to Float64.
# Column MOOD successfully converted to Float64.
# Column MSFD successfully converted to Float64.
# Column MSFL successfully converted to Float64.
# Column MSFU successfully converted to Float64.
# Column NCPB successfully converted to Float64.
# Column NERD successfully converted to Float64.
# Column NEWZ successfully converted to Float64.
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# ...
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))

# %%
cleaned_data
# Out:
# shape: (1_363, 645)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Date      ┆ AADR      ┆ AAPB      ┆ AAPD      ┆ … ┆ XFIX      ┆ XT        ┆ YLDE      ┆ ZZZ      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2019-01-0 ┆ 37.611721 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 31.699696 ┆ 23.76158  ┆ 0.0      │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 37.192055 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 30.861734 ┆ 23.422531 ┆ 0.0      │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 38.637581 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 31.918711 ┆ 23.999846 ┆ 0.0      │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.094551 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 32.404346 ┆ 24.228943 ┆ 0.0      │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.365002 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 32.585262 ┆ 24.250931 ┆ 0.0      │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2024-05-2 ┆ 63.126698 ┆ 20.99     ┆ 20.237186 ┆ … ┆ 50.850384 ┆ 59.230984 ┆ 46.30584  ┆ 24.38761 │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 3        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-2 ┆ 63.562946 ┆ 21.030001 ┆ 20.237186 ┆ … ┆ 50.657887 ┆ 59.320744 ┆ 46.065861 ┆ 24.31945 │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-2 ┆ 63.414223 ┆ 21.110001 ┆ 20.227299 ┆ … ┆ 50.490547 ┆ 58.433125 ┆ 45.606804 ┆ 24.15015 │
# │ 9         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-3 ┆ 64.256973 ┆ 21.32     ┆ 20.123493 ┆ … ┆ 50.710392 ┆ 58.094036 ┆ 45.859734 ┆ 24.16814 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-3 ┆ 64.237144 ┆ 21.49     ┆ 20.029575 ┆ … ┆ 50.955303 ┆ 57.934464 ┆ 46.511967 ┆ 24.19245 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 5        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Feature Engineering

# %%
# import polars as pl
# import numpy as np

# # Assuming 'cleaned_data' is your DataFrame
# float_columns = [col for col, dtype in zip(cleaned_data.columns, cleaned_data.dtypes) if dtype == pl.Float64 and col != 'Date']

# # Calculate percentage change, mean returns, and volatility for each column
# returns = []
# volatility = []
# for col in float_columns:
#     pct_change = cleaned_data.select(pl.col(col)).with_columns(pl.col(col).pct_change().alias("pct_change"))
#     returns.append(pct_change.select(pl.mean("pct_change")).to_numpy()[0, 0] * 255)  # Annualized return
#     volatility.append(pct_change.select(pl.std("pct_change")).to_numpy()[0, 0] * np.sqrt(255))  # Annualized volatility

# # Create DataFrame with Returns and Volatility information
# df_returns = pl.DataFrame({
#     'ETF': float_columns,
#     'Returns': returns,
#     'Volatility': volatility
# })

# print("DataFrame with Returns and Volatility:")
# print(df_returns.tail())

# %%
import yfinance as yf

data_pd = yf.download(symbols, start=start_date, end=end_date)['Adj Close']
print(data_pd.head())
# Out:
# [*********************100%%**********************]  644 of 644 completed
# 19 Failed downloads:
# ['BSCY', 'BGRO', 'METD', 'BMDL', 'METU', 'IBGA', 'EVSD', 'QQQT', 'BELT', 'AIPI', 'BSJW', 'QXQ', 'IBTP', 'IBGK', 'GLOW', 'FCTE', 'QBUF', 'BRHY', 'TMET']: Exception("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1717214400")
#                           AADR  AAPB  AAPD  AAPU       AAXJ  ABCS       ACWI  \
# Date
# 2019-01-02 00:00:00  37.611721   NaN   NaN   NaN  57.365265   NaN  57.852905
# 2019-01-03 00:00:00  37.192051   NaN   NaN   NaN  56.010464   NaN  56.869751
# 2019-01-04 00:00:00  38.637577   NaN   NaN   NaN  57.856270   NaN  58.682728
# 2019-01-07 00:00:00  39.094551   NaN   NaN   NaN  58.201790   NaN  59.043514
# 2019-01-08 00:00:00  39.365005   NaN   NaN   NaN  58.356365   NaN  59.476475
#
#                           ACWX  AGMI       AGNG  ...  WISE  WNDY       WOOD  \
# Date                                             ...
# 2019-01-02 00:00:00  35.929512   NaN  18.078400  ...   NaN   NaN  51.865036
# 2019-01-03 00:00:00  35.594364   NaN  18.043736  ...   NaN   NaN  51.638748
# 2019-01-04 00:00:00  36.694340   NaN  18.670584  ...   NaN   NaN  53.449051
# 2019-01-07 00:00:00  36.745895   NaN  19.003746  ...   NaN   NaN  53.783958
# 2019-01-08 00:00:00  36.986519   NaN  19.028780  ...   NaN   NaN  54.290848
#
#                      WRND  WTBN  XBIL  XFIX         XT       YLDE  ZZZ
# Date
# 2019-01-02 00:00:00   NaN   NaN   NaN   NaN  31.699694  23.761587  NaN
# 2019-01-03 00:00:00   NaN   NaN   NaN   NaN  30.861729  23.422527  NaN
# 2019-01-04 00:00:00   NaN   NaN   NaN   NaN  31.918703  23.999842  NaN
# 2019-01-07 00:00:00   NaN   NaN   NaN   NaN  32.404343  24.228939  NaN
# 2019-01-08 00:00:00   NaN   NaN   NaN   NaN  32.585266  24.250927  NaN
#
# [5 rows x 644 columns]

# %%
# Removing columns with any NaN values
data_pd.dropna(axis=1, inplace=True)

# Checking the shape and null values after cleaning
print("Shape after dropping NaNs: ", data_pd.shape)
print("Null Values after dropping NaNs: ", data_pd.isnull().values.any())
data_pd.head()
# Out:
# Shape after dropping NaNs:  (1363, 308)
# Null Values after dropping NaNs:  False
#                           AADR       AAXJ       ACWI       ACWX       AGNG  \
# Date
# 2019-01-02 00:00:00  37.611721  57.365265  57.852905  35.929512  18.078400
# 2019-01-03 00:00:00  37.192051  56.010464  56.869751  35.594364  18.043736
# 2019-01-04 00:00:00  38.637577  57.856270  58.682728  36.694340  18.670584
# 2019-01-07 00:00:00  39.094551  58.201790  59.043514  36.745895  19.003746
# 2019-01-08 00:00:00  39.365005  58.356365  59.476475  36.986519  19.028780
#
#                           AGZD        AIA        AIQ       AIRR      ALTY  \
# Date
# 2019-01-02 00:00:00  18.813509  49.291370  12.734488  21.639994  8.677717
# 2019-01-03 00:00:00  18.773777  47.861721  12.401688  21.451561  8.691306
# 2019-01-04 00:00:00  18.869135  49.552124  12.900887  22.145788  8.808433
# 2019-01-07 00:00:00  18.809534  49.857830  13.145594  22.502817  8.988332
# 2019-01-08 00:00:00  18.908867  49.722958  13.272840  22.790424  9.078923
#
#                      ...        VTWG       VTWO       VTWV       VWOB  \
# Date                 ...
# 2019-01-02 00:00:00  ...  117.246979  50.260658  84.563370  57.171001
# 2019-01-03 00:00:00  ...  115.129028  49.308140  84.382973  57.323963
# 2019-01-04 00:00:00  ...  119.461143  51.134197  86.574867  57.469265
# 2019-01-07 00:00:00  ...  122.378151  52.096016  87.702362  57.668121
# 2019-01-08 00:00:00  ...  124.361282  52.890553  89.100479  57.668121
#
#                           VXUS       VYMI       WBND       WOOD         XT  \
# Date
# 2019-01-02 00:00:00  40.046909  44.070274  70.805161  51.865036  31.699694
# 2019-01-03 00:00:00  39.596558  43.921253  70.721489  51.638748  30.861729
# 2019-01-04 00:00:00  40.888123  45.160469  70.554176  53.449051  31.918703
# 2019-01-07 00:00:00  41.015579  45.199677  70.916710  53.783958  32.404343
# 2019-01-08 00:00:00  41.312984  45.411446  71.056145  54.290848  32.585266
#
#                           YLDE
# Date
# 2019-01-02 00:00:00  23.761587
# 2019-01-03 00:00:00  23.422527
# 2019-01-04 00:00:00  23.999842
# 2019-01-07 00:00:00  24.228939
# 2019-01-08 00:00:00  24.250927
#
# [5 rows x 308 columns]

# %%
import polars as pl
import numpy as np

# Convert Pandas DataFrame to Polars DataFrame, including resetting the index.
# This is done to convert the Date from the index to a regular column,
# which we don't need for our analysis, thus simplifying the DataFrame structure.
pl_df = pl.from_pandas(data_pd.reset_index())

# Identify columns with floating point data which are typically price data in financial datasets.
# We exclude the 'Date' column because time data is irrelevant for K-means clustering in this context.
# K-means clustering will be used to find patterns in price movements, not time series trends.
float_columns = [col for col, dtype in zip(pl_df.columns, pl_df.dtypes) if isinstance(dtype, pl.Float64) and col != 'Date']

# Initialize lists to store calculated annual returns and volatilities for each stock.
# These metrics are crucial for trading as they provide insights into the risk-return profile of stocks.
returns = []
volatility = []
for col in float_columns:
    # Calculate the percentage change, which is a common financial metric to assess stock performance.
    pct_change = pl_df.select(pl.col(col)).with_columns(pl.col(col).pct_change().alias("pct_change"))
    
    # Calculate and store annualized returns, which normalize returns over a year for comparability.
    # This is crucial for clustering as it standardizes data points, making the K-means algorithm more effective.
    annual_return = pct_change.select(pl.mean("pct_change")).to_numpy() * 255
    returns.append(annual_return[0, 0])  # Extract the scalar from the numpy array
    
    # Calculate and store annualized volatility, a measure of the price variability and thus risk.
    # Higher volatility stocks may cluster differently from lower volatility stocks in K-means.
    annual_volatility = pct_change.select(pl.std("pct_change")).to_numpy() * np.sqrt(255)
    volatility.append(annual_volatility[0, 0])  # Extract the scalar from the numpy array

# Create a new DataFrame containing the returns and volatility of each stock.
# This DataFrame is well-suited for K-means clustering to segment stocks into groups based on their
# risk-return profiles, which can inform investment strategies and risk management.
df_returns = pl.DataFrame({
    'ETF': float_columns,
    'Returns': returns,
    'Volatility': volatility
})

print("DataFrame with Returns and Volatility:")
print(df_returns)
# Out:
# DataFrame with Returns and Volatility:
# shape: (308, 3)
# ┌──────┬───────────┬────────────┐
# │ ETF  ┆ Returns   ┆ Volatility │
# │ ---  ┆ ---       ┆ ---        │
# │ str  ┆ f64       ┆ f64        │
# ╞══════╪═══════════╪════════════╡
# │ AADR ┆ 0.127934  ┆ 0.233967   │
# │ AAXJ ┆ 0.060713  ┆ 0.217516   │
# │ ACWI ┆ 0.139888  ┆ 0.195757   │
# │ ACWX ┆ 0.093164  ┆ 0.194469   │
# │ AGNG ┆ 0.109739  ┆ 0.186009   │
# │ …    ┆ …         ┆ …          │
# │ VYMI ┆ 0.104908  ┆ 0.190829   │
# │ WBND ┆ -0.135238 ┆ 0.320158   │
# │ WOOD ┆ 0.117898  ┆ 0.254531   │
# │ XT   ┆ 0.139008  ┆ 0.227995   │
# │ YLDE ┆ 0.142387  ┆ 0.181442   │
# └──────┴───────────┴────────────┘

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler

# Convert Polars DataFrame to NumPy array for scaling
data_for_scaling = df_returns.select(['Returns', 'Volatility']).to_numpy()

# Initialize and apply StandardScaler
# The scaler adjusts each feature to have zero mean and unit variance,
# which is vital for uniform analysis across different trading instruments,
# ensuring no single asset's characteristics dominate due to scale differences.
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_for_scaling)  # Use the correct data array

# Convert the scaled data back to a Polars DataFrame
# This maintains efficient data operations while ensuring comparability across assets.
scaled_df = pl.DataFrame(scaled_data, schema=['Scaled_Returns', 'Scaled_Volatility'])

# Assuming 'ETF' is a column in the original df_returns you want to keep
df_returns_scaled = df_returns.drop(['Returns', 'Volatility']).with_columns(scaled_df)

# Output the scaled DataFrame
# Scaled features are now ready for clustering or other statistical techniques
# that require standardized input to identify patterns in trading data effectively.
print(df_returns_scaled)

#the goal is to create a scaled version of the original dataframe. However, there are some differences between the code you've shown
#and the original code snippet in the image. Let's break it down:

#The original code uses pandas (pd) and sklearn's StandardScaler, while your code uses polars (pl) and sklearn's StandardScaler.
#The original code scales the entire df_returns dataframe, while your code specifically scales only the 'Returns' and 'Volatility' columns.
#The original code keeps the original column names, while your code renames the scaled columns to 'Scaled_Returns' and 'Scaled_Volatility'.
#The original code preserves the index of df_returns, while the polars approach doesn't explicitly handle the index.
# Out:
# shape: (308, 3)
# ┌──────┬────────────────┬───────────────────┐
# │ ETF  ┆ Scaled_Returns ┆ Scaled_Volatility │
# │ ---  ┆ ---            ┆ ---               │
# │ str  ┆ f64            ┆ f64               │
# ╞══════╪════════════════╪═══════════════════╡
# │ AADR ┆ 0.261166       ┆ 0.194313          │
# │ AAXJ ┆ -0.497125      ┆ 0.030128          │
# │ ACWI ┆ 0.396008       ┆ -0.187025         │
# │ ACWX ┆ -0.131066      ┆ -0.199882         │
# │ AGNG ┆ 0.05591        ┆ -0.284313         │
# │ …    ┆ …              ┆ …                 │
# │ VYMI ┆ 0.001421       ┆ -0.236202         │
# │ WBND ┆ -2.707534      ┆ 1.05449           │
# │ WOOD ┆ 0.147955       ┆ 0.399533          │
# │ XT   ┆ 0.386084       ┆ 0.134713          │
# │ YLDE ┆ 0.424196       ┆ -0.329885         │
# └──────┴────────────────┴───────────────────┘

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler

# Assuming df_returns is your original Polars DataFrame

# Extract numeric columns for scaling
numeric_cols = ['Returns', 'Volatility']
data_for_scaling = df_returns.select(numeric_cols).to_numpy()

# Initialize and apply StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_for_scaling)

# Create a new DataFrame with scaled data
df_scaled = pl.DataFrame(
    scaled_data,
    schema=['Returns', 'Volatility']
)

# Add the ETF column back
df_scaled = df_scaled.with_columns(df_returns['ETF'])

# Reorder columns to match original
df_scaled = df_scaled.select(['ETF', 'Returns', 'Volatility'])

print("Scaled DataFrame:")
print(df_scaled)
# Out:
# Scaled DataFrame:
# shape: (308, 3)
# ┌──────┬───────────┬────────────┐
# │ ETF  ┆ Returns   ┆ Volatility │
# │ ---  ┆ ---       ┆ ---        │
# │ str  ┆ f64       ┆ f64        │
# ╞══════╪═══════════╪════════════╡
# │ AADR ┆ 0.261166  ┆ 0.194313   │
# │ AAXJ ┆ -0.497125 ┆ 0.030128   │
# │ ACWI ┆ 0.396008  ┆ -0.187025  │
# │ ACWX ┆ -0.131066 ┆ -0.199882  │
# │ AGNG ┆ 0.05591   ┆ -0.284313  │
# │ …    ┆ …         ┆ …          │
# │ VYMI ┆ 0.001421  ┆ -0.236202  │
# │ WBND ┆ -2.707534 ┆ 1.05449    │
# │ WOOD ┆ 0.147955  ┆ 0.399533   │
# │ XT   ┆ 0.386084  ┆ 0.134713   │
# │ YLDE ┆ 0.424196  ┆ -0.329885  │
# └──────┴───────────┴────────────┘

# %% [markdown]
# ## K-Means Clustering

# %%
# Find the optimum number of clusters

# %% [markdown]
# In the context of trading and financial analysis, finding the optimal number of clusters when using K-means clustering is crucial for several reasons:
#
# 1. **Segmentation of Financial Instruments**: Trading involves a wide range of financial instruments such as stocks, ETFs, bonds, and derivatives. Clustering these into homogeneous groups helps in understanding their behavior under various economic conditions. For example, stocks in one cluster might behave similarly in response to market changes, economic news, or sector-specific shifts. This insight is vital for portfolio diversification and risk management.
#
# 2. **Tailored Strategies**: Different clusters may warrant different trading strategies. For example, a cluster of high-volatility stocks might be suited for short-term, high-risk trading strategies, while a cluster of stable, low-volatility stocks might be more appropriate for long-term investment strategies. Determining the optimal number of clusters helps in crafting strategies that are well-suited to each group's characteristics.
#
# 3. **Risk Management**: By clustering financial instruments based on features like returns and volatility, traders can identify which groups are more likely to experience large fluctuations. This information is critical for managing risk and determining capital allocation. For instance, a cluster identified as high risk might necessitate a different risk management approach compared to a cluster with low-risk profiles.
#
# 4. **Performance Evaluation**: Clusters can serve as benchmarks to evaluate the performance of individual stocks or assets. By comparing an asset's performance to its cluster's average, traders can assess whether it's underperforming or outperforming its peers.
#
# 5. **Efficient Allocation of Resources**: Clustering can help in the efficient allocation of analytical resources. By identifying clusters, analysts can focus their efforts on analyzing the characteristics of a few groups rather than individual assets. This approach is more scalable and can lead to more focused and effective analysis.
#
# ### Finding the Optimal Number of Clusters
#
# The optimal number of clusters is not inherently clear without analysis and can significantly impact the effectiveness of the clustering in trading. Here are a few common methods used to determine the optimal number of clusters:
#
# - **Elbow Method**: This method involves plotting the sum of squared distances of samples to their closest cluster center and looking for an "elbow" where the rate of decrease sharply shifts. The elbow typically suggests a good balance between the number of clusters and the compactness of the clusters, minimizing within-cluster variance.
#
# - **Silhouette Score**: This measure assesses how similar an object is to its own cluster compared to other clusters. A higher silhouette score indicates that objects are well matched to their own cluster and poorly matched to neighboring clusters. The number of clusters that maximizes the average silhouette score is considered optimal.
#
# - **Gap Statistic**: This method compares the total within intra-cluster variation for different values of k with their expected values under null reference distribution of the data. The optimal k is the one that maximizes the gap statistic, indicating a clustering structure that is significantly away from random uniform distribution of points.
#
# Each of these methods provides a different way to quantitatively assess the number of clusters, helping to inform a decision that could significantly affect trading outcomes based on how well the actual market segments are captured by the model.

# %%
df_scaled.head()
# Out:
# shape: (5, 3)
# ┌──────┬───────────┬────────────┐
# │ ETF  ┆ Returns   ┆ Volatility │
# │ ---  ┆ ---       ┆ ---        │
# │ str  ┆ f64       ┆ f64        │
# ╞══════╪═══════════╪════════════╡
# │ AADR ┆ 0.261166  ┆ 0.194313   │
# │ AAXJ ┆ -0.497125 ┆ 0.030128   │
# │ ACWI ┆ 0.396008  ┆ -0.187025  │
# │ ACWX ┆ -0.131066 ┆ -0.199882  │
# │ AGNG ┆ 0.05591   ┆ -0.284313  │
# └──────┴───────────┴────────────┘

# %%
import polars as pl
from sklearn.cluster import KMeans
from kneed import KneeLocator

# Extract the scaled 'Returns' and 'Volatility' data for clustering
# These are key metrics for analyzing ETF performance
X = df_scaled.select(['Returns', 'Volatility']).to_numpy() 

# Define the range of cluster numbers to test
# We're considering 1 to 15 clusters
K = range(1, 15)

# Initialize list to store distortion values for each K
distortions = []

# Iterate through each potential number of clusters
for k in K:
    # Initialize K-means model with k clusters
    # This will group ETFs based on their risk-return profiles
    kmeans = KMeans(n_clusters=k, random_state=42) # Reproducibility. 
    # Setting a fixed random state ensures that the K-means algorithm starts with the same initial centroids every time you run it.
    # When analyzing different sets of ETFs or time periods, a consistent random state allows for more meaningful comparisons 
    
    # Fit the model to our ETF data
    kmeans.fit(X)
    
    # Calculate and store the distortion (inertia) for this clustering
    # Lower distortion indicates tighter clusters of similar ETFs
    distortions.append(kmeans.inertia_)

# Use the Elbow method to find the optimal number of clusters
# This helps in determining how many distinct ETF groups exist in our data
kl = KneeLocator(K, distortions, curve="convex", direction="decreasing")
elbow = kl.elbow

# Print the optimal number of clusters
# This suggests how many different ETF categories we should consider in our portfolio
print(f"Optimum Clusters: {elbow}")
# Out:
# Optimum Clusters: 4

# %% [markdown]
# # Distortions in K-means Clustering
#
# Distortions in K-means clustering refer to the sum of squared distances between each data point and its assigned cluster centroid. This concept is important for understanding the quality and characteristics of the clustering solution. Let's break this down:
#
# ## 1. Definition
# - Distortion is a measure of how much the data points deviate from their cluster centroids.
# - Mathematically, it's the sum of squared Euclidean distances between each point and the centroid of its assigned cluster.
# ## 2. Calculation
# For each cluster:
# 1. Calculate the distance between each point in the cluster and the cluster centroid.
# 2. Square these distances.
# 3. Sum up all these squared distances.
# The total distortion is the sum of these values across all clusters.
# ## 3. Significance
# - Lower distortion generally indicates tighter, more compact clusters.
# - It's used to evaluate the quality of clustering for different values of K (number of clusters).
# ## 4. Use in K-means
# - The K-means algorithm aims to minimize the total distortion across all clusters.
# - Each iteration of K-means reassigns points and recalculates centroids to reduce the overall distortion.
# ## 5. Elbow Method
# - Distortion is often used in the "elbow method" for determining the optimal number of clusters.
# - As K increases, distortion typically decreases (each point is closer to its centroid).
# - The "elbow" in the distortion vs. K plot can indicate a good trade-off between cluster number and distortion.
# ## 6. Limitations
# - Distortion alone doesn't always indicate the best clustering solution.
# - It tends to decrease with more clusters, even if those additional clusters don't represent meaningful divisions in the data.
# ## 7. In Financial Context
# - For clustering financial instruments like ETFs, lower distortion could indicate groups of assets with more similar return and volatility characteristics.
# - However, the interpretation should always consider the financial meaning of the clusters, not just the mathematical measure.
# ## Implementation
# To implement this in your analysis, you would typically:
#
# 1. Run K-means for different values of K.
# 2. Calculate the distortion for each K.
# 3. Plot distortion vs. K.
# 4. Look for an "elbow" point where the rate of distortion decrease slows significantly.
#
# This analysis helps in choosing an appropriate number of clusters that balances between fitting the data well and avoiding overfitting.

# %%
# Fit K-Means Model
k_means = KMeans(n_clusters=elbow, random_state=42)
k_means.fit(X)

# Select only the numeric columns for prediction
X_predict = df_scaled.select(['Returns', 'Volatility']).to_numpy() # need to this way since the ETF column is a string

# Predict clusters
prediction = k_means.predict(X_predict)

# %%
import matplotlib.pyplot as plt
import polars as pl
import numpy as np

# Ensure we have the cluster information
X_predict = df_scaled.select(['Returns', 'Volatility']).to_numpy()
prediction = k_means.predict(X_predict)

# Add predictions to the original dataframe
df_scaled = df_scaled.with_columns(pl.Series(name='Cluster', values=prediction))

# Extract centroids
centroids = k_means.cluster_centers_

# Create the plot
fig, ax = plt.subplots(figsize=(18, 10))

# Scatter plot of ETFs
scatter = ax.scatter(
    df_scaled['Returns'].to_numpy(),
    df_scaled['Volatility'].to_numpy(),
    c=df_scaled['Cluster'].to_numpy(),
    cmap='rainbow',
    alpha=0.7,
    s=50
)

# Plot centroids
ax.scatter(
    centroids[:, 0],
    centroids[:, 1],
    c='black',
    s=200,
    marker='X',
    label='Centroids'
)

# Customize the plot
ax.set_title('K-Means Cluster Analysis Results of ETFs', fontsize=16)
ax.set_xlabel('Mean Return', fontsize=12)
ax.set_ylabel('Volatility', fontsize=12)
plt.colorbar(scatter, label='Cluster')
ax.legend()

# Add ETF labels
for i, etf in enumerate(df_scaled['ETF'].to_numpy()):
    ax.annotate(etf, (df_scaled['Returns'][i], df_scaled['Volatility'][i]), fontsize=8)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import RectangleSelector, Button
import polars as pl
import numpy as np
import mplcursors

# Assuming df_scaled is your Polars DataFrame with the data
# and k_means is your fitted KMeans model

# Create the plot
fig, ax = plt.subplots(figsize=(14, 10))

# Scatter plot of ETFs
scatter = ax.scatter(
    df_scaled['Returns'].to_numpy(),
    df_scaled['Volatility'].to_numpy(),
    c=df_scaled['Cluster'].to_numpy(),
    cmap='rainbow',
    alpha=0.7,
    s=50
)

# Plot centroids
centroids = k_means.cluster_centers_
ax.scatter(
    centroids[:, 0],
    centroids[:, 1],
    c='black',
    s=200,
    marker='X',
    label='Centroids'
)

# Customize the plot
ax.set_title('K-Means Cluster Analysis Results of ETFs', fontsize=16)
ax.set_xlabel('Mean Return', fontsize=12)
ax.set_ylabel('Volatility', fontsize=12)
plt.colorbar(scatter, label='Cluster')
ax.legend()

# Function to handle zooming
def line_select_callback(eclick, erelease):
    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    ax.set_xlim(min(x1, x2), max(x1, x2))
    ax.set_ylim(min(y1, y2), max(y1, y2))
    fig.canvas.draw_idle()

# Function to reset zoom
def reset_zoom(event):
    ax.autoscale(True)
    ax.relim()
    ax.autoscale_view()
    fig.canvas.draw_idle()

# Set up RectangleSelector for zooming
rs = RectangleSelector(ax, line_select_callback, useblit=True,
                       button=[1],  # use only the main mouse button
                       minspanx=5, minspany=5,
                       spancoords='pixels',
                       interactive=True)

# Add a button for resetting zoom
reset_button_ax = fig.add_axes([0.85, 0.01, 0.1, 0.05])
reset_button = Button(reset_button_ax, 'Reset Zoom')
reset_button.on_clicked(reset_zoom)

# Add hover functionality
cursor = mplcursors.cursor(scatter, hover=True)

@cursor.connect("add")
def on_add(sel):
    i = sel.target.index
    etf = df_scaled['ETF'][i]
    returns = df_scaled['Returns'][i]
    volatility = df_scaled['Volatility'][i]
    cluster = df_scaled['Cluster'][i]
    sel.annotation.set_text(f"ETF: {etf}\nReturns: {returns:.4f}\nVolatility: {volatility:.4f}\nCluster: {cluster}")

# Add instructions to the plot
instructions = """
Zoom: Click and drag
Reset: Use 'Reset Zoom' button
or double-click
Hover: Move cursor over points
"""
fig.text(0.01, 0.01, instructions, fontsize=10, verticalalignment='bottom')

# Function to handle double click for resetting zoom
def on_double_click(event):
    if event.dblclick:
        reset_zoom(event)

fig.canvas.mpl_connect('button_press_event', on_double_click)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_62180/1274910081.py:97: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import polars as pl

# Create a Polars DataFrame directly from the ETF names and cluster labels
df = pl.DataFrame({
    'ETF': df_scaled['ETF'],
    'Cluster': k_means.labels_.flatten()
})

# Keep the complete series (equivalent to clustered_series_all)
clustered_series_all = df

# Filter out rows where 'Cluster' is -1
clustered_series = df.filter(pl.col('Cluster') != -1)

# Display the first 15 entries of the filtered DataFrame
print(clustered_series.head(15))

# To display the entire unfiltered series
print(clustered_series_all.head(15))
# Out:
# shape: (15, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AADR ┆ 0       │
# │ AAXJ ┆ 0       │
# │ ACWI ┆ 0       │
# │ ACWX ┆ 0       │
# │ AGNG ┆ 0       │
# │ …    ┆ …       │
# │ ANGL ┆ 1       │
# │ ASET ┆ 0       │
# │ BBH  ┆ 0       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# └──────┴─────────┘
# shape: (15, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AADR ┆ 0       │
# │ AAXJ ┆ 0       │
# │ ACWI ┆ 0       │
# │ ACWX ┆ 0       │
# │ AGNG ┆ 0       │
# │ …    ┆ …       │
# │ ANGL ┆ 1       │
# │ ASET ┆ 0       │
# │ BBH  ┆ 0       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# └──────┴─────────┘

# %%
import matplotlib.pyplot as plt

# Calculate cluster counts
cluster_counts = clustered_series.get_column('Cluster').value_counts().sort('Cluster')

# Create the plot
plt.figure(figsize=(10, 5))
plt.bar(cluster_counts['Cluster'], cluster_counts['count'])  # Note: 'count' instead of 'counts'

# Set labels and title
plt.title("Clusters")
plt.xlabel("Cluster")
plt.ylabel("Features Count")

# Show the plot
plt.show()

# %%
# Remove items if preferred
clusters_clean = clustered_series.filter(pl.col('Cluster') > .5)

print("Feature Number Previous: ", len(clustered_series))
print("Feature Number Current: ", len(clusters_clean))
# Out:
# Feature Number Previous:  308
# Feature Number Current:  92

# %%
clusters_clean
# Out:
# shape: (92, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AGZD ┆ 1       │
# │ AIRR ┆ 3       │
# │ ANGL ┆ 1       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# │ …    ┆ …       │
# │ VRIG ┆ 1       │
# │ VTC  ┆ 1       │
# │ VTIP ┆ 1       │
# │ VWOB ┆ 1       │
# │ WBND ┆ 2       │
# └──────┴─────────┘

# %% [markdown]
# # Calculating Cointegrated Pairs

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint

def calculate_cointegration(series1, series2):
    """
    Calculates whether two financial assets are cointegrated, providing key parameters for pairs trading.
    
    Parameters:
    series1 (array-like): Price series of the first asset.
    series2 (array-like): Price series of the second asset.

    Returns:
    coint_flag (int): Indicates if the pair is cointegrated (1 if yes, 0 if no).
    hedge_ratio (float): Ratio used to hedge positions between the two assets.
    """

    # Perform cointegration test using statsmodels
    coint_res = coint(series1, series2)
    coint_t = coint_res[0]  # Test statistic
    p_value = coint_res[1]  # P-value of the test statistic
    critical_value = coint_res[2][1]  # 5% critical value

    # Conduct linear regression to determine the hedge ratio
    series1 = sm.add_constant(series1)  # Add a constant for the intercept
    model = sm.OLS(series2, series1).fit()
    hedge_ratio = model.params[1]  # Hedge ratio from the regression slope

    # Evaluate cointegration based on p-value and test statistic against critical value
    coint_flag = 1 if p_value < 0.05 and coint_t < critical_value else 0

    # Notify the user that the cointegration calculation is complete
    print("Cointegration calculation complete. Cointegration Flag:", coint_flag, "Hedge Ratio:", hedge_ratio)

    return coint_flag, hedge_ratio

# %%
import polars as pl

def loop_through_and_calculate_cointegration(clusters_clean, data):
    tested_pairs = []
    cointegrated_pairs = []

    # Fetch the list of unique ETFs from the clusters_clean DataFrame
    etf_names = clusters_clean.get_column('ETF').to_list() # uses .to_list because polars has issues working with strings and numerics

    # Iterate over each ETF as the base asset
    for base_asset in etf_names:
        # Retrieve the cluster label for the base asset
        base_label = clusters_clean.filter(pl.col('ETF') == base_asset).select('Cluster').to_series()[0]

        # Iterate over each ETF again as the compare asset
        for compare_asset in etf_names:
            if base_asset != compare_asset:
                compare_label = clusters_clean.filter(pl.col('ETF') == compare_asset).select('Cluster').to_series()[0]

                # Only compare assets within the same cluster
                if base_label == compare_label:
                    # Create a sorted tuple of the pair to ensure uniqueness
                    test_pair = tuple(sorted((base_asset, compare_asset)))

                    if test_pair not in tested_pairs:
                        tested_pairs.append(test_pair)

                        # Access the time series data for both ETFs from the data DataFrame
                        # Extracting data for all dates (assuming data is already aligned)
                        series1 = data.get_column(base_asset).to_numpy().astype(float)
                        series2 = data.get_column(compare_asset).to_numpy().astype(float)

                        # Calculate cointegration; the function needs to be defined to accept these series
                        coint_flag, hedge_ratio = calculate_cointegration(series1, series2)

                        # If the assets are cointegrated, add them to the list of cointegrated pairs
                        if coint_flag == 1:
                            cointegrated_pairs.append({
                                "base_asset": base_asset,
                                "compare_asset": compare_asset,
                                "label": base_label
                            })

    # Create a DataFrame from the list of cointegrated pairs
    df_coint = pl.DataFrame(cointegrated_pairs)
    
    # Save the results to a CSV file for further analysis
    df_coint.write_csv('data/cointegrated_pairs.csv')
    print("Calculation and saving of cointegrated pairs complete.")

# Make sure to define or import your calculate_cointegration function that can handle these series.
import polars as pl

def loop_through_and_calculate_cointegration(clusters_clean, data):
    tested_pairs = []
    cointegrated_pairs = []

    # Fetch the list of ETFs from the clusters_clean DataFrame. This list is used to iterate over all possible pairs.
    etf_names = clusters_clean.get_column('ETF').to_list()

    # Iterate over each ETF as the base asset. The base asset will be paired with every other possible compare asset.
    for base_asset in etf_names:
        # Retrieve the cluster label for the base asset. Clustering ETFs often groups them by similar characteristics such as sector or volatility.
        base_label = clusters_clean.filter(pl.col('ETF') == base_asset).select('Cluster').to_series()[0]

        # Iterate over each ETF again to find a suitable compare asset.
        for compare_asset in etf_names:
            if base_asset != compare_asset:
                # Fetch the cluster label for the compare asset to ensure both assets are comparable.
                compare_label = clusters_clean.filter(pl.col('ETF') == compare_asset).select('Cluster').to_series()[0]

                # Only consider pairs within the same cluster to enhance the likelihood that they share similar economic or market dynamics.
                if base_label == compare_label:
                    # Create a sorted tuple to uniquely identify each pair, ensuring no duplicate pair analysis.
                    test_pair = tuple(sorted((base_asset, compare_asset)))

                    if test_pair not in tested_pairs:
                        tested_pairs.append(test_pair)

                        # Access the historical price series data for both ETFs. This is crucial for determining their statistical relationship over time.
                        series1 = data.get_column(base_asset).to_numpy().astype(float)
                        series2 = data.get_column(compare_asset).to_numpy().astype(float)

                        # Calculate cointegration to determine if the pair has a statistically significant long-term equilibrium relationship.
                        coint_flag, hedge_ratio = calculate_cointegration(series1, series2)

                        # If the assets are found to be cointegrated, it implies a stable long-term relationship where the spread between them is mean-reverting.
                        if coint_flag == 1:
                            cointegrated_pairs.append({
                                "base_asset": base_asset,
                                "compare_asset": compare_asset,
                                "label": base_label
                            })

    # Compile the findings into a DataFrame for easy analysis and storage.
    df_coint = pl.DataFrame(cointegrated_pairs)
    
    # Save the results to a CSV file for further analysis or for use in trading strategies.
    df_coint.write_csv('data/cointegrated_pairs.csv')
    print("Calculation and saving of cointegrated pairs complete.")

# Ensure that the calculate_cointegration function is defined in your environment.
# This function should be able to handle the price series and calculate the cointegration flag and hedge ratio.

# %%
print(clusters_clean.head())
print(data.head())
# Out:
# shape: (5, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AGZD ┆ 1       │
# │ AIRR ┆ 3       │
# │ ANGL ┆ 1       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# └──────┴─────────┘
# shape: (5, 645)
# ┌─────────────────────┬───────────┬──────┬──────┬───┬──────┬───────────┬───────────┬─────┐
# │ Date                ┆ AADR      ┆ AAPB ┆ AAPD ┆ … ┆ XFIX ┆ XT        ┆ YLDE      ┆ ZZZ │
# │ ---                 ┆ ---       ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---       ┆ ---       ┆ --- │
# │ str                 ┆ f64       ┆ str  ┆ str  ┆   ┆ str  ┆ f64       ┆ f64       ┆ str │
# ╞═════════════════════╪═══════════╪══════╪══════╪═══╪══════╪═══════════╪═══════════╪═════╡
# │ 2019-01-02 00:00:00 ┆ 37.611721 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 31.699696 ┆ 23.76158  ┆ 0   │
# │ 2019-01-03 00:00:00 ┆ 37.192055 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 30.861734 ┆ 23.422531 ┆ 0   │
# │ 2019-01-04 00:00:00 ┆ 38.637581 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 31.918711 ┆ 23.999846 ┆ 0   │
# │ 2019-01-07 00:00:00 ┆ 39.094551 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 32.404346 ┆ 24.228943 ┆ 0   │
# │ 2019-01-08 00:00:00 ┆ 39.365002 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 32.585262 ┆ 24.250931 ┆ 0   │
# └─────────────────────┴───────────┴──────┴──────┴───┴──────┴───────────┴───────────┴─────┘

# %%
loop_through_and_calculate_cointegration(clusters_clean, data)
# Out:
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8077135729352958
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.1673785960320935
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.8809334507053987
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.6087522469821252
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.0439506563793446
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.671777204740257
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.49751175258397123
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3422458111802933
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.29050360927828955
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23376592765323484
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1297195957944564
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5874940855865185
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2662097367040972
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.803598760426635
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3455755743997435
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.8274239436939355
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2395869802731134
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.46463203474141
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7877611847300487
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7219707163715547
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2500068361913211
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.3476130244208357
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5004990312938628
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7891094334144609
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.6035401865091292
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.277938056545812
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.9419095847018415
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.4417436702419733
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -2.437717103020571
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.197219495922197
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9433532108713493
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3826400324624586
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5810711379563578
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5643644950270392
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -5.2433230434411175
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -2.4831200485631344
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.6782026377518626
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.03949293155529464
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -4.8120908463667265
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9272426826092022
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -3.7055578382650265
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40275536784066374
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.870181924376121
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6684539276647101
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -3.2487729232431755
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.15208099514875906
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6794559403711785
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6601804618246327
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.6129715302825343
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 3.2356565173970493
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.44769241376335844
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5333762079763734
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0132692477044114
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36229409739373303
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.35001811890386786
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -16.460399563610803
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.4325759193114528
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.4823427576100247
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8107233721741398
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2652452944412455
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -3.637931265661408
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3413764789310663
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.5544351087186825
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -9.189560764893344
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3974105392619856
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.5465696998392002
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4689863156595269
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -2.8369312128362445
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.3049501269758768
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8763651533792318
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.106931527873356
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8002328991272514
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0099781722186043
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2709848337406926
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4985066017371721
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3734069713931802
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7093356392115054
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7583989669693794
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7509726560949255
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6183171389868667
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2041851245085873
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06140750035783015
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.4884093549703854
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.471414778115683
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9393006348960921
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4132853775190425
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.30238430383089526
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5302338565696677
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40957520740042114
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.223962028081684
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3251353537727899
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3219333075766981
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32204873472700446
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3360088493591419
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3549841321261142
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4454009633459754
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5466383353451421
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5065943707105153
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.5337734941550436
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7625072926902821
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1366854803368227
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3196586768769525
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7905425284526737
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9402353159357388
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7235233419342734
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13186519223374138
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40901633484568795
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6805452215692162
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9858218423348031
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37166476732466813
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9338538326674786
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4120770953630884
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.05626711162909822
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.010462929456642235
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8020166295909607
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6575888451075904
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.849622179689455
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9340391206899543
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.41923357783825
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19170190608976037
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5309296379133511
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2490708799285939
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8214834416908419
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13498488060101319
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5922266209756877
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06288658820944143
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.41146995220515037
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.41320660499558654
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.26257279943714956
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23696741816131336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.42459714063208104
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7909675981523283
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4563149470864115
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0633159508436358
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.604102983972787
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.39793076904909264
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7101738619623699
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5165660950626156
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2575598905227672
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32972827366838514
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.6135353413563872
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5593833055513151
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7631077940497751
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6520960756940662
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2292961630454693
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4765383095232416
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8599553369559578
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.26075648456106026
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.29905628573337656
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.30336644985191463
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1160266711483732
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5407439135492499
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4827223351726669
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3157800883458514
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1252365919585294
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.795405173299557
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8610803493942082
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5239113240175615
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.3340749644977734
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.883439922641919
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09900427199732169
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17212586097988303
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2390291770948717
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27376384306806656
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3289423672275141
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.025324434110871753
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0674584951792123
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.02492762937960468
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10524976783518987
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.012488350229574077
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.4185595076448116
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0833360471646123
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.6937264565490543
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18884430537960628
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5018878130997333
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5459367704663274
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0442217867403716
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5648265560624713
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6028535550544494
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.17570774354283247
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.288265194022194
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1742844196732766
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.7680478428537956
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1129227533379307
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11257046292199475
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23918537162358564
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3466878401833874
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3960293094201389
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.174538815043631
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.678331309817929
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9277342725317386
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7040095638494361
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.039710802171334
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9733925718706928
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36140846896784384
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.7323733138696846
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3789085188659749
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9006173681380546
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17241338901992861
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7972612354758928
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3466382980386485
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4048994507877262
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2798639614613153
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22939946570234152
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3026996412203394
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.43903506297644057
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6489011836656174
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2525866418536817
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18544734507767957
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.555352660631772
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.715311040160821
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.847999696669852
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1357809292588252
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.05296411784810446
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.6460208529088993
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.292487906588758
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5402489992725754
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.088108451139529
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.873547431162292
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.30146703791381135
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.8733577349390195
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1630091850110879
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.303546384779229
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1285660718705319
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7644395269490802
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.17311592073321694
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.5511472333698295
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2762837440503057
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1697688121104663
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6220948682261342
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.33301224370115806
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32346796036545383
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.26763854383365643
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7035380725412865
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7999430884755342
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13851883448586147
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36184351385727304
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5198517838571626
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6872697266044836
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.11799541277856278
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3356610266419862
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 16.060856866078684
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8102591303372899
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8512709517135968
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5449265359515764
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07444332649611912
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1211072574840249
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1638127207735595
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18447951026336773
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2180206338958737
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.011231545742130053
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.041013913866935356
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.01326843152946708
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12555825407918975
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.028904701228557383
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4291463368555568
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6559348325627888
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3682110638496134
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13375670859853833
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3133876722765306
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2839734469962466
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6854901801459322
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3561798973747462
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37626474913913804
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12159683458752565
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.18088640687501634
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10907452355272346
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4905345570491895
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7401175299503475
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.05664914541802228
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1717049920660392
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21640556080849002
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.25028819923096357
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12334023522149985
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7758032270678534
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.2734207636900792
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4004940719911747
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6758300464413424
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1999622122036473
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.242257548860285
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.0419266941576155
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2506517161575156
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.587561506674308
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.10639717321921753
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.151356377972584
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21647636011069607
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2596809538189955
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13166729402978947
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2340468601228934
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.18878195057212352
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2942040241000905
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.43219070747800725
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17276440452803712
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12279922629649709
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3607898387069385
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.446781477893036
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5545624136041125
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7372491763249379
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.04659378287791544
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0700707794612117
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.131604419008727
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.360571813443334
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.7220285431573767
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.567170186714231
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2035268669145902
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5582706878062377
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.0960854103762839
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7359092346451902
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0827682074880965
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1445582064309905
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.06550459380142676
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9226523416504362
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6553639674528018
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07752807516047044
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1320354121448297
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18189444045135947
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.20673924457978524
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.24696222979709223
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.013236654327419965
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.05293048660489243
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.013770152419956033
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.01285220991873306
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.033076427840653164
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7408278646415327
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.775860675425672
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.4848245306305186
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.14073123995163875
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36434612974950253
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37320044689452975
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7879880698726756
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4143137102971985
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.43832009138535993
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13242229212534856
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2181061884557041
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1298901874597665
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5770574283181403
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8499109821590553
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07010538277083879
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1857207671858062
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2543473581835382
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.29057283634969716
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13826518533440676
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.04003308802718
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.4640253522503723
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5009473547250897
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7775771457647801
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.445678098231282
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27350914197362064
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.2585076899877743
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2864802596627438
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6782762775273943
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1277665181135369
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3486234758394526
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.25203556617128187
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.29797597389942443
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.18459980634765574
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.21868008424628946
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22215002809172785
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3364581199832326
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.48998612313812445
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19285548962347387
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13988464017694938
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4164950309407992
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.122400122627126
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6364811785492711
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8505316669634083
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.04236421037769321
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2319064878258683
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.4663622368408147
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40810558183824636
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.8280794380881978
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.955828690100812
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23166827516232338
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.655176005041356
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11316168326396088
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9252128355598769
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.098290520537218
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.321365147552867
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.11005744429337105
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1183414605657807
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09597890693046603
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17645297594004963
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2499788082770321
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.28783054885424775
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3490180846758215
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.017945893577316116
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.08934415177824759
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.015143358568330474
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3206314050878666
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.05164763220463665
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 2.691617506584199
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1558560180302073
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8170205131649496
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17579338688024773
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5312516750933356
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6240653155968242
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1379252418859687
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6051372762422657
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6404553156475088
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1791073238439291
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3377779802347727
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.19736330164684512
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8581616779398735
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2282615690093877
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.10635471905539241
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.24475115021345556
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3745359793010572
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4215962118799996
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.19522346133159552
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.948084558849643
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.1159987119923023
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.796481114519426
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.12242260532689
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2114475305536105
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3838256698206517
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.929667074760133
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4096194963784907
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9844869338027974
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19380779580662477
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9950586100643408
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36839540432703627
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.42608735114071133
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.32960939231063724
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2290381162935495
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3320859626634898
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.482259667000214
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6930594760022469
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2661304555569738
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1987956563157224
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6042125841493186
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 7.434603432775372
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9164758615689357
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2324616190754718
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.038478674534211735
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7798678925215403
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.590548040453426
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5747320689441405
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1933603145978746
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.2873961488653105
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32995362087517893
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9714588786752852
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1659309620100807
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4788462016512705
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1490337433052131
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9166966527574016
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2257262882516517
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7190318649292862
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0102851758808709
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0244855851226295
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.049080513192389
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.100756365131114
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0959988454915082
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3723745764171538
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.252805389779161
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 8.18909773124521
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2849164459493683
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.9200430163316384
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.485538079770884
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7165393927692616
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3510597082847404
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8376193788774826
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3219372945620431
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3924718435645476
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7781256446121798
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.238391452005185
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8204645825076727
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.356628569834258
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2452630130075357
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3647409608804989
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5255652035071747
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.524605803258416
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.671627836364381
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.097703432227937
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3893293861673324
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9167116751568839
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8538671527776964
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.435646220778585
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.06721120763809119
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.5366161685705615
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2797955751230407
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.796471269248336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07210445895467488
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2964782360156988
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.397711805631659
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8497569630199291
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0760249669822979
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0037689733026305
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8083982818636046
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7798656217142889
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8334168280432064
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.928754125661673
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.416360636228689
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.1986070039020817
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.592199824281793
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7976290067703087
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0431044301318066
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.438927737536921
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7553898811198698
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3579498897589275
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8626090813559857
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.82726008053813
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.710355725357271
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.6180076187113297
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2723223751611874
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0803743449906662
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0649711312380246
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5229850964427164
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9937629275251678
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.02483365035961134
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8592666247165222
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.5152739391982792
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.0611540564304653
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2502143877727265
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0694743387919068
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1180895869956406
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2053249468220864
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9210798162945371
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0801924389382696
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0546870871332834
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.967461326996777
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0268833866145877
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.324075793126311
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.7655653585850417
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9279976985125211
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.1226930141117384
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9389319130409444
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6453893511748083
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.06723310448828
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9431786250127518
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3534837944295828
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4976245345351933
# ...
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.0951134498091867
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3344950007017139
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.08626249592070723
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.04668712290944652
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7774968474603696
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 11.430838582191196
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.8266631645606086
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.8282829318901936
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7169242845091508
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.914974206512718
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 9.182655750366838
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.1645134792354237
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.802522770631542
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.820529320316916
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.4278428075350689
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8878141209501442
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.129781917085541
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2130310923782046
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5681403618293163
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.823570946979919
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4252628912152903
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.589510268319518
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 10.690103353412296
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.540233760545844
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.0718389853433776
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.30802169179885674
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.0403033643768875
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.773719061271666
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1588580784137537
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.835746382621823
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.185868272107608
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5813484890179843
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4120828268462273
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4152014496232238
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.0791011925476246
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10080596380817024
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.20099396698372
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.04595191550234381
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.6401887239599526
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09611050819474251
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1264418892000192
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.01831331919550549
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17700513895782058
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40028410401827547
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.03902299217661507
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.14381627741598946
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5740671662318043
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.029460725274585185
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11350649244951441
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0006255769584951956
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13789638015987463
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.03224469834808836
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19866807397137765
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.04321109461085476
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.15576793947321246
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.039658560457031006
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.3273926348945397
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23512109812207105
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9621656619972903
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.652317470633398
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.769622241179062
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.177540184545942
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.8696018528833998
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3883950745603728
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8863842807328342
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27959025223775336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.26607744765101
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0473685949994481
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 2.045192996138038
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09137728419403937
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.644873372536737
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1776811547245058
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.474183847585564
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.7502752674145903
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5830515522801285
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8645241014855476
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.848814581656552
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2860773148085988
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.660327660129016
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21730553162723693
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9839335579047221
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.02900271418491321
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5421024715689462
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.060043763761031134
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2720413547068419
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2336710447719164
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8422187415596324
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1395620668771775
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13462763987558896
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.4636632056079515
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4486062857954406
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.11631819328423387
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.46513023449790053
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.5173486499656841
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5437449887518997
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9988628058276704
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1304311647367369
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6069209300666859
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8141038289650575
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.41368199858738447
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5723350952672767
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8229921779444318
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.20054071424749023
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.43028677277979294
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.15027573304585606
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6181338143829118
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0038074507945967035
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.034244650786191
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06670458584852736
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8474636571709956
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17194195203676596
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.31797303381171066
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1313286393272262
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.08908712923571468
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2505199795972323
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06119124420575045
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3842050101762202
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.03251880283721949
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5380629937745812
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.019683394602814666
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.447712286607035
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8069977883518915
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8055957463818215
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4430263781579465
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5261369323708049
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36879145679882364
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6013032917984625
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.20872583142137197
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7476921900717455
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5114426963661762
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3577223326789443
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.575683343278354
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2786174361224117
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7547862956463284
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07516805768813505
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8468075572945326
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13135912791143803
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4866473462554628
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12209343858389007
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1504056863491128
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.05308751160326468
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19779672140358603
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0015048340464546939
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23465511701315772
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0547574737795127
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.34887352787833326
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.07306438624423534
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27230754570218213
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.375983073032145
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.42470100322172855
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8707369735629386
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.22497436364641638
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.651294433246468
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6806803148877254
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.660757098810698
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1301123425712653
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4627676550079565
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.21115063362857162
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8341392708988378
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2888438404654658
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5831783443995144
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5820637279305685
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.16945226817000356
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1538230515271881
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5485400173773336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2023217863342373
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.07443713683190908
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5937619449824874
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10553664760923674
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6769979933736275
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.5608195904588285
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7101930722549552
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.5508423927902301
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.027751389259070103
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.826202109039372
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22478092693674273
# Calculation and saving of cointegrated pairs complete.

# %%
#Load Cointegrated Pairs
df_coint = pl.read_csv('data/cointegrated_pairs.csv')
df_coint.head()
# Out:
# shape: (5, 3)
# ┌────────────┬───────────────┬───────┐
# │ base_asset ┆ compare_asset ┆ label │
# │ ---        ┆ ---           ┆ ---   │
# │ str        ┆ str           ┆ i64   │
# ╞════════════╪═══════════════╪═══════╡
# │ AGZD       ┆ FTSM          ┆ 1     │
# │ AGZD       ┆ SHV           ┆ 1     │
# │ AGZD       ┆ VRIG          ┆ 1     │
# │ BGRN       ┆ BNDW          ┆ 1     │
# │ BGRN       ┆ BNDX          ┆ 1     │
# └────────────┴───────────────┴───────┘

# %%
df_coint.tail()
# Out:
# shape: (5, 3)
# ┌────────────┬───────────────┬───────┐
# │ base_asset ┆ compare_asset ┆ label │
# │ ---        ┆ ---           ┆ ---   │
# │ str        ┆ str           ┆ i64   │
# ╞════════════╪═══════════════╪═══════╡
# │ SUSB       ┆ VGSH          ┆ 1     │
# │ SUSC       ┆ UITB          ┆ 1     │
# │ UITB       ┆ USIG          ┆ 1     │
# │ UITB       ┆ VTC           ┆ 1     │
# │ VCLT       ┆ VGIT          ┆ 1     │
# └────────────┴───────────────┴───────┘

# %% [markdown]
# ## TSNE Plot for Visualization

# %%
import polars as pl

# Load the cointegrated pairs from a CSV file
df_coint = pl.read_csv('data/cointegrated_pairs.csv') #turn loaded file into polars dataframe

# Concatenate 'base_asset' and 'compare_asset' into a single Series and then find unique assets
# Use Series.append() for combining two columns from DataFrame into one Series
coint_unique_assets = df_coint['base_asset'].append(df_coint['compare_asset']).unique().sort()


print(coint_unique_assets.head())
# Out:
# shape: (10,)
# Series: 'base_asset' [str]
# [
# 	"AGZD"
# 	"BGRN"
# 	"BIS"
# 	"BND"
# 	"BNDW"
# 	"BNDX"
# 	"BSCS"
# 	"BSJO"
# 	"BSJQ"
# 	"EMB"
# ]

# %%
df_scaled.columns
# Out:
# ['ETF', 'Returns', 'Volatility', 'Cluster']

# %%
# Filters the scaled data to include only those ETFs that have been identified as cointegrated.
df_tsne = df_scaled.filter(pl.col('ETF').is_in(coint_unique_assets))

# Display the head of the DataFrame focusing on cointegrated ETFs
print(df_tsne.head())

# Coding Comments:
# This cell filters the df_scaled DataFrame to retain only those rows where the 'ETF' column
# matches any of the unique ETFs identified as part of cointegrated pairs. This is done using
# Polars' filter() method combined with is_in(), which checks for membership in the 
# coint_unique_assets list.

# Trading Reasoning:
# By focusing on the returns and volatility data of only those ETFs that are cointegrated, this 
# approach streamlines the analysis towards the most relevant data for pairs trading strategies.
# Cointegrated ETFs are likely to revert to their long-term mean, allowing traders to potentially 
# exploit temporary inefficiencies for profit. This focused analysis helps in reducing the risk 
# associated with trading non-cointegrated or less predictable ETF pairs.
# Out:
# shape: (5, 4)
# ┌──────┬───────────┬────────────┬─────────┐
# │ ETF  ┆ Returns   ┆ Volatility ┆ Cluster │
# │ ---  ┆ ---       ┆ ---        ┆ ---     │
# │ str  ┆ f64       ┆ f64        ┆ i32     │
# ╞══════╪═══════════╪════════════╪═════════╡
# │ AGZD ┆ -0.828786 ┆ -1.756145  ┆ 1       │
# │ BGRN ┆ -1.05959  ┆ -1.597026  ┆ 1       │
# │ BIS  ┆ -3.167668 ┆ 2.745099   ┆ 2       │
# │ BND  ┆ -1.076231 ┆ -1.470524  ┆ 1       │
# │ BNDW ┆ -1.091016 ┆ -1.603281  ┆ 1       │
# └──────┴───────────┴────────────┴─────────┘

# %%
from sklearn.manifold import TSNE
import numpy as np

# Ensure only numeric columns are used for t-SNE
numeric_data = df_tsne.select(['Returns', 'Volatility']).to_numpy()

# Configure and apply t-SNE to reduce dimensionality for visualization
tsne = TSNE(learning_rate=30, perplexity=5, random_state=42, n_jobs=-1)
X_tsne = tsne.fit_transform(numeric_data)  # Convert to NumPy array for compatibility with sklearn

# Print the first 5 transformed data points
print(X_tsne[:5])

# Coding Comments:
# Applies t-SNE to the filtered DataFrame to visualize high-dimensional data in two dimensions.
# The 'ETF' column is excluded because t-SNE requires numerical data. We convert the remaining
# numeric columns ('Returns' and 'Volatility') to a NumPy array as sklearn does not support Polars directly.

# Trading Reasoning:
# t-SNE helps in visualizing the relationships and clustering among cointegrated assets, which can aid
# traders in identifying which assets move in a correlated manner. This visualization is crucial for
# selecting pairs that might return to their mean, providing profitable trading opportunities. The 
# method efficiently handles the complexity of financial data, offering insights into potential 
# mean-reverting opportunities within the asset pairs.
# Out:
# [[ 11.117418    8.385481 ]
#  [ 14.7821865 -13.43288  ]
#  [-28.178776   20.649239 ]
#  [ 19.68401   -12.787885 ]
#  [ 14.016049  -14.860974 ]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx

# First, we visualize using t-SNE
plt.figure(figsize=(25, 20))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=df_tsne['ETF'].to_list(), palette='viridis', s=100)
plt.title('t-SNE Visualization of Cointegrated Pairs')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.show()

# Coding Comments for t-SNE:
# Uses Seaborn for plotting the t-SNE results, providing a visual clustering of assets based on their
# returns and volatility profiles. The 'hue' parameter is used to color code the different assets,
# allowing for easy identification of clusters.

# Trading Reasoning for t-SNE:
# The visualization aids in identifying natural groupings or clusters among cointegrated assets, which 
# is useful in adjusting pairs trading strategies based on visual insights into which assets behave 
# similarly in terms of price movements and volatility. This helps in selecting assets that might 
# demonstrate mean-reverting behavior, a key aspect of pairs trading strategies.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph object
G = nx.Graph()

# Adding edges using native Polars operations
edges = df_coint.to_dicts()

# Add nodes and edges from the cointegrated pairs DataFrame
for edge in edges:
    G.add_edge(edge['base_asset'], edge['compare_asset'])

# Position nodes using the spring layout
pos = nx.spring_layout(G, seed=42)  # seed for reproducibility

# Draw the network graph
plt.figure(figsize=(25, 20))
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=1500, edge_color='k', linewidths=1, font_size=10)
plt.title('Network of Cointegrated ETFs')
plt.show()

# Coding Comments:
# NetworkX is used to create a visual representation of connections between ETFs. Each node represents
# an ETF, and each edge represents a cointegration relationship. The spring layout is used to position 
# nodes in a way that minimizes overlaps and clearly shows the connections.

# Trading Reasoning:
# Visualizing the network of ETF relationships can help traders understand how different ETFs are
# interconnected. This network view can be instrumental in identifying central assets that have
# multiple cointegration links, potentially serving as key players in a trading strategy focused on
# stability and mean reversion.
