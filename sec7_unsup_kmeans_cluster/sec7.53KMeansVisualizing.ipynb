# %% [markdown]
# ### Imports

# %%
# Remove unwanted warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Data extraction and management
import polars as pl
import numpy as np
import yfinance as yf

# Feature Engineering
from sklearn.preprocessing import StandardScaler

# Machine Learning
from sklearn.cluster import KMeans
from sklearn import metrics
from kneed import KneeLocator

# Cointegration and Statistics
from statsmodels.tsa.stattools import coint
import statsmodels.api as sm

# Reporting visualization
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %% [markdown]
# ## Data Extraction

# %%
# Set Data Extraction parameters for trading with Polars
start_date = "2019-01-01"  # Start date for historical data
end_date = "2024-06-01"    # End date for historical data (adjust as needed)

# File paths for storing and retrieving data
file_name = "data/raw_data_etf.csv"  # Path for ETF data
file_name_coint = "data/raw_data_coint_pairs.csv"  # Path for cointegrated pairs data

# Flags for data loading
load_existing = True     # Set to True to load existing ETF data from file
load_coint_pairs = False   # Set to True to load existing cointegrated pairs data

# Note: When using Polars for trading:
# - Ensure date parsing is handled correctly when reading/writing CSV files
# - Consider using Polars' memory-efficient data types for large datasets
# - Leverage Polars' fast I/O operations for reading/writing data
# - Utilize Polars' vectorized operations for quick data manipulations

# %% [markdown]
# ### Get Symbols

# %%
import yfinance as yf  # Import the yfinance library for financial data
import polars as pl    # Import the Polars library for DataFrame operations
import pandas as pd    # Import the pandas library for data manipulation

# Variable to determine whether to load existing data or fetch new data
load_existing = True

# Function to fetch NASDAQ symbols
def get_nasdaq_symbols():
    # URL of the NASDAQ listed symbols file
    url = 'ftp://ftp.nasdaqtrader.com/SymbolDirectory/nasdaqlisted.txt'
    # Read the symbols data from the URL using pandas
    symbols = pd.read_csv(url, sep='|')
    # Drop rows with any missing values
    symbols = symbols.dropna()
    # Set the 'Symbol' column as the index of the DataFrame
    symbols.set_index('Symbol', inplace=True)
    # Return the DataFrame containing the symbols
    return symbols

# Function to load existing symbols from a file
def load_existing_symbols(file_path):
    # Read the symbols from a CSV file
    existing_symbols = pd.read_csv(file_path)
    # Set the 'Symbol' column as the index of the DataFrame
    existing_symbols.set_index('Symbol', inplace=True)
    # Return the DataFrame containing the existing symbols
    return existing_symbols

# Path to the file where existing symbols are stored
existing_symbols_file = 'data/existing_symbols.csv'

# Check if we should load existing data or fetch new data
if load_existing:
    # Load existing symbols from the file
    existing_symbols = load_existing_symbols(existing_symbols_file)
    # Ensure symbols variable is defined when loading existing data
    symbols = existing_symbols.copy()
else:
    # Fetch the NASDAQ symbols using the defined function
    symbols = get_nasdaq_symbols()
    # Filter the symbols to include only those that are ETFs (ETF == 'Y') and belong to the NASDAQ Global Market (Market Category == 'G')
    symbols = symbols[(symbols['ETF'] == 'Y') & (symbols['Market Category'] == 'G')]
    # Convert the filtered symbols DataFrame index to a list of symbol strings
    new_symbols = list(symbols.index.values)

    # Compare new symbols with existing symbols (if they exist)
    try:
        existing_symbols = load_existing_symbols(existing_symbols_file)
        existing_symbols_list = list(existing_symbols.index.values)

        if new_symbols != existing_symbols_list:
            # If there are new or updated symbols, replace the existing symbols
            symbols.to_csv(existing_symbols_file)
            print("Symbols updated.")
        else:
            print("No new symbols.")
    except FileNotFoundError:
        # If the existing symbols file does not exist, save the new symbols
        symbols.to_csv(existing_symbols_file)
        print("Symbols saved.")

    # Print the list of new symbols
    print(new_symbols)

# Print the length of the symbols DataFrame
print(len(symbols))
# Out:
# 644

# %%
print(len(symbols))
# Out:
# 644

# %%
import yfinance as yf  
import pandas as pd   

# Ensure symbols is a list of strings, somehow errored because it was not in string format
if isinstance(symbols, pd.DataFrame):
    symbols = symbols.index.tolist()

# Fetch adjusted close prices for the symbols from Yahoo Finance
data = yf.download(symbols, start=start_date, end=end_date)['Adj Close']

# Save the data to a CSV file
data.to_csv(file_name)

print(f"Data saved to {file_name}")
# Out:
# [*********************100%%**********************]  644 of 644 completed
# 19 Failed downloads:
# ['EVSD', 'BSCY', 'IBTP', 'BELT', 'BMDL', 'QQQT', 'AIPI', 'QXQ', 'QBUF', 'METU', 'BGRO', 'BSJW', 'TMET', 'GLOW', 'BRHY', 'FCTE', 'IBGA', 'IBGK', 'METD']: Exception("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1717214400")
# Data saved to data/raw_data_etf.csv

# %%
import polars as pl

# Load (or re-load for consistency) Data and remove features with NaN's
data = pl.read_csv(file_name)

# Filter columns that have all null values
data = data.filter(~pl.all_horizontal(pl.all().is_null()))

# Replace null values with zero for each column explicitly
data = data.with_columns(
    [pl.col(column).fill_null(0) for column in data.columns]
)

# Print the shape of the dataset
print("Shape:", data.shape)

# Check for any null values and print a boolean
has_null_values = data.null_count().sum_horizontal().sum() > 0
print("Null Values:", has_null_values)

# Display the first 50 rows to verify
data
# Out:
# Shape: (1363, 645)
# Null Values: False
# shape: (1_363, 645)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Date      ┆ AADR      ┆ AAPB      ┆ AAPD      ┆ … ┆ XFIX      ┆ XT        ┆ YLDE      ┆ ZZZ      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ f64       ┆ str       ┆ str       ┆   ┆ str       ┆ f64       ┆ f64       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2019-01-0 ┆ 37.611717 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 31.699696 ┆ 23.761585 ┆ 0        │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 37.192055 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 30.861729 ┆ 23.422527 ┆ 0        │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 38.637585 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 31.918707 ┆ 23.999849 ┆ 0        │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.094543 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 32.404339 ┆ 24.228937 ┆ 0        │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.365005 ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 32.58527  ┆ 24.250927 ┆ 0        │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2024-05-2 ┆ 63.126698 ┆ 20.989999 ┆ 20.237186 ┆ … ┆ 50.850383 ┆ 59.230984 ┆ 46.30584  ┆ 24.38761 │
# │ 4         ┆           ┆ 771118164 ┆ 431884766 ┆   ┆ 75854492  ┆           ┆           ┆ 32965087 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 9        │
# │ 2024-05-2 ┆ 63.562946 ┆ 21.030000 ┆ 20.237186 ┆ … ┆ 50.657886 ┆ 59.320744 ┆ 46.065861 ┆ 24.31945 │
# │ 8         ┆           ┆ 686645508 ┆ 431884766 ┆   ┆ 50512695  ┆           ┆           ┆ 03784179 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 7        │
# │ 2024-05-2 ┆ 63.414223 ┆ 21.110000 ┆ 20.227298 ┆ … ┆ 50.490547 ┆ 58.433125 ┆ 45.606804 ┆ 24.15015 │
# │ 9         ┆           ┆ 610351562 ┆ 736572266 ┆   ┆ 18017578  ┆           ┆           ┆ 60211181 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 64       │
# │ 2024-05-3 ┆ 64.256973 ┆ 21.319999 ┆ 20.123493 ┆ … ┆ 50.710391 ┆ 58.094036 ┆ 45.859734 ┆ 24.16814 │
# │ 0         ┆           ┆ 69482422  ┆ 194580078 ┆   ┆ 998291016 ┆           ┆           ┆ 61334228 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 5        │
# │ 2024-05-3 ┆ 64.237144 ┆ 21.489999 ┆ 20.029575 ┆ … ┆ 50.955303 ┆ 57.934464 ┆ 46.511967 ┆ 24.19245 │
# │ 1         ┆           ┆ 771118164 ┆ 34790039  ┆   ┆ 19213867  ┆           ┆           ┆ 52917480 │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 47       │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Data Clean up

# %%
import polars as pl

def clean_data(df):
    # Function to try converting to float
    def try_float(s):
        try:
            return float(s)
        except ValueError:
            return s  # Return the original value if it can't be converted

    # Identify columns that are strings
    string_cols = [col for col, dtype in df.schema.items() if dtype == pl.String]
    
    for col in string_cols:
        # Try to convert the column to float
        df = df.with_columns(pl.col(col).apply(try_float))
        
        # Check if all values in the column are now float
        if df[col].dtype == pl.Float64:
            print(f"Column {col} successfully converted to Float64.")
        else:
            print(f"Column {col} contains non-numeric values and will remain as its original type.")

    return df

# Clean the data
cleaned_data = clean_data(data)

# Print schema to verify changes
print("\nUpdated Schema:")
print(cleaned_data.schema)

# Print the first few rows of the cleaned data
print("\nFirst few rows of cleaned data:")
print(cleaned_data.head())

# Count of float columns
float_cols = [col for col, dtype in cleaned_data.schema.items() if dtype == pl.Float64]
print(f"\nNumber of Float64 columns: {len(float_cols)}")
# Out:
# Column Date contains non-numeric values and will remain as its original type.
# Column AAPB successfully converted to Float64.
# Column AAPD successfully converted to Float64.
# Column AAPU successfully converted to Float64.
# Column ABCS successfully converted to Float64.
# Column AGMI successfully converted to Float64.
# Column AIPI successfully converted to Float64.
# Column AIRL successfully converted to Float64.
# Column AMDL successfully converted to Float64.
# Column AMDS successfully converted to Float64.
# Column AMID successfully converted to Float64.
# Column AMZD successfully converted to Float64.
# Column AMZU successfully converted to Float64.
# Column AMZZ successfully converted to Float64.
# Column AOTG successfully converted to Float64.
# Column AQWA successfully converted to Float64.
# Column ARVR successfully converted to Float64.
# Column AUMI successfully converted to Float64.
# Column AVXC successfully converted to Float64.
# Column BABX successfully converted to Float64.
# Column BDGS successfully converted to Float64.
# Column BEEZ successfully converted to Float64.
# Column BELT successfully converted to Float64.
# Column BGRO successfully converted to Float64.
# Column BITS successfully converted to Float64.
# Column BKCH successfully converted to Float64.
# Column BKIV successfully converted to Float64.
# Column BKWO successfully converted to Float64.
# Column BLCR successfully converted to Float64.
# Column BLLD successfully converted to Float64.
# Column BMDL successfully converted to Float64.
# Column BOTT successfully converted to Float64.
# Column BRHY successfully converted to Float64.
# Column BRNY successfully converted to Float64.
# Column BRRR successfully converted to Float64.
# Column BRTR successfully converted to Float64.
# Column BSCT successfully converted to Float64.
# Column BSCU successfully converted to Float64.
# Column BSCV successfully converted to Float64.
# Column BSCW successfully converted to Float64.
# Column BSCX successfully converted to Float64.
# Column BSCY successfully converted to Float64.
# Column BSJR successfully converted to Float64.
# Column BSJS successfully converted to Float64.
# Column BSJT successfully converted to Float64.
# Column BSJU successfully converted to Float64.
# Column BSJV successfully converted to Float64.
# Column BSJW successfully converted to Float64.
# Column BSMO successfully converted to Float64.
# Column BSMP successfully converted to Float64.
# Column BSMQ successfully converted to Float64.
# Column BSMR successfully converted to Float64.
# Column BSMS successfully converted to Float64.
# Column BSMT successfully converted to Float64.
# Column BSMU successfully converted to Float64.
# Column BSMV successfully converted to Float64.
# Column BSMW successfully converted to Float64.
# Column BSSX successfully converted to Float64.
# Column BSVO successfully converted to Float64.
# Column BTF successfully converted to Float64.
# Column BTFX successfully converted to Float64.
# Column BUFC successfully converted to Float64.
# Column BUG successfully converted to Float64.
# Column BULD successfully converted to Float64.
# Column CA successfully converted to Float64.
# Column CAFG successfully converted to Float64.
# Column CALY successfully converted to Float64.
# Column CANC successfully converted to Float64.
# Column CANQ successfully converted to Float64.
# Column CCSB successfully converted to Float64.
# Column CCSO successfully converted to Float64.
# Column CEFA successfully converted to Float64.
# Column CHPS successfully converted to Float64.
# Column CLOA successfully converted to Float64.
# Column CLOD successfully converted to Float64.
# Column CLSM successfully converted to Float64.
# Column CONL successfully converted to Float64.
# Column COPJ successfully converted to Float64.
# Column COPP successfully converted to Float64.
# Column COWG successfully converted to Float64.
# Column COWS successfully converted to Float64.
# Column CPLS successfully converted to Float64.
# Column CTEC successfully converted to Float64.
# Column CZAR successfully converted to Float64.
# Column DAPP successfully converted to Float64.
# Column DEMZ successfully converted to Float64.
# Column DFGP successfully converted to Float64.
# Column DFGX successfully converted to Float64.
# Column DGCB successfully converted to Float64.
# Column DIVD successfully converted to Float64.
# Column DMAT successfully converted to Float64.
# Column DMXF successfully converted to Float64.
# Column DTCR successfully converted to Float64.
# Column DVAL successfully converted to Float64.
# Column DWAW successfully converted to Float64.
# Column DWUS successfully converted to Float64.
# Column DYFI successfully converted to Float64.
# Column DYNI successfully converted to Float64.
# Column DYTA successfully converted to Float64.
# Column EDOC successfully converted to Float64.
# Column EFRA successfully converted to Float64.
# Column EHLS successfully converted to Float64.
# Column EKG successfully converted to Float64.
# Column EMXF successfully converted to Float64.
# Column ERET successfully converted to Float64.
# Column ERNZ successfully converted to Float64.
# Column ESMV successfully converted to Float64.
# Column ETEC successfully converted to Float64.
# Column EVMT successfully converted to Float64.
# Column EVSD successfully converted to Float64.
# Column EYEG successfully converted to Float64.
# Column FBL successfully converted to Float64.
# Column FBOT successfully converted to Float64.
# Column FCTE successfully converted to Float64.
# Column FDCF successfully converted to Float64.
# Column FDFF successfully converted to Float64.
# Column FDIF successfully converted to Float64.
# Column FDIG successfully converted to Float64.
# Column FDIV successfully converted to Float64.
# Column FDTX successfully converted to Float64.
# Column FEPI successfully converted to Float64.
# Column FICS successfully converted to Float64.
# Column FINE successfully converted to Float64.
# Column FIXT successfully converted to Float64.
# Column FLDB successfully converted to Float64.
# Column FMED successfully converted to Float64.
# Column FMET successfully converted to Float64.
# Column FTGS successfully converted to Float64.
# Column GFGF successfully converted to Float64.
# Column GGLL successfully converted to Float64.
# Column GGLS successfully converted to Float64.
# Column GINX successfully converted to Float64.
# Column GLOW successfully converted to Float64.
# Column GPIQ successfully converted to Float64.
# Column GPIX successfully converted to Float64.
# Column GSIB successfully converted to Float64.
# Column GTR successfully converted to Float64.
# Column GXTG successfully converted to Float64.
# Column HCOW successfully converted to Float64.
# Column HERO successfully converted to Float64.
# Column HIDE successfully converted to Float64.
# Column HLAL successfully converted to Float64.
# Column HQGO successfully converted to Float64.
# Column HRTS successfully converted to Float64.
# Column HYDR successfully converted to Float64.
# Column IBAT successfully converted to Float64.
# Column IBBQ successfully converted to Float64.
# Column IBGA successfully converted to Float64.
# Column IBGK successfully converted to Float64.
# Column IBIT successfully converted to Float64.
# Column IBOT successfully converted to Float64.
# Column IBTE successfully converted to Float64.
# Column IBTF successfully converted to Float64.
# Column IBTG successfully converted to Float64.
# Column IBTH successfully converted to Float64.
# Column IBTI successfully converted to Float64.
# Column IBTJ successfully converted to Float64.
# Column IBTK successfully converted to Float64.
# Column IBTL successfully converted to Float64.
# Column IBTM successfully converted to Float64.
# Column IBTO successfully converted to Float64.
# Column IBTP successfully converted to Float64.
# Column ICOP successfully converted to Float64.
# Column IHYF successfully converted to Float64.
# Column ILIT successfully converted to Float64.
# Column INDH successfully converted to Float64.
# Column INFR successfully converted to Float64.
# Column INRO successfully converted to Float64.
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# ...
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: DeprecationWarning: `apply` is deprecated. It has been renamed to `map_elements`.
#   df = df.with_columns(pl.col(col).apply(try_float))
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/3318089774.py:16: MapWithoutReturnDtypeWarning: Calling `map_elements` without specifying `return_dtype` can lead to unpredictable results. Specify `return_dtype` to silence this warning.
#   df = df.with_columns(pl.col(col).apply(try_float))

# %%
cleaned_data
# Out:
# shape: (1_363, 645)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ Date      ┆ AADR      ┆ AAPB      ┆ AAPD      ┆ … ┆ XFIX      ┆ XT        ┆ YLDE      ┆ ZZZ      │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2019-01-0 ┆ 37.611717 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 31.699696 ┆ 23.761585 ┆ 0.0      │
# │ 2         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 37.192055 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 30.861729 ┆ 23.422527 ┆ 0.0      │
# │ 3         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 38.637585 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 31.918707 ┆ 23.999849 ┆ 0.0      │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.094543 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 32.404339 ┆ 24.228937 ┆ 0.0      │
# │ 7         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2019-01-0 ┆ 39.365005 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 32.58527  ┆ 24.250927 ┆ 0.0      │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 2024-05-2 ┆ 63.126698 ┆ 20.99     ┆ 20.237186 ┆ … ┆ 50.850384 ┆ 59.230984 ┆ 46.30584  ┆ 24.38761 │
# │ 4         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 3        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-2 ┆ 63.562946 ┆ 21.030001 ┆ 20.237186 ┆ … ┆ 50.657887 ┆ 59.320744 ┆ 46.065861 ┆ 24.31945 │
# │ 8         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-2 ┆ 63.414223 ┆ 21.110001 ┆ 20.227299 ┆ … ┆ 50.490547 ┆ 58.433125 ┆ 45.606804 ┆ 24.15015 │
# │ 9         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-3 ┆ 64.256973 ┆ 21.32     ┆ 20.123493 ┆ … ┆ 50.710392 ┆ 58.094036 ┆ 45.859734 ┆ 24.16814 │
# │ 0         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 2024-05-3 ┆ 64.237144 ┆ 21.49     ┆ 20.029575 ┆ … ┆ 50.955303 ┆ 57.934464 ┆ 46.511967 ┆ 24.19245 │
# │ 1         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 5        │
# │ 00:00:00  ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# ## Feature Engineering

# %%
# import polars as pl
# import numpy as np

# # Assuming 'cleaned_data' is your DataFrame
# float_columns = [col for col, dtype in zip(cleaned_data.columns, cleaned_data.dtypes) if dtype == pl.Float64 and col != 'Date']

# # Calculate percentage change, mean returns, and volatility for each column
# returns = []
# volatility = []
# for col in float_columns:
#     pct_change = cleaned_data.select(pl.col(col)).with_columns(pl.col(col).pct_change().alias("pct_change"))
#     returns.append(pct_change.select(pl.mean("pct_change")).to_numpy()[0, 0] * 255)  # Annualized return
#     volatility.append(pct_change.select(pl.std("pct_change")).to_numpy()[0, 0] * np.sqrt(255))  # Annualized volatility

# # Create DataFrame with Returns and Volatility information
# df_returns = pl.DataFrame({
#     'ETF': float_columns,
#     'Returns': returns,
#     'Volatility': volatility
# })

# print("DataFrame with Returns and Volatility:")
# print(df_returns.tail())

# %%
import yfinance as yf

data_pd = yf.download(symbols, start=start_date, end=end_date)['Adj Close']
print(data_pd.head())
# Out:
# [*********************100%%**********************]  644 of 644 completed
# 19 Failed downloads:
# ['EVSD', 'BSCY', 'IBTP', 'BELT', 'BMDL', 'QQQT', 'AIPI', 'QXQ', 'QBUF', 'METU', 'BGRO', 'BSJW', 'TMET', 'GLOW', 'BRHY', 'FCTE', 'IBGA', 'IBGK', 'METD']: Exception("%ticker%: Data doesn't exist for startDate = 1546318800, endDate = 1717214400")
#                           AADR  AAPB  AAPD  AAPU       AAXJ  ABCS       ACWI  \
# Date
# 2019-01-02 00:00:00  37.611721   NaN   NaN   NaN  57.365273   NaN  57.852901
# 2019-01-03 00:00:00  37.192055   NaN   NaN   NaN  56.010468   NaN  56.869743
# 2019-01-04 00:00:00  38.637573   NaN   NaN   NaN  57.856270   NaN  58.682724
# 2019-01-07 00:00:00  39.094547   NaN   NaN   NaN  58.201794   NaN  59.043522
# 2019-01-08 00:00:00  39.365005   NaN   NaN   NaN  58.356354   NaN  59.476467
#
#                           ACWX  AGMI       AGNG  ...  WISE  WNDY       WOOD  \
# Date                                             ...
# 2019-01-02 00:00:00  35.929508   NaN  18.078402  ...   NaN   NaN  51.865036
# 2019-01-03 00:00:00  35.594364   NaN  18.043734  ...   NaN   NaN  51.638756
# 2019-01-04 00:00:00  36.694336   NaN  18.670582  ...   NaN   NaN  53.449051
# 2019-01-07 00:00:00  36.745899   NaN  19.003746  ...   NaN   NaN  53.783958
# 2019-01-08 00:00:00  36.986534   NaN  19.028782  ...   NaN   NaN  54.290840
#
#                      WRND  WTBN  XBIL  XFIX         XT       YLDE  ZZZ
# Date
# 2019-01-02 00:00:00   NaN   NaN   NaN   NaN  31.699694  23.761585  NaN
# 2019-01-03 00:00:00   NaN   NaN   NaN   NaN  30.861734  23.422529  NaN
# 2019-01-04 00:00:00   NaN   NaN   NaN   NaN  31.918707  23.999846  NaN
# 2019-01-07 00:00:00   NaN   NaN   NaN   NaN  32.404343  24.228939  NaN
# 2019-01-08 00:00:00   NaN   NaN   NaN   NaN  32.585266  24.250931  NaN
#
# [5 rows x 644 columns]

# %%
# Removing columns with any NaN values
data_pd.dropna(axis=1, inplace=True)

# Checking the shape and null values after cleaning
print("Shape after dropping NaNs: ", data_pd.shape)
print("Null Values after dropping NaNs: ", data_pd.isnull().values.any())
data_pd.head()
# Out:
# Shape after dropping NaNs:  (1363, 308)
# Null Values after dropping NaNs:  False
#                           AADR       AAXJ       ACWI       ACWX       AGNG  \
# Date
# 2019-01-02 00:00:00  37.611721  57.365273  57.852901  35.929508  18.078402
# 2019-01-03 00:00:00  37.192055  56.010468  56.869743  35.594364  18.043734
# 2019-01-04 00:00:00  38.637573  57.856270  58.682724  36.694336  18.670582
# 2019-01-07 00:00:00  39.094547  58.201794  59.043522  36.745899  19.003746
# 2019-01-08 00:00:00  39.365005  58.356354  59.476467  36.986534  19.028782
#
#                           AGZD        AIA        AIQ       AIRR      ALTY  \
# Date
# 2019-01-02 00:00:00  18.813507  49.291370  12.734487  21.639994  8.677716
# 2019-01-03 00:00:00  18.773775  47.861713  12.401689  21.451561  8.691306
# 2019-01-04 00:00:00  18.869141  49.552128  12.900887  22.145792  8.808431
# 2019-01-07 00:00:00  18.809540  49.857830  13.145595  22.502821  8.988329
# 2019-01-08 00:00:00  18.908867  49.722954  13.272841  22.790424  9.078921
#
#                      ...        VTWG       VTWO       VTWV       VWOB  \
# Date                 ...
# 2019-01-02 00:00:00  ...  117.246964  50.260654  84.563377  57.170990
# 2019-01-03 00:00:00  ...  115.129028  49.308140  84.382965  57.323933
# 2019-01-04 00:00:00  ...  119.461182  51.134186  86.574844  57.469261
# 2019-01-07 00:00:00  ...  122.378151  52.096012  87.702377  57.668125
# 2019-01-08 00:00:00  ...  124.361282  52.890545  89.100487  57.668125
#
#                           VXUS       VYMI       WBND       WOOD         XT  \
# Date
# 2019-01-02 00:00:00  40.046913  44.070271  70.805176  51.865036  31.699694
# 2019-01-03 00:00:00  39.596569  43.921253  70.721512  51.638756  30.861734
# 2019-01-04 00:00:00  40.888130  45.160461  70.554161  53.449051  31.918707
# 2019-01-07 00:00:00  41.015587  45.199677  70.916718  53.783958  32.404343
# 2019-01-08 00:00:00  41.312981  45.411442  71.056099  54.290840  32.585266
#
#                           YLDE
# Date
# 2019-01-02 00:00:00  23.761585
# 2019-01-03 00:00:00  23.422529
# 2019-01-04 00:00:00  23.999846
# 2019-01-07 00:00:00  24.228939
# 2019-01-08 00:00:00  24.250931
#
# [5 rows x 308 columns]

# %%
import polars as pl
import numpy as np

# Convert Pandas DataFrame to Polars DataFrame, including resetting the index.
# This is done to convert the Date from the index to a regular column,
# which we don't need for our analysis, thus simplifying the DataFrame structure.
pl_df = pl.from_pandas(data_pd.reset_index())

# Identify columns with floating point data which are typically price data in financial datasets.
# We exclude the 'Date' column because time data is irrelevant for K-means clustering in this context.
# K-means clustering will be used to find patterns in price movements, not time series trends.
float_columns = [col for col, dtype in zip(pl_df.columns, pl_df.dtypes) if isinstance(dtype, pl.Float64) and col != 'Date']

# Initialize lists to store calculated annual returns and volatilities for each stock.
# These metrics are crucial for trading as they provide insights into the risk-return profile of stocks.
returns = []
volatility = []
for col in float_columns:
    # Calculate the percentage change, which is a common financial metric to assess stock performance.
    pct_change = pl_df.select(pl.col(col)).with_columns(pl.col(col).pct_change().alias("pct_change"))
    
    # Calculate and store annualized returns, which normalize returns over a year for comparability.
    # This is crucial for clustering as it standardizes data points, making the K-means algorithm more effective.
    annual_return = pct_change.select(pl.mean("pct_change")).to_numpy() * 255
    returns.append(annual_return[0, 0])  # Extract the scalar from the numpy array
    
    # Calculate and store annualized volatility, a measure of the price variability and thus risk.
    # Higher volatility stocks may cluster differently from lower volatility stocks in K-means.
    annual_volatility = pct_change.select(pl.std("pct_change")).to_numpy() * np.sqrt(255)
    volatility.append(annual_volatility[0, 0])  # Extract the scalar from the numpy array

# Create a new DataFrame containing the returns and volatility of each stock.
# This DataFrame is well-suited for K-means clustering to segment stocks into groups based on their
# risk-return profiles, which can inform investment strategies and risk management.
df_returns = pl.DataFrame({
    'ETF': float_columns,
    'Returns': returns,
    'Volatility': volatility
})

print("DataFrame with Returns and Volatility:")
print(df_returns)
# Out:
# DataFrame with Returns and Volatility:
# shape: (308, 3)
# ┌──────┬───────────┬────────────┐
# │ ETF  ┆ Returns   ┆ Volatility │
# │ ---  ┆ ---       ┆ ---        │
# │ str  ┆ f64       ┆ f64        │
# ╞══════╪═══════════╪════════════╡
# │ AADR ┆ 0.127935  ┆ 0.233968   │
# │ AAXJ ┆ 0.060713  ┆ 0.217516   │
# │ ACWI ┆ 0.139888  ┆ 0.195757   │
# │ ACWX ┆ 0.093164  ┆ 0.194469   │
# │ AGNG ┆ 0.109739  ┆ 0.186009   │
# │ …    ┆ …         ┆ …          │
# │ VYMI ┆ 0.104908  ┆ 0.19083    │
# │ WBND ┆ -0.135238 ┆ 0.320158   │
# │ WOOD ┆ 0.117898  ┆ 0.254531   │
# │ XT   ┆ 0.139008  ┆ 0.227995   │
# │ YLDE ┆ 0.142387  ┆ 0.181442   │
# └──────┴───────────┴────────────┘

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler

# Convert Polars DataFrame to NumPy array for scaling
data_for_scaling = df_returns.select(['Returns', 'Volatility']).to_numpy()

# Initialize and apply StandardScaler
# The scaler adjusts each feature to have zero mean and unit variance,
# which is vital for uniform analysis across different trading instruments,
# ensuring no single asset's characteristics dominate due to scale differences.
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_for_scaling)  # Use the correct data array

# Convert the scaled data back to a Polars DataFrame
# This maintains efficient data operations while ensuring comparability across assets.
scaled_df = pl.DataFrame(scaled_data, schema=['Scaled_Returns', 'Scaled_Volatility'])

# Assuming 'ETF' is a column in the original df_returns you want to keep
df_returns_scaled = df_returns.drop(['Returns', 'Volatility']).with_columns(scaled_df)

# Output the scaled DataFrame
# Scaled features are now ready for clustering or other statistical techniques
# that require standardized input to identify patterns in trading data effectively.
print(df_returns_scaled)

#the goal is to create a scaled version of the original dataframe. However, there are some differences between the code you've shown
#and the original code snippet in the image. Let's break it down:

#The original code uses pandas (pd) and sklearn's StandardScaler, while your code uses polars (pl) and sklearn's StandardScaler.
#The original code scales the entire df_returns dataframe, while your code specifically scales only the 'Returns' and 'Volatility' columns.
#The original code keeps the original column names, while your code renames the scaled columns to 'Scaled_Returns' and 'Scaled_Volatility'.
#The original code preserves the index of df_returns, while the polars approach doesn't explicitly handle the index.
# Out:
# shape: (308, 3)
# ┌──────┬────────────────┬───────────────────┐
# │ ETF  ┆ Scaled_Returns ┆ Scaled_Volatility │
# │ ---  ┆ ---            ┆ ---               │
# │ str  ┆ f64            ┆ f64               │
# ╞══════╪════════════════╪═══════════════════╡
# │ AADR ┆ 0.261167       ┆ 0.194315          │
# │ AAXJ ┆ -0.497126      ┆ 0.030128          │
# │ ACWI ┆ 0.396008       ┆ -0.187025         │
# │ ACWX ┆ -0.131066      ┆ -0.199882         │
# │ AGNG ┆ 0.05591        ┆ -0.284312         │
# │ …    ┆ …              ┆ …                 │
# │ VYMI ┆ 0.001421       ┆ -0.236201         │
# │ WBND ┆ -2.707534      ┆ 1.05449           │
# │ WOOD ┆ 0.147955       ┆ 0.399533          │
# │ XT   ┆ 0.386084       ┆ 0.134712          │
# │ YLDE ┆ 0.424196       ┆ -0.329886         │
# └──────┴────────────────┴───────────────────┘

# %%
import polars as pl
import numpy as np
from sklearn.preprocessing import StandardScaler

# Assuming df_returns is your original Polars DataFrame

# Extract numeric columns for scaling
numeric_cols = ['Returns', 'Volatility']
data_for_scaling = df_returns.select(numeric_cols).to_numpy()

# Initialize and apply StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data_for_scaling)

# Create a new DataFrame with scaled data
df_scaled = pl.DataFrame(
    scaled_data,
    schema=['Returns', 'Volatility']
)

# Add the ETF column back
df_scaled = df_scaled.with_columns(df_returns['ETF'])

# Reorder columns to match original
df_scaled = df_scaled.select(['ETF', 'Returns', 'Volatility'])

print("Scaled DataFrame:")
print(df_scaled)
# Out:
# Scaled DataFrame:
# shape: (308, 3)
# ┌──────┬───────────┬────────────┐
# │ ETF  ┆ Returns   ┆ Volatility │
# │ ---  ┆ ---       ┆ ---        │
# │ str  ┆ f64       ┆ f64        │
# ╞══════╪═══════════╪════════════╡
# │ AADR ┆ 0.261167  ┆ 0.194315   │
# │ AAXJ ┆ -0.497126 ┆ 0.030128   │
# │ ACWI ┆ 0.396008  ┆ -0.187025  │
# │ ACWX ┆ -0.131066 ┆ -0.199882  │
# │ AGNG ┆ 0.05591   ┆ -0.284312  │
# │ …    ┆ …         ┆ …          │
# │ VYMI ┆ 0.001421  ┆ -0.236201  │
# │ WBND ┆ -2.707534 ┆ 1.05449    │
# │ WOOD ┆ 0.147955  ┆ 0.399533   │
# │ XT   ┆ 0.386084  ┆ 0.134712   │
# │ YLDE ┆ 0.424196  ┆ -0.329886  │
# └──────┴───────────┴────────────┘

# %% [markdown]
# ## K-Means Clustering

# %%
# Find the optimum number of clusters

# %% [markdown]
# In the context of trading and financial analysis, finding the optimal number of clusters when using K-means clustering is crucial for several reasons:
#
# 1. **Segmentation of Financial Instruments**: Trading involves a wide range of financial instruments such as stocks, ETFs, bonds, and derivatives. Clustering these into homogeneous groups helps in understanding their behavior under various economic conditions. For example, stocks in one cluster might behave similarly in response to market changes, economic news, or sector-specific shifts. This insight is vital for portfolio diversification and risk management.
#
# 2. **Tailored Strategies**: Different clusters may warrant different trading strategies. For example, a cluster of high-volatility stocks might be suited for short-term, high-risk trading strategies, while a cluster of stable, low-volatility stocks might be more appropriate for long-term investment strategies. Determining the optimal number of clusters helps in crafting strategies that are well-suited to each group's characteristics.
#
# 3. **Risk Management**: By clustering financial instruments based on features like returns and volatility, traders can identify which groups are more likely to experience large fluctuations. This information is critical for managing risk and determining capital allocation. For instance, a cluster identified as high risk might necessitate a different risk management approach compared to a cluster with low-risk profiles.
#
# 4. **Performance Evaluation**: Clusters can serve as benchmarks to evaluate the performance of individual stocks or assets. By comparing an asset's performance to its cluster's average, traders can assess whether it's underperforming or outperforming its peers.
#
# 5. **Efficient Allocation of Resources**: Clustering can help in the efficient allocation of analytical resources. By identifying clusters, analysts can focus their efforts on analyzing the characteristics of a few groups rather than individual assets. This approach is more scalable and can lead to more focused and effective analysis.
#
# ### Finding the Optimal Number of Clusters
#
# The optimal number of clusters is not inherently clear without analysis and can significantly impact the effectiveness of the clustering in trading. Here are a few common methods used to determine the optimal number of clusters:
#
# - **Elbow Method**: This method involves plotting the sum of squared distances of samples to their closest cluster center and looking for an "elbow" where the rate of decrease sharply shifts. The elbow typically suggests a good balance between the number of clusters and the compactness of the clusters, minimizing within-cluster variance.
#
# - **Silhouette Score**: This measure assesses how similar an object is to its own cluster compared to other clusters. A higher silhouette score indicates that objects are well matched to their own cluster and poorly matched to neighboring clusters. The number of clusters that maximizes the average silhouette score is considered optimal.
#
# - **Gap Statistic**: This method compares the total within intra-cluster variation for different values of k with their expected values under null reference distribution of the data. The optimal k is the one that maximizes the gap statistic, indicating a clustering structure that is significantly away from random uniform distribution of points.
#
# Each of these methods provides a different way to quantitatively assess the number of clusters, helping to inform a decision that could significantly affect trading outcomes based on how well the actual market segments are captured by the model.

# %%
df_scaled.head()
# Out:
# shape: (5, 3)
# ┌──────┬───────────┬────────────┐
# │ ETF  ┆ Returns   ┆ Volatility │
# │ ---  ┆ ---       ┆ ---        │
# │ str  ┆ f64       ┆ f64        │
# ╞══════╪═══════════╪════════════╡
# │ AADR ┆ 0.261167  ┆ 0.194315   │
# │ AAXJ ┆ -0.497126 ┆ 0.030128   │
# │ ACWI ┆ 0.396008  ┆ -0.187025  │
# │ ACWX ┆ -0.131066 ┆ -0.199882  │
# │ AGNG ┆ 0.05591   ┆ -0.284312  │
# └──────┴───────────┴────────────┘

# %%
import polars as pl
from sklearn.cluster import KMeans
from kneed import KneeLocator

# Extract the scaled 'Returns' and 'Volatility' data for clustering
# These are key metrics for analyzing ETF performance
X = df_scaled.select(['Returns', 'Volatility']).to_numpy() 

# Define the range of cluster numbers to test
# We're considering 1 to 15 clusters
K = range(1, 15)

# Initialize list to store distortion values for each K
distortions = []

# Iterate through each potential number of clusters
for k in K:
    # Initialize K-means model with k clusters
    # This will group ETFs based on their risk-return profiles
    kmeans = KMeans(n_clusters=k, random_state=42) # Reproducibility. 
    # Setting a fixed random state ensures that the K-means algorithm starts with the same initial centroids every time you run it.
    # When analyzing different sets of ETFs or time periods, a consistent random state allows for more meaningful comparisons 
    
    # Fit the model to our ETF data
    kmeans.fit(X)
    
    # Calculate and store the distortion (inertia) for this clustering
    # Lower distortion indicates tighter clusters of similar ETFs
    distortions.append(kmeans.inertia_)

# Use the Elbow method to find the optimal number of clusters
# This helps in determining how many distinct ETF groups exist in our data
kl = KneeLocator(K, distortions, curve="convex", direction="decreasing")
elbow = kl.elbow

# Print the optimal number of clusters
# This suggests how many different ETF categories we should consider in our portfolio
print(f"Optimum Clusters: {elbow}")
# Out:
# Optimum Clusters: 4

# %% [markdown]
# # Distortions in K-means Clustering
#
# Distortions in K-means clustering refer to the sum of squared distances between each data point and its assigned cluster centroid. This concept is important for understanding the quality and characteristics of the clustering solution. Let's break this down:
#
# ## 1. Definition
# - Distortion is a measure of how much the data points deviate from their cluster centroids.
# - Mathematically, it's the sum of squared Euclidean distances between each point and the centroid of its assigned cluster.
# ## 2. Calculation
# For each cluster:
# 1. Calculate the distance between each point in the cluster and the cluster centroid.
# 2. Square these distances.
# 3. Sum up all these squared distances.
# The total distortion is the sum of these values across all clusters.
# ## 3. Significance
# - Lower distortion generally indicates tighter, more compact clusters.
# - It's used to evaluate the quality of clustering for different values of K (number of clusters).
# ## 4. Use in K-means
# - The K-means algorithm aims to minimize the total distortion across all clusters.
# - Each iteration of K-means reassigns points and recalculates centroids to reduce the overall distortion.
# ## 5. Elbow Method
# - Distortion is often used in the "elbow method" for determining the optimal number of clusters.
# - As K increases, distortion typically decreases (each point is closer to its centroid).
# - The "elbow" in the distortion vs. K plot can indicate a good trade-off between cluster number and distortion.
# ## 6. Limitations
# - Distortion alone doesn't always indicate the best clustering solution.
# - It tends to decrease with more clusters, even if those additional clusters don't represent meaningful divisions in the data.
# ## 7. In Financial Context
# - For clustering financial instruments like ETFs, lower distortion could indicate groups of assets with more similar return and volatility characteristics.
# - However, the interpretation should always consider the financial meaning of the clusters, not just the mathematical measure.
# ## Implementation
# To implement this in your analysis, you would typically:
#
# 1. Run K-means for different values of K.
# 2. Calculate the distortion for each K.
# 3. Plot distortion vs. K.
# 4. Look for an "elbow" point where the rate of distortion decrease slows significantly.
#
# This analysis helps in choosing an appropriate number of clusters that balances between fitting the data well and avoiding overfitting.

# %%
# Fit K-Means Model
k_means = KMeans(n_clusters=elbow, random_state=42)
k_means.fit(X)

# Select only the numeric columns for prediction
X_predict = df_scaled.select(['Returns', 'Volatility']).to_numpy() # need to this way since the ETF column is a string

# Predict clusters
prediction = k_means.predict(X_predict)

# %%
import matplotlib.pyplot as plt
import polars as pl
import numpy as np

# Ensure we have the cluster information
X_predict = df_scaled.select(['Returns', 'Volatility']).to_numpy()
prediction = k_means.predict(X_predict)

# Add predictions to the original dataframe
df_scaled = df_scaled.with_columns(pl.Series(name='Cluster', values=prediction))

# Extract centroids
centroids = k_means.cluster_centers_

# Create the plot
fig, ax = plt.subplots(figsize=(18, 10))

# Scatter plot of ETFs
scatter = ax.scatter(
    df_scaled['Returns'].to_numpy(),
    df_scaled['Volatility'].to_numpy(),
    c=df_scaled['Cluster'].to_numpy(),
    cmap='rainbow',
    alpha=0.7,
    s=50
)

# Plot centroids
ax.scatter(
    centroids[:, 0],
    centroids[:, 1],
    c='black',
    s=200,
    marker='X',
    label='Centroids'
)

# Customize the plot
ax.set_title('K-Means Cluster Analysis Results of ETFs', fontsize=16)
ax.set_xlabel('Mean Return', fontsize=12)
ax.set_ylabel('Volatility', fontsize=12)
plt.colorbar(scatter, label='Cluster')
ax.legend()

# Add ETF labels
for i, etf in enumerate(df_scaled['ETF'].to_numpy()):
    ax.annotate(etf, (df_scaled['Returns'][i], df_scaled['Volatility'][i]), fontsize=8)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.widgets import RectangleSelector, Button
import polars as pl
import numpy as np
import mplcursors

# Assuming df_scaled is your Polars DataFrame with the data
# and k_means is your fitted KMeans model

# Create the plot
fig, ax = plt.subplots(figsize=(14, 10))

# Scatter plot of ETFs
scatter = ax.scatter(
    df_scaled['Returns'].to_numpy(),
    df_scaled['Volatility'].to_numpy(),
    c=df_scaled['Cluster'].to_numpy(),
    cmap='rainbow',
    alpha=0.7,
    s=50
)

# Plot centroids
centroids = k_means.cluster_centers_
ax.scatter(
    centroids[:, 0],
    centroids[:, 1],
    c='black',
    s=200,
    marker='X',
    label='Centroids'
)

# Customize the plot
ax.set_title('K-Means Cluster Analysis Results of ETFs', fontsize=16)
ax.set_xlabel('Mean Return', fontsize=12)
ax.set_ylabel('Volatility', fontsize=12)
plt.colorbar(scatter, label='Cluster')
ax.legend()

# Function to handle zooming
def line_select_callback(eclick, erelease):
    x1, y1 = eclick.xdata, eclick.ydata
    x2, y2 = erelease.xdata, erelease.ydata
    ax.set_xlim(min(x1, x2), max(x1, x2))
    ax.set_ylim(min(y1, y2), max(y1, y2))
    fig.canvas.draw_idle()

# Function to reset zoom
def reset_zoom(event):
    ax.autoscale(True)
    ax.relim()
    ax.autoscale_view()
    fig.canvas.draw_idle()

# Set up RectangleSelector for zooming
rs = RectangleSelector(ax, line_select_callback, useblit=True,
                       button=[1],  # use only the main mouse button
                       minspanx=5, minspany=5,
                       spancoords='pixels',
                       interactive=True)

# Add a button for resetting zoom
reset_button_ax = fig.add_axes([0.85, 0.01, 0.1, 0.05])
reset_button = Button(reset_button_ax, 'Reset Zoom')
reset_button.on_clicked(reset_zoom)

# Add hover functionality
cursor = mplcursors.cursor(scatter, hover=True)

@cursor.connect("add")
def on_add(sel):
    i = sel.target.index
    etf = df_scaled['ETF'][i]
    returns = df_scaled['Returns'][i]
    volatility = df_scaled['Volatility'][i]
    cluster = df_scaled['Cluster'][i]
    sel.annotation.set_text(f"ETF: {etf}\nReturns: {returns:.4f}\nVolatility: {volatility:.4f}\nCluster: {cluster}")

# Add instructions to the plot
instructions = """
Zoom: Click and drag
Reset: Use 'Reset Zoom' button
or double-click
Hover: Move cursor over points
"""
fig.text(0.01, 0.01, instructions, fontsize=10, verticalalignment='bottom')

# Function to handle double click for resetting zoom
def on_double_click(event):
    if event.dblclick:
        reset_zoom(event)

fig.canvas.mpl_connect('button_press_event', on_double_click)

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# /var/folders/4w/6x3yk1r13xvcwchd72ftlnsc0000gn/T/ipykernel_60372/1274910081.py:97: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
import polars as pl

# Create a Polars DataFrame directly from the ETF names and cluster labels
df = pl.DataFrame({
    'ETF': df_scaled['ETF'],
    'Cluster': k_means.labels_.flatten()
})

# Keep the complete series (equivalent to clustered_series_all)
clustered_series_all = df

# Filter out rows where 'Cluster' is -1
clustered_series = df.filter(pl.col('Cluster') != -1)

# Display the first 15 entries of the filtered DataFrame
print(clustered_series.head(15))

# To display the entire unfiltered series
print(clustered_series_all.head(15))
# Out:
# shape: (15, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AADR ┆ 0       │
# │ AAXJ ┆ 0       │
# │ ACWI ┆ 0       │
# │ ACWX ┆ 0       │
# │ AGNG ┆ 0       │
# │ …    ┆ …       │
# │ ANGL ┆ 1       │
# │ ASET ┆ 0       │
# │ BBH  ┆ 0       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# └──────┴─────────┘
# shape: (15, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AADR ┆ 0       │
# │ AAXJ ┆ 0       │
# │ ACWI ┆ 0       │
# │ ACWX ┆ 0       │
# │ AGNG ┆ 0       │
# │ …    ┆ …       │
# │ ANGL ┆ 1       │
# │ ASET ┆ 0       │
# │ BBH  ┆ 0       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# └──────┴─────────┘

# %%
import matplotlib.pyplot as plt

# Calculate cluster counts
cluster_counts = clustered_series.get_column('Cluster').value_counts().sort('Cluster')

# Create the plot
plt.figure(figsize=(10, 5))
plt.bar(cluster_counts['Cluster'], cluster_counts['count'])  # Note: 'count' instead of 'counts'

# Set labels and title
plt.title("Clusters")
plt.xlabel("Cluster")
plt.ylabel("Features Count")

# Show the plot
plt.show()

# %%
# Remove items if preferred
clusters_clean = clustered_series.filter(pl.col('Cluster') > .5)

print("Feature Number Previous: ", len(clustered_series))
print("Feature Number Current: ", len(clusters_clean))
# Out:
# Feature Number Previous:  308
# Feature Number Current:  92

# %%
clusters_clean
# Out:
# shape: (92, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AGZD ┆ 1       │
# │ AIRR ┆ 3       │
# │ ANGL ┆ 1       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# │ …    ┆ …       │
# │ VRIG ┆ 1       │
# │ VTC  ┆ 1       │
# │ VTIP ┆ 1       │
# │ VWOB ┆ 1       │
# │ WBND ┆ 2       │
# └──────┴─────────┘

# %% [markdown]
# # Calculating Cointegrated Pairs

# %%
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint

def calculate_cointegration(series1, series2):
    """
    Calculates whether two financial assets are cointegrated, providing key parameters for pairs trading.
    
    Parameters:
    series1 (array-like): Price series of the first asset.
    series2 (array-like): Price series of the second asset.

    Returns:
    coint_flag (int): Indicates if the pair is cointegrated (1 if yes, 0 if no).
    hedge_ratio (float): Ratio used to hedge positions between the two assets.
    """

    # Perform cointegration test using statsmodels
    coint_res = coint(series1, series2)
    coint_t = coint_res[0]  # Test statistic
    p_value = coint_res[1]  # P-value of the test statistic
    critical_value = coint_res[2][1]  # 5% critical value

    # Conduct linear regression to determine the hedge ratio
    series1 = sm.add_constant(series1)  # Add a constant for the intercept
    model = sm.OLS(series2, series1).fit()
    hedge_ratio = model.params[1]  # Hedge ratio from the regression slope

    # Evaluate cointegration based on p-value and test statistic against critical value
    coint_flag = 1 if p_value < 0.05 and coint_t < critical_value else 0

    # Notify the user that the cointegration calculation is complete
    print("Cointegration calculation complete. Cointegration Flag:", coint_flag, "Hedge Ratio:", hedge_ratio)

    return coint_flag, hedge_ratio

# %%
import polars as pl

def loop_through_and_calculate_cointegration(clusters_clean, data):
    tested_pairs = []
    cointegrated_pairs = []

    # Fetch the list of unique ETFs from the clusters_clean DataFrame
    etf_names = clusters_clean.get_column('ETF').to_list() # uses .to_list because polars has issues working with strings and numerics

    # Iterate over each ETF as the base asset
    for base_asset in etf_names:
        # Retrieve the cluster label for the base asset
        base_label = clusters_clean.filter(pl.col('ETF') == base_asset).select('Cluster').to_series()[0]

        # Iterate over each ETF again as the compare asset
        for compare_asset in etf_names:
            if base_asset != compare_asset:
                compare_label = clusters_clean.filter(pl.col('ETF') == compare_asset).select('Cluster').to_series()[0]

                # Only compare assets within the same cluster
                if base_label == compare_label:
                    # Create a sorted tuple of the pair to ensure uniqueness
                    test_pair = tuple(sorted((base_asset, compare_asset)))

                    if test_pair not in tested_pairs:
                        tested_pairs.append(test_pair)

                        # Access the time series data for both ETFs from the data DataFrame
                        # Extracting data for all dates (assuming data is already aligned)
                        series1 = data.get_column(base_asset).to_numpy().astype(float)
                        series2 = data.get_column(compare_asset).to_numpy().astype(float)

                        # Calculate cointegration; the function needs to be defined to accept these series
                        coint_flag, hedge_ratio = calculate_cointegration(series1, series2)

                        # If the assets are cointegrated, add them to the list of cointegrated pairs
                        if coint_flag == 1:
                            cointegrated_pairs.append({
                                "base_asset": base_asset,
                                "compare_asset": compare_asset,
                                "label": base_label
                            })

    # Create a DataFrame from the list of cointegrated pairs
    df_coint = pl.DataFrame(cointegrated_pairs)
    
    # Save the results to a CSV file for further analysis
    df_coint.write_csv('data/cointegrated_pairs.csv')
    print("Calculation and saving of cointegrated pairs complete.")

# Make sure to define or import your calculate_cointegration function that can handle these series.
import polars as pl

def loop_through_and_calculate_cointegration(clusters_clean, data):
    tested_pairs = []
    cointegrated_pairs = []

    # Fetch the list of ETFs from the clusters_clean DataFrame. This list is used to iterate over all possible pairs.
    etf_names = clusters_clean.get_column('ETF').to_list()

    # Iterate over each ETF as the base asset. The base asset will be paired with every other possible compare asset.
    for base_asset in etf_names:
        # Retrieve the cluster label for the base asset. Clustering ETFs often groups them by similar characteristics such as sector or volatility.
        base_label = clusters_clean.filter(pl.col('ETF') == base_asset).select('Cluster').to_series()[0]

        # Iterate over each ETF again to find a suitable compare asset.
        for compare_asset in etf_names:
            if base_asset != compare_asset:
                # Fetch the cluster label for the compare asset to ensure both assets are comparable.
                compare_label = clusters_clean.filter(pl.col('ETF') == compare_asset).select('Cluster').to_series()[0]

                # Only consider pairs within the same cluster to enhance the likelihood that they share similar economic or market dynamics.
                if base_label == compare_label:
                    # Create a sorted tuple to uniquely identify each pair, ensuring no duplicate pair analysis.
                    test_pair = tuple(sorted((base_asset, compare_asset)))

                    if test_pair not in tested_pairs:
                        tested_pairs.append(test_pair)

                        # Access the historical price series data for both ETFs. This is crucial for determining their statistical relationship over time.
                        series1 = data.get_column(base_asset).to_numpy().astype(float)
                        series2 = data.get_column(compare_asset).to_numpy().astype(float)

                        # Calculate cointegration to determine if the pair has a statistically significant long-term equilibrium relationship.
                        coint_flag, hedge_ratio = calculate_cointegration(series1, series2)

                        # If the assets are found to be cointegrated, it implies a stable long-term relationship where the spread between them is mean-reverting.
                        if coint_flag == 1:
                            cointegrated_pairs.append({
                                "base_asset": base_asset,
                                "compare_asset": compare_asset,
                                "label": base_label
                            })

    # Compile the findings into a DataFrame for easy analysis and storage.
    df_coint = pl.DataFrame(cointegrated_pairs)
    
    # Save the results to a CSV file for further analysis or for use in trading strategies.
    df_coint.write_csv('data/cointegrated_pairs.csv')
    print("Calculation and saving of cointegrated pairs complete.")

# Ensure that the calculate_cointegration function is defined in your environment.
# This function should be able to handle the price series and calculate the cointegration flag and hedge ratio.

# %%
print(clusters_clean.head())
print(data.head())
# Out:
# shape: (5, 2)
# ┌──────┬─────────┐
# │ ETF  ┆ Cluster │
# │ ---  ┆ ---     │
# │ str  ┆ i32     │
# ╞══════╪═════════╡
# │ AGZD ┆ 1       │
# │ AIRR ┆ 3       │
# │ ANGL ┆ 1       │
# │ BGRN ┆ 1       │
# │ BIB  ┆ 3       │
# └──────┴─────────┘
# shape: (5, 645)
# ┌─────────────────────┬───────────┬──────┬──────┬───┬──────┬───────────┬───────────┬─────┐
# │ Date                ┆ AADR      ┆ AAPB ┆ AAPD ┆ … ┆ XFIX ┆ XT        ┆ YLDE      ┆ ZZZ │
# │ ---                 ┆ ---       ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---       ┆ ---       ┆ --- │
# │ str                 ┆ f64       ┆ str  ┆ str  ┆   ┆ str  ┆ f64       ┆ f64       ┆ str │
# ╞═════════════════════╪═══════════╪══════╪══════╪═══╪══════╪═══════════╪═══════════╪═════╡
# │ 2019-01-02 00:00:00 ┆ 37.611717 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 31.699696 ┆ 23.761585 ┆ 0   │
# │ 2019-01-03 00:00:00 ┆ 37.192055 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 30.861729 ┆ 23.422527 ┆ 0   │
# │ 2019-01-04 00:00:00 ┆ 38.637585 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 31.918707 ┆ 23.999849 ┆ 0   │
# │ 2019-01-07 00:00:00 ┆ 39.094543 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 32.404339 ┆ 24.228937 ┆ 0   │
# │ 2019-01-08 00:00:00 ┆ 39.365005 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 32.58527  ┆ 24.250927 ┆ 0   │
# └─────────────────────┴───────────┴──────┴──────┴───┴──────┴───────────┴───────────┴─────┘

# %%
loop_through_and_calculate_cointegration(clusters_clean, data)
# Out:
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8077132468399708
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.1673785179081768
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.8809332617097354
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.608752397172768
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.0439508863769495
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6717772356261635
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4975120475785925
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3422456512076159
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2905036924827116
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23376601523678947
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1297196543929842
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5874940295724396
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.266209637145029
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.803598122202577
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3455752115476134
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.827424961992365
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2395856819158444
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.4646321386697814
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7877609149981413
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7219700757801537
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2500073793096117
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.3476128753870729
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.500498987852396
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7891088979615141
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.6035404851785982
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.277938625734429
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.941908837471335
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.4417443057073316
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -2.437717383920728
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.197219591695684
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9433531402270355
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3826398003764153
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5810708032332195
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5643644961465215
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -5.243323900711099
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -2.483120735471163
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.6782036699834668
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.03949342179736548
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -4.812092423411662
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.927242735259107
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -3.7055598649799926
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4027549461940987
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8701822687677867
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6684539853081185
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -3.2487731784789284
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.15208075821491018
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6794554219750263
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6601804634532459
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.6129709286239904
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 3.2356571877996037
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4476928878026624
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5333760217628277
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0132693459357007
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36229426057163067
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3500182410673736
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -16.460400654349346
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.4325762035028492
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.4823430139264024
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8107236050818651
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.26524586963168967
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -3.637932066801684
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3413754095223704
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.5544349092929395
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -9.189561073637067
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.39741034642226
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.5465703974336291
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4689853869604202
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -2.8369329140424737
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.304950130699453
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8763657429482645
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.1069315529312185
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8002338399772347
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.009978181507319392
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2709848510021378
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4985066054985668
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.373406980411196
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7093356332633374
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7583989663153774
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7509726578218463
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6183171427652283
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.204185157658259
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06140749264176442
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.4884093413141137
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.4714148106421483
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9393006356638284
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4132853874070773
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3023841726497178
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5302338408840166
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40957567554014657
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2239619060079788
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3251353575723382
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32193329614582344
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3220486932366098
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.33600892470646676
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3549842750119922
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4454009192482984
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5466382468689985
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5065943637683383
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.533773487934184
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7625074267637236
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1366858476161255
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3196584694145026
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.790542591454693
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9402353258110885
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7235232477299022
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13186526472035767
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4090165178345077
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6805452987677448
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9858215677074865
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37166487381025837
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9338539909207902
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4120768612064414
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.056266951066670595
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.010463034995897567
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8020166982047452
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6575888778258222
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8496221686489559
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9340392370370799
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4192335269333812
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19170112422077926
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5309294586860007
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.24907095666224835
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.821483394688413
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13498491647000724
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5922268130481075
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.0628865896294007
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4114698462497842
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4132064255232655
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2625728620354173
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23696711341691765
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.42459712776868114
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7909675416537529
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.45631503050521466
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0633159208400746
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6041029498984258
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.39793114364100357
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7101740545136952
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5165660636114089
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.25755991368598063
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32972834220575675
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.6135355759251769
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5593832983279138
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7631078134484548
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6520962765968074
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2292962663747484
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4765384992451775
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8599548789719128
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2607566222972601
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2990562139513252
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.30336604564590336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11602652025666883
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5407439591930041
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.48272247832651677
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.31578014568954343
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1252367733441926
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7954050423950166
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8610803552664139
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5239113574144305
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.3340755641975348
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.8834400722305339
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.0990042356758078
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1721257377819141
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23902913790027058
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27376385176940793
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.32894246513592845
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.025324413821924466
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.06745848765065075
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.024927686195683387
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1052499884163401
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0124883253451059
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.4185598424857178
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0833363222108008
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.6937266204963531
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18884434100654274
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5018881220966803
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5459369838021393
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0442219173650102
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5648265930560589
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6028535876442516
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1757077637691257
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2882651913440937
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1742847137536381
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.7680480957329181
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1129228904853117
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11257036643466833
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23918534566203437
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3466878686336129
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3960294014265387
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.17453889466177933
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.6783313818826415
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9277348285979081
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7040096856440515
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.039710977457648
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9733929129000756
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36140856612694333
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.7323736039246511
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37890871385440955
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9006174598266625
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17241333570864342
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7972610221358623
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.34663838042671286
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40489941729864276
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2798641172396345
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22939938742428403
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.30269988195494535
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.43903542429066944
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6489014105063408
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2525865611630798
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1854472718728709
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5553527784474979
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.715312447099099
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8479998539823225
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1357810046917833
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.052964241853929506
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.6460211640591411
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.292488653962496
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5402489997037576
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0881086132948392
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.8735481375419845
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3014669264181336
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.87335787520579
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.16300917864144612
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3035466064705596
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12856606369257007
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.764439826675515
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.17311599463481891
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.5511475849046277
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2762837449145219
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.16976881131858262
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6220948760016067
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3330122520929317
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3234679638765403
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.26763854256594594
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7035380766380808
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7999430916413861
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13851883367220438
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36184353255997165
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5198517869994946
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6872697404533472
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.11799541161327784
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.33566103032856637
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 16.06085712242451
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8102591606295595
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8512713217936246
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5449266225929562
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07444331699035492
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12110721705921959
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.16381270460073638
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18447953088836527
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21802073334394703
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.011231532530470363
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.04101389670360569
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.013268474624911111
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12555821700199796
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.028904733852344017
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.429146647996131
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6559349638590746
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.368211046417211
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13375676368056705
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3133878629668023
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.28397351582142977
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6854902554191965
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3561799401568029
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37626477451577184
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12159680977239722
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1808863353031919
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10907468499748611
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4905346721985984
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7401176192420397
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.05664909104969089
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17170501771637023
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21640562750044487
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2502882800071383
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12334027248099153
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7758031962865646
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.2734210902599108
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4004941138920745
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6758301851378671
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1999623421963324
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.24225764334865071
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.0419267707446198
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.25065182982335127
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5875615710588853
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.10639718222173455
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1513562299576812
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21647641407834742
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2596809703237227
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13166728963193988
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.23404687040019329
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.18878207700846925
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.29420424606068163
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4321908813437068
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1727643721903721
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12279920803272554
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36078992745107047
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.446782381247469
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5545625181777805
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7372492627469375
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.04659390011981012
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.07007096504862
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.1316048884475642
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3605718338043709
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.7220286239165098
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.5671706250008435
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.20352679388877673
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5582707089327426
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09608541239811
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7359092952348508
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.08276817399203125
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1445583923332043
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.06550458519774331
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9226525266449088
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6553637776525437
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07752805948325839
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1320353251221874
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1818943744957236
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.20673920564325676
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2469622485002373
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.013236681500370386
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.052930383592216336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.013770248283770225
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.01285159824101517
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.03307622571318492
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7408275153256645
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7758607388460189
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.48482419411858285
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1407313661370425
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36434630299724063
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3732004091741725
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7879878714807096
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4143136591656306
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4383200840270277
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.13242223240299344
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2181059469794733
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12989029537301766
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.577057333595758
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8499106777000459
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07010538624696495
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.18572077301545686
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2543474240123672
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2905729135008952
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1382651272656911
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.0400321728274027
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.4640251551350782
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5009473469302099
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7775770439249922
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.445677679266146
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27350919129987683
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.258507399133335
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2864803296146524
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6782761028467157
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12776647227422383
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3486227440000031
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2520355803983004
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.29797597672497583
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1845996649743093
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.21867983881439998
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22215006563341796
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3364582480968094
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4899861821195627
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19285540845639768
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13988457291252895
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.41649497955805026
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.122398648111906
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.636481083020256
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8505314519957204
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.0423643854520195
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2319063065202245
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.466361827057099
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.408105533019663
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.8280792029561079
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.9558277507807977
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.23166813446004939
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6551757975103626
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11316180169961686
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.925212802409761
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0982904234492171
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3213649038573176
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.11005730062030215
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1183412995265012
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09597884942384109
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17645281539343144
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.24997872167513485
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.28783049545475686
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3490181021427479
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.017945817704715705
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.08934415673181793
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.015143373467082479
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3206316514124845
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.05164780350468284
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 2.691617157103267
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.155855993390255
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.8170205335689248
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1757933572635182
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5312518295461869
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6240652744456393
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1379251738723182
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6051371236329864
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.640455124858187
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.17910739343637377
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3377779777513985
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1973635781445536
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8581618044464352
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2282615584011178
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.10635442122742722
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.244751053929921
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.37453588607671573
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.42159617102784847
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.19522354406124856
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.9480843088336828
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.115998993508416
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.796480963042382
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1224225686352136
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.211447428031975
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.38382569966533425
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.9296668960506524
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4096196501625022
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9844868661715546
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19380769043771157
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9950580096168788
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36839536653939864
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4260872008676649
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3296094337443994
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22903836899668106
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.3320861729342707
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.48225989144354064
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6930595890089591
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.26613029251088777
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19879553273925765
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6042125890610276
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 7.434604009100389
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9164758407758076
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2324614325167538
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.038478780411975645
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7798678572828495
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.5905480944792822
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5747319902364026
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.19336031967407
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.287396361681499
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3299534951350759
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9714588668260604
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1659309142148114
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4788459294353238
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.14903372394305534
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.916696588177495
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.22572629906900793
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7190317901140664
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0102853017975912
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0244853640518683
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.049080699181051
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1007569702355282
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0959990404047026
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3723747393073016
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2528057782363007
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 8.189098630010694
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2849171529784416
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.9200441504122843
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.4855378176867875
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.716539918837379
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.351060028760459
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8376194435061777
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3219377365125436
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.392471975351089
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7781258693995923
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2383911076449894
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8204651244964893
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3566297813338934
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2452620766282188
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.36474046752455275
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5255644225982219
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5246060355377482
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.6716280598064823
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.097703830231533
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3893300810464098
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9167117962021331
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8538640368647274
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.4356456424565107
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.06721123530698253
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.536615953584344
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.27979651638312736
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.796471981794219
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07210373320992283
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2964781014539761
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.3977110469736038
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8497570592713565
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0760233919952442
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0037689703283232
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8083982376505483
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7798660462823176
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.833417597825159
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9287549089639608
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4163621157202713
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.1986076730992132
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5921999770907067
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.797629125515037
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0431046351285465
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4389245290352313
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7553897967520242
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3579499695481054
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8626099876592725
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.827260257209117
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.710355730971368
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.618006362517873
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2723221771026985
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0803730271277878
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.064970134188951
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5229839728425059
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9937630256512159
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.02483355493401494
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.859266919052095
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.5152740002463654
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.0611541075442457
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2502145632564288
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0694740203191322
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.118089605337804
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.205325320966275
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9210797922554337
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0801926253176357
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.054687367226384
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.9674630616509425
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0268834666496771
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.324072865202913
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.7655635146166833
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9279994388317572
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.122693082016527
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9389317390215712
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6453887771021561
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.067232409781813
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9431782960290833
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.3534826732294625
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.49762530330096805
# ...
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09511345201161549
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3344949996262837
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.08626249585417764
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.04668712454803404
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7774967465748863
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 11.430831763411934
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.8266625676536945
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.828282159779051
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7169254390269602
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.914973271894797
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 9.182653679278438
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.1645123273962663
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.8025221694597766
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.820525747619792
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.427841754125685
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8878126825632917
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1297820705924981
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.2130285595192207
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5681407812682101
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.823569765819709
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4252635045184143
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 4.5895084955675
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 10.690102717671701
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.5402336693940286
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.071838712700535
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3080220351709977
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.0403032615121584
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 5.7737187494521045
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1588578326823358
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.835746298433705
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 6.185867805803492
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5813481158471536
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4120825380171818
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.41520145979499434
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.079100586055961
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10080583635386012
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.2009937311846737
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.045951997708397696
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.6401883207027765
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09611050457178508
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.12644187227814316
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.01831330441711712
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17700512641898994
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.40028410291707944
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.03902300024383715
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1438162584491813
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5740671346257529
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.029460720824310744
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.11350648190545137
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0006255789625151297
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13789636725726057
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.032244687707651834
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.19866806052302033
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.043211090888552336
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1557679369980688
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.039658562308199516
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 1.3273925365364556
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.235121298065746
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.9621656827084122
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.652317600305437
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.769622053624553
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.177540185260119
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.8696019024214308
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.38839481968477
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8863841704966968
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27959022576117715
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2660772821572304
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.04736855296491656
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 2.0451930051165257
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.09137722563505063
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.6448733625788807
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.17768133473212683
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4741839875827478
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.750275519185882
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5830514777856408
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8645241816671625
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.848814753146047
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.28607716137337236
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6603276225011596
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.21730556554801167
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.9839335285676857
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.029002667814240598
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5421025751301118
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06004378829387163
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.272041338766432
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2336712222082742
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8422199952895906
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1395612748402715
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13462811870100977
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -1.463661153733619
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.44860587834407145
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.11631820604540485
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4651302221735839
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.5173481192908941
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5437448154186965
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.998863228294573
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1304306959750454
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.606921111680695
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.814103866634164
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4136818622477
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.572335040900146
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.822992080363308
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.20054054412286473
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4302866907850783
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.15027574914345673
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6181339349559688
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0038074244288102614
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.0342446269314678
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06670456284771409
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8474636879530096
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1719419342755947
# Cointegration calculation complete. Cointegration Flag: 1 Hedge Ratio: 0.3179730370951909
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1313286271033756
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.08908708436863112
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.25051996125980863
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.06119123671496195
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.38420496986672503
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.03251878285674718
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5380629833691161
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.01968339204784232
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.4477122703293246
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8069984250349149
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8055979065085492
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.44302624403179697
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5261371567065483
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.3687916269655646
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6013039649512242
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2087258747815082
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.747693305956216
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5114426599954544
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.357723317793228
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.575683518369868
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2786173281253744
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.7547862645030503
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.07516816603876673
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8468077925086185
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.1313590921525518
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.486647507629816
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.12209340628852347
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.1504059027687306
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.05308750772262266
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.1977967194280753
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.0015048227903242427
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.2346551314768915
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.05475745885446564
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.34887353557913864
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.073064384131796
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.27230757142202705
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.375983435308884
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.42470001720073497
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8707358881777021
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.22497444163852456
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 3.6512961811513187
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6806802280501639
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 2.6607580888779188
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.13011239103006328
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.4627681426770904
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.21115067451066685
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.8341391586970872
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2888440155759761
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.5831785554453397
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.582063802079994
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.16945233861061157
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.153823487831452
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5485397939422043
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.2023217362064864
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.07443713752964816
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.5937619937271561
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.10553662752170442
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.6769979732964544
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.5608188954292452
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 1.7101931418642846
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.5508420193472486
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.027751393023284554
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: 0.8262021013423028
# Cointegration calculation complete. Cointegration Flag: 0 Hedge Ratio: -0.2247810670911666
# Calculation and saving of cointegrated pairs complete.

# %%
#Load Cointegrated Pairs
df_coint = pl.read_csv('data/cointegrated_pairs.csv')
df_coint.head()
# Out:
# shape: (5, 3)
# ┌────────────┬───────────────┬───────┐
# │ base_asset ┆ compare_asset ┆ label │
# │ ---        ┆ ---           ┆ ---   │
# │ str        ┆ str           ┆ i64   │
# ╞════════════╪═══════════════╪═══════╡
# │ AGZD       ┆ FTSM          ┆ 1     │
# │ AGZD       ┆ SHV           ┆ 1     │
# │ AGZD       ┆ VRIG          ┆ 1     │
# │ BGRN       ┆ BNDW          ┆ 1     │
# │ BGRN       ┆ BNDX          ┆ 1     │
# └────────────┴───────────────┴───────┘

# %%
df_coint.tail()
# Out:
# shape: (5, 3)
# ┌────────────┬───────────────┬───────┐
# │ base_asset ┆ compare_asset ┆ label │
# │ ---        ┆ ---           ┆ ---   │
# │ str        ┆ str           ┆ i64   │
# ╞════════════╪═══════════════╪═══════╡
# │ SUSB       ┆ VGSH          ┆ 1     │
# │ SUSC       ┆ UITB          ┆ 1     │
# │ UITB       ┆ USIG          ┆ 1     │
# │ UITB       ┆ VTC           ┆ 1     │
# │ VCLT       ┆ VGIT          ┆ 1     │
# └────────────┴───────────────┴───────┘

# %% [markdown]
# ## TSNE Plot for Visualization

# %%
import polars as pl

# Load the cointegrated pairs from a CSV file
df_coint = pl.read_csv('data/cointegrated_pairs.csv') #turn loaded file into polars dataframe

# Concatenate 'base_asset' and 'compare_asset' into a single Series and then find unique assets
# Use Series.append() for combining two columns from DataFrame into one Series
coint_unique_assets = df_coint['base_asset'].append(df_coint['compare_asset']).unique().sort()


print(coint_unique_assets.head())
# Out:
# shape: (10,)
# Series: 'base_asset' [str]
# [
# 	"AGZD"
# 	"BGRN"
# 	"BIS"
# 	"BND"
# 	"BNDW"
# 	"BNDX"
# 	"BSCS"
# 	"BSJO"
# 	"BSJQ"
# 	"EMB"
# ]

# %%
df_scaled.columns
# Out:
# ['ETF', 'Returns', 'Volatility', 'Cluster']

# %%
# Filters the scaled data to include only those ETFs that have been identified as cointegrated.
df_tsne = df_scaled.filter(pl.col('ETF').is_in(coint_unique_assets))

# Display the head of the DataFrame focusing on cointegrated ETFs
print(df_tsne.head())

# Coding Comments:
# This cell filters the df_scaled DataFrame to retain only those rows where the 'ETF' column
# matches any of the unique ETFs identified as part of cointegrated pairs. This is done using
# Polars' filter() method combined with is_in(), which checks for membership in the 
# coint_unique_assets list.

# Trading Reasoning:
# By focusing on the returns and volatility data of only those ETFs that are cointegrated, this 
# approach streamlines the analysis towards the most relevant data for pairs trading strategies.
# Cointegrated ETFs are likely to revert to their long-term mean, allowing traders to potentially 
# exploit temporary inefficiencies for profit. This focused analysis helps in reducing the risk 
# associated with trading non-cointegrated or less predictable ETF pairs.
# Out:
# shape: (5, 4)
# ┌──────┬───────────┬────────────┬─────────┐
# │ ETF  ┆ Returns   ┆ Volatility ┆ Cluster │
# │ ---  ┆ ---       ┆ ---        ┆ ---     │
# │ str  ┆ f64       ┆ f64        ┆ i32     │
# ╞══════╪═══════════╪════════════╪═════════╡
# │ AGZD ┆ -0.828786 ┆ -1.756146  ┆ 1       │
# │ BGRN ┆ -1.05959  ┆ -1.597027  ┆ 1       │
# │ BIS  ┆ -3.167668 ┆ 2.745099   ┆ 2       │
# │ BND  ┆ -1.07623  ┆ -1.470525  ┆ 1       │
# │ BNDW ┆ -1.091015 ┆ -1.603282  ┆ 1       │
# └──────┴───────────┴────────────┴─────────┘

# %%
from sklearn.manifold import TSNE
import numpy as np

# Ensure only numeric columns are used for t-SNE
numeric_data = df_tsne.select(['Returns', 'Volatility']).to_numpy()

# Configure and apply t-SNE to reduce dimensionality for visualization
tsne = TSNE(learning_rate=30, perplexity=5, random_state=42, n_jobs=-1)
X_tsne = tsne.fit_transform(numeric_data)  # Convert to NumPy array for compatibility with sklearn

# Print the first 5 transformed data points
print(X_tsne[:5])

# Coding Comments:
# Applies t-SNE to the filtered DataFrame to visualize high-dimensional data in two dimensions.
# The 'ETF' column is excluded because t-SNE requires numerical data. We convert the remaining
# numeric columns ('Returns' and 'Volatility') to a NumPy array as sklearn does not support Polars directly.

# Trading Reasoning:
# t-SNE helps in visualizing the relationships and clustering among cointegrated assets, which can aid
# traders in identifying which assets move in a correlated manner. This visualization is crucial for
# selecting pairs that might return to their mean, providing profitable trading opportunities. The 
# method efficiently handles the complexity of financial data, offering insights into potential 
# mean-reverting opportunities within the asset pairs.
# Out:
# [[  7.909174    9.82482  ]
#  [ 22.04926    -7.6356945]
#  [-36.219654   -0.5829276]
#  [ 26.303072   -4.803747 ]
#  [ 22.100767   -9.314317 ]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import networkx as nx

# First, we visualize using t-SNE
plt.figure(figsize=(25, 20))
sns.scatterplot(x=X_tsne[:, 0], y=X_tsne[:, 1], hue=df_tsne['ETF'].to_list(), palette='viridis', s=100)
plt.title('t-SNE Visualization of Cointegrated Pairs')
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.show()

# Coding Comments for t-SNE:
# Uses Seaborn for plotting the t-SNE results, providing a visual clustering of assets based on their
# returns and volatility profiles. The 'hue' parameter is used to color code the different assets,
# allowing for easy identification of clusters.

# Trading Reasoning for t-SNE:
# The visualization aids in identifying natural groupings or clusters among cointegrated assets, which 
# is useful in adjusting pairs trading strategies based on visual insights into which assets behave 
# similarly in terms of price movements and volatility. This helps in selecting assets that might 
# demonstrate mean-reverting behavior, a key aspect of pairs trading strategies.

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph object
G = nx.Graph()

# Adding edges using native Polars operations
edges = df_coint.to_dicts()

# Add nodes and edges from the cointegrated pairs DataFrame
for edge in edges:
    G.add_edge(edge['base_asset'], edge['compare_asset'])

# Position nodes using the spring layout
pos = nx.spring_layout(G, seed=42)  # seed for reproducibility

# Draw the network graph
plt.figure(figsize=(25, 20))
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=1500, edge_color='k', linewidths=1, font_size=10)
plt.title('Network of Cointegrated ETFs')
plt.show()

# Coding Comments:
# NetworkX is used to create a visual representation of connections between ETFs. Each node represents
# an ETF, and each edge represents a cointegration relationship. The spring layout is used to position 
# nodes in a way that minimizes overlaps and clearly shows the connections.

# Trading Reasoning:
# Visualizing the network of ETF relationships can help traders understand how different ETFs are
# interconnected. This network view can be instrumental in identifying central assets that have
# multiple cointegration links, potentially serving as key players in a trading strategy focused on
# stability and mean reversion.

# %% [markdown]
# ## Review Pair

# %%
df_tsne
# Out:
# shape: (50, 4)
# ┌──────┬───────────┬────────────┬─────────┐
# │ ETF  ┆ Returns   ┆ Volatility ┆ Cluster │
# │ ---  ┆ ---       ┆ ---        ┆ ---     │
# │ str  ┆ f64       ┆ f64        ┆ i32     │
# ╞══════╪═══════════╪════════════╪═════════╡
# │ AGZD ┆ -0.828786 ┆ -1.756146  ┆ 1       │
# │ BGRN ┆ -1.05959  ┆ -1.597027  ┆ 1       │
# │ BIS  ┆ -3.167668 ┆ 2.745099   ┆ 2       │
# │ BND  ┆ -1.07623  ┆ -1.470525  ┆ 1       │
# │ BNDW ┆ -1.091015 ┆ -1.603282  ┆ 1       │
# │ …    ┆ …         ┆ …          ┆ …       │
# │ VNQI ┆ -1.053531 ┆ -0.32029   ┆ 1       │
# │ VRIG ┆ -0.775187 ┆ -1.640746  ┆ 1       │
# │ VTC  ┆ -0.902652 ┆ -1.242657  ┆ 1       │
# │ VWOB ┆ -0.907607 ┆ -0.973229  ┆ 1       │
# │ WBND ┆ -2.707534 ┆ 1.05449    ┆ 2       │
# └──────┴───────────┴────────────┴─────────┘

# %%
#Plot price comparison for any given asset
data.head(3)
# Out:
# shape: (3, 645)
# ┌─────────────────────┬───────────┬──────┬──────┬───┬──────┬───────────┬───────────┬─────┐
# │ Date                ┆ AADR      ┆ AAPB ┆ AAPD ┆ … ┆ XFIX ┆ XT        ┆ YLDE      ┆ ZZZ │
# │ ---                 ┆ ---       ┆ ---  ┆ ---  ┆   ┆ ---  ┆ ---       ┆ ---       ┆ --- │
# │ str                 ┆ f64       ┆ str  ┆ str  ┆   ┆ str  ┆ f64       ┆ f64       ┆ str │
# ╞═════════════════════╪═══════════╪══════╪══════╪═══╪══════╪═══════════╪═══════════╪═════╡
# │ 2019-01-02 00:00:00 ┆ 37.611717 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 31.699696 ┆ 23.761585 ┆ 0   │
# │ 2019-01-03 00:00:00 ┆ 37.192055 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 30.861729 ┆ 23.422527 ┆ 0   │
# │ 2019-01-04 00:00:00 ┆ 38.637585 ┆ 0    ┆ 0    ┆ … ┆ 0    ┆ 31.918707 ┆ 23.999849 ┆ 0   │
# └─────────────────────┴───────────┴──────┴──────┴───┴──────┴───────────┴───────────┴─────┘

# %%
data.columns
# Out:
# ['Date',
#  'AADR',
#  'AAPB',
#  'AAPD',
#  'AAPU',
#  'AAXJ',
#  'ABCS',
#  'ACWI',
#  'ACWX',
#  'AGMI',
#  'AGNG',
#  'AGZD',
#  'AIA',
#  'AIPI',
#  'AIQ',
#  'AIRL',
#  'AIRR',
#  'ALTY',
#  'AMDL',
#  'AMDS',
#  'AMID',
#  'AMZD',
#  'AMZU',
#  'AMZZ',
#  'ANGL',
#  'AOTG',
#  'AQWA',
#  'ARVR',
#  'ASET',
#  'AUMI',
#  'AVXC',
#  'BABX',
#  'BBH',
#  'BDGS',
#  'BEEZ',
#  'BELT',
#  'BGRN',
#  'BGRO',
#  'BIB',
#  'BIS',
#  'BITS',
#  'BJK',
#  'BKCH',
#  'BKIV',
#  'BKWO',
#  'BLCN',
#  'BLCR',
#  'BLLD',
#  'BMDL',
#  'BND',
#  'BNDW',
#  'BNDX',
#  'BOTT',
#  'BOTZ',
#  'BRHY',
#  'BRNY',
#  'BRRR',
#  'BRTR',
#  'BSCO',
#  'BSCP',
#  'BSCQ',
#  'BSCR',
#  'BSCS',
#  'BSCT',
#  'BSCU',
#  'BSCV',
#  'BSCW',
#  'BSCX',
#  'BSCY',
#  'BSJO',
#  'BSJP',
#  'BSJQ',
#  'BSJR',
#  'BSJS',
#  'BSJT',
#  'BSJU',
#  'BSJV',
#  'BSJW',
#  'BSMO',
#  'BSMP',
#  'BSMQ',
#  'BSMR',
#  'BSMS',
#  'BSMT',
#  'BSMU',
#  'BSMV',
#  'BSMW',
#  'BSSX',
#  'BSVO',
#  'BTEC',
#  'BTF',
#  'BTFX',
#  'BUFC',
#  'BUG',
#  'BULD',
#  'CA',
#  'CAFG',
#  'CALY',
#  'CANC',
#  'CANQ',
#  'CARZ',
#  'CATH',
#  'CCSB',
#  'CCSO',
#  'CDC',
#  'CDL',
#  'CEFA',
#  'CFA',
#  'CFO',
#  'CHPS',
#  'CIBR',
#  'CID',
#  'CIL',
#  'CIZ',
#  'CLOA',
#  'CLOD',
#  'CLOU',
#  'CLSM',
#  'CNCR',
#  'COMT',
#  'CONL',
#  'COPJ',
#  'COPP',
#  'COWG',
#  'COWS',
#  'CPLS',
#  'CSA',
#  'CSB',
#  'CSF',
#  'CTEC',
#  'CXSE',
#  'CZAR',
#  'DALI',
#  'DAPP',
#  'DAX',
#  'DDIV',
#  'DEMZ',
#  'DFGP',
#  'DFGX',
#  'DGCB',
#  'DGRE',
#  'DGRS',
#  'DGRW',
#  'DIVD',
#  'DMAT',
#  'DMXF',
#  'DRIV',
#  'DTCR',
#  'DVAL',
#  'DVLU',
#  'DVOL',
#  'DVY',
#  'DWAS',
#  'DWAW',
#  'DWSH',
#  'DWUS',
#  'DXJS',
#  'DYFI',
#  'DYNI',
#  'DYTA',
#  'EBIZ',
#  'ECOW',
#  'EDOC',
#  'EEMA',
#  'EFAS',
#  'EFRA',
#  'EHLS',
#  'EKG',
#  'EMB',
#  'EMCB',
#  'EMIF',
#  'EMXC',
#  'EMXF',
#  'ENTR',
#  'ENZL',
#  'EQRR',
#  'ERET',
#  'ERNZ',
#  'ESGD',
#  'ESGE',
#  'ESGU',
#  'ESMV',
#  'ESPO',
#  'ETEC',
#  'EUFN',
#  'EVMT',
#  'EVSD',
#  'EWJV',
#  'EWZS',
#  'EYEG',
#  'FAAR',
#  'FAB',
#  'FAD',
#  'FALN',
#  'FBL',
#  'FBOT',
#  'FBZ',
#  'FCA',
#  'FCAL',
#  'FCEF',
#  'FCTE',
#  'FCVT',
#  'FDCF',
#  'FDFF',
#  'FDIF',
#  'FDIG',
#  'FDIV',
#  'FDNI',
#  'FDT',
#  'FDTS',
#  'FDTX',
#  'FEM',
#  'FEMB',
#  'FEMS',
#  'FEP',
#  'FEPI',
#  'FEUZ',
#  'FEX',
#  'FGM',
#  'FICS',
#  'FID',
#  'FINE',
#  'FINX',
#  'FIXD',
#  'FIXT',
#  'FJP',
#  'FKU',
#  'FLDB',
#  'FLN',
#  'FMB',
#  'FMED',
#  'FMET',
#  'FMHI',
#  'FNK',
#  'FNX',
#  'FNY',
#  'FPA',
#  'FPXE',
#  'FPXI',
#  'FSCS',
#  'FSZ',
#  'FTA',
#  'FTAG',
#  'FTC',
#  'FTCS',
#  'FTDS',
#  'FTGC',
#  'FTGS',
#  'FTHI',
#  'FTQI',
#  'FTRI',
#  'FTSL',
#  'FTSM',
#  'FTXG',
#  'FTXH',
#  'FTXL',
#  'FTXN',
#  'FTXO',
#  'FTXR',
#  'FV',
#  'FVC',
#  'FYC',
#  'FYT',
#  'FYX',
#  'GFGF',
#  'GGLL',
#  'GGLS',
#  'GINX',
#  'GLOW',
#  'GNMA',
#  'GNOM',
#  'GOVI',
#  'GPIQ',
#  'GPIX',
#  'GRID',
#  'GSIB',
#  'GTR',
#  'GXTG',
#  'HCOW',
#  'HERD',
#  'HERO',
#  'HEWG',
#  'HIDE',
#  'HISF',
#  'HLAL',
#  'HNDL',
#  'HQGO',
#  'HRTS',
#  'HYDR',
#  'HYLS',
#  'HYXF',
#  'HYZD',
#  'IBAT',
#  'IBB',
#  'IBBQ',
#  'IBGA',
#  'IBGK',
#  'IBIT',
#  'IBOT',
#  'IBTE',
#  'IBTF',
#  'IBTG',
#  'IBTH',
#  'IBTI',
#  'IBTJ',
#  'IBTK',
#  'IBTL',
#  'IBTM',
#  'IBTO',
#  'IBTP',
#  'ICLN',
#  'ICOP',
#  'IEF',
#  'IEI',
#  'IEUS',
#  'IFGL',
#  'IFV',
#  'IGF',
#  'IGIB',
#  'IGOV',
#  'IGSB',
#  'IHYF',
#  'IJT',
#  'ILIT',
#  'IMCV',
#  'IMOM',
#  'INDH',
#  'INDY',
#  'INFR',
#  'INRO',
#  'IPKW',
#  'IQQQ',
#  'ISHG',
#  'ISHP',
#  'ISTB',
#  'IUS',
#  'IUSB',
#  'IUSG',
#  'IUSV',
#  'IVAL',
#  'IVEG',
#  'IWTR',
#  'IXUS',
#  'JDOC',
#  'JEPQ',
#  'JGLO',
#  'JIVE',
#  'JPEF',
#  'JSMD',
#  'JSML',
#  'JTEK',
#  'KBWB',
#  'KBWD',
#  'KBWP',
#  'KBWR',
#  'KBWY',
#  'KEAT',
#  'KNGZ',
#  'KRMA',
#  'KROP',
#  'LDEM',
#  'LDSF',
#  'LEGR',
#  'LGRO',
#  'LITP',
#  'LMBS',
#  'LRGE',
#  'LRND',
#  'LVHD',
#  'MAGQ',
#  'MAGS',
#  'MAGX',
#  'MAXI',
#  'MBB',
#  'MCHI',
#  'MCHS',
#  'MCSE',
#  'MDCP',
#  'MDIV',
#  'MEDX',
#  'MEMS',
#  'METD',
#  'METU',
#  'MFLX',
#  'MILN',
#  'MKAM',
#  'MNTL',
#  'MODL',
#  'MOOD',
#  'MSFD',
#  'MSFL',
#  'MSFU',
#  'NCPB',
#  'NERD',
#  'NEWZ',
#  'NFTY',
#  'NIKL',
#  'NPFI',
#  'NRES',
#  'NSCR',
#  'NSI',
#  'NTZG',
#  'NUSB',
#  'NVD',
#  'NVDD',
#  'NVDL',
#  'NVDS',
#  'NVDU',
#  'NXTG',
#  'NZAC',
#  'NZUS',
#  'OBIL',
#  'ODDS',
#  'ONEQ',
#  'OPTZ',
#  'OZEM',
#  'PABD',
#  'PABU',
#  'PDBA',
#  'PDBC',
#  'PDP',
#  'PEY',
#  'PEZ',
#  'PFF',
#  'PFI',
#  'PFM',
#  'PGJ',
#  'PHO',
#  'PID',
#  'PIE',
#  'PIO',
#  'PIZ',
#  'PKW',
#  'PNQI',
#  'PPH',
#  'PRFZ',
#  'PRN',
#  'PSC',
#  'PSCC',
#  'PSCD',
#  'PSCE',
#  'PSCF',
#  'PSCH',
#  'PSCI',
#  'PSCM',
#  'PSCT',
#  'PSCU',
#  'PSET',
#  'PSL',
#  'PSTR',
#  'PSWD',
#  'PTEC',
#  'PTF',
#  'PTH',
#  'PTNQ',
#  'PUI',
#  'PXI',
#  'PY',
#  'PYZ',
#  'QABA',
#  'QAT',
#  'QBUF',
#  'QCLN',
#  'QCLR',
#  'QMID',
#  'QMOM',
#  'QOWZ',
#  'QQEW',
#  'QQJG',
#  'QQMG',
#  'QQQ',
#  'QQQA',
#  'QQQE',
#  'QQQI',
#  'QQQJ',
#  'QQQM',
#  'QQQN',
#  'QQQS',
#  'QQQT',
#  'QQQY',
#  'QQXT',
#  'QRMI',
#  'QSML',
#  'QTEC',
#  'QTR',
#  'QVAL',
#  'QXQ',
#  'QYLD',
#  'QYLE',
#  'QYLG',
#  'RAYS',
#  'RDVY',
#  'REAI',
#  'REIT',
#  'RFDI',
#  'RFEM',
#  'RFEU',
#  'RING',
#  'RNEM',
#  'RNEW',
#  'RNRG',
#  'RNSC',
#  'ROBT',
#  'ROE',
#  'RTH',
#  'RUNN',
#  'SARK',
#  'SCZ',
#  'SDG',
#  'SDSI',
#  'SDVY',
#  'SETM',
#  'SFLO',
#  'SHRY',
#  'SHV',
#  'SHY',
#  'SKOR',
#  'SKRE',
#  'SKYU',
#  'SKYY',
#  'SLQD',
#  'SMCF',
#  'SMCO',
#  'SMCP',
#  'SMH',
#  'SMRI',
#  'SNSR',
#  'SOCL',
#  'SOXQ',
#  'SOXX',
#  'SPAM',
#  'SPAQ',
#  'SPBC',
#  'SPC',
#  'SPCX',
#  'SPRX',
#  'SQLV',
#  'SQQQ',
#  'SRET',
#  'SUSB',
#  'SUSC',
#  'SUSL',
#  'TARK',
#  'TBIL',
#  'TCHI',
#  'TDI',
#  'TDIV',
#  'TDSB',
#  'TDSC',
#  'TLT',
#  'TMET',
#  'TQQQ',
#  'TRES',
#  'TSDD',
#  'TSL',
#  'TSLL',
#  'TSLQ',
#  'TSLR',
#  'TSLS',
#  'TSLT',
#  'TSLZ',
#  'TUG',
#  'TUGN',
#  'TUR',
#  'TXSS',
#  'UAE',
#  'UBND',
#  'UCRD',
#  'UCYB',
#  'UEVM',
#  'UFIV',
#  'UFO',
#  'UITB',
#  'UIVM',
#  'ULVM',
#  'UMMA',
#  'UNIY',
#  'UPGR',
#  'URNJ',
#  'USBF',
#  'USCF',
#  'USCL',
#  'USDX',
#  'USFI',
#  'USIG',
#  'USIN',
#  'USMC',
#  'USOY',
#  'USRD',
#  'USSH',
#  'USTB',
#  'USVM',
#  'USVN',
#  'USXF',
#  'UTEN',
#  'UTHY',
#  'UTRE',
#  'UTWO',
#  'UTWY',
#  'VCIT',
#  'VCLT',
#  'VCRB',
#  'VCSH',
#  'VFLO',
#  'VGIT',
#  'VGLT',
#  'VGSH',
#  'VGSR',
#  'VIGI',
#  'VMBS',
#  'VMOT',
#  'VNQI',
#  'VONE',
#  'VONG',
#  'VONV',
#  'VPLS',
#  'VRIG',
#  'VSDA',
#  'VSMV',
#  'VTC',
#  'VTHR',
#  'VTIP',
#  'VTWG',
#  'VTWO',
#  'VTWV',
#  'VWOB',
#  'VXUS',
#  'VYMI',
#  'WABF',
#  'WBND',
#  'WCBR',
#  'WCLD',
#  'WEEI',
#  'WGMI',
#  'WINC',
#  'WISE',
#  'WNDY',
#  'WOOD',
#  'WRND',
#  'WTBN',
#  'XBIL',
#  'XFIX',
#  'XT',
#  'YLDE',
#  'ZZZ']

# %%
import polars as pl
import matplotlib.pyplot as plt

# Assume 'data' is your Polars DataFrame
asset_1 = "VRIG"
asset_2 = "AGZD"

# Normalize prices by the first value
asset_1_values = data[asset_1] / data[asset_1][0]
asset_2_values = data[asset_2] / data[asset_2][0]

# Plot with Date on the x-axis
plt.figure(figsize=(20, 8))
plt.plot(data['Date'], asset_1_values, label=asset_1)
plt.plot(data['Date'], asset_2_values, label=asset_2)
plt.legend()
plt.title(f"Normalized Price Comparison: {asset_1} vs {asset_2}")
plt.xlabel("Date")
plt.ylabel("Normalized Price")
plt.show()

# %% [markdown]
# ## Plot the Spread

# %%
import polars as pl
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import coint

# Function to calculate cointegration
def calculate_cointegration(series_1, series_2):
    _, p_value, _ = coint(series_1, series_2)
    return p_value


# Extract the price series for the two assets and convert to numpy arrays
series_1 = data.select(pl.col(asset_1).cast(pl.Float64)).to_numpy().flatten()
series_2 = data.select(pl.col(asset_2).cast(pl.Float64)).to_numpy().flatten()

# Calculate cointegration
p_value = calculate_cointegration(series_1, series_2)

# Calculate hedge ratio using a simple linear regression
hedge_ratio = np.polyfit(series_2, series_1, 1)[0]

# Calculate the spread
spread = series_1 - (hedge_ratio * series_2)

# Plot the spread
plt.figure(figsize=(20, 8))
plt.plot(spread)
plt.title(f"Spread between {asset_1} and {asset_2}")
plt.xlabel("Time")
plt.ylabel("Spread")
plt.show()

# %%
import polars as pl
import matplotlib.pyplot as plt
import numpy as np

# Function to calculate cointegration and hedge ratio
def calculate_cointegration(series_1, series_2):
    from statsmodels.tsa.stattools import coint
    _, p_value, _ = coint(series_1, series_2)
    hedge_ratio = np.polyfit(series_2, series_1, 1)[0]
    return p_value, hedge_ratio

# Calculate cointegration and hedge ratio
p_value, hedge_ratio = calculate_cointegration(series_1, series_2)

# Calculate the spread
spread = series_1 - (hedge_ratio * series_2)

# Calculate the rolling z-score
window = 100
spread_series = pl.Series(spread)
mean = spread_series.rolling_mean(window)
std = spread_series.rolling_std(window)
z_score = (spread_series - mean) / std

# Plot the z-score
plt.figure(figsize=(20, 8))
plt.plot(z_score.to_numpy())
plt.title(f"Z-Score of Spread between {asset_1} and {asset_2}")
plt.xlabel("Time")
plt.ylabel("Z-Score")
plt.show()

# Coding Comments:
# - This script extracts the price series for two assets from a Polars DataFrame and converts them to numpy arrays.
# - It uses the statsmodels library to perform a cointegration test and calculate the hedge ratio.
# - The spread is calculated using the formula: spread = series_1 - (hedge_ratio * series_2).
# - A rolling window is used to compute the mean and standard deviation of the spread.
# - The z-score is calculated as (spread - mean) / std and plotted to visualize deviations from the mean over time.

# Trading Reasoning:
# - The z-score of the spread can be used to identify potential trading signals. Extreme z-scores may indicate overbought or oversold conditions.
# - By plotting the z-score, traders can visually assess when the spread deviates significantly from the mean, potentially indicating profitable trading opportunities.
